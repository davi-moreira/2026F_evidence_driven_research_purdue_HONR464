# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Chapter 13 — Research Ethics and Data Governance
#
# This is the **companion notebook** of [Chapter 13 — Research Ethics and Data Governance](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part2-curiosity-to-design/research-ethics-and-data-governance.html) from **EDR|AI — Evidence-Driven Research in the Age of AI**. Authored by [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html).
#
# [Open the chapter](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part2-curiosity-to-design/research-ethics-and-data-governance.html) · [Book home](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html) · [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html)
#
# *AI is your arm and your research assistant, not your brain.*

# %% [markdown]
# ## How to use this notebook
#
# 1. Work top to bottom, with the chapter open in another tab.
# 2. Copy each **AI prompt** into your AI tool, run it, then record in the response cell what came back and what you verified.
# 3. Run the code cells; change something and run again.
# 4. Finish the **It is your turn** workspace at the end — that is this chapter's step of your own research project.
# 5. Log every AI use in your **AI Research Ledger**: task · tool · prompt · output summary · decision · verification method · remaining concern · you as the responsible researcher.
# 6. Your AI can be more than a chatbot: agentic tools can run multi-step work for you. Delegating boldly is fine; reviewing, curating, and deciding stay yours.

# %% [markdown]
# > **The research decision.** Whether you are permitted to collect the data your design
# > calls for, who decides that, and how you will hold the data once you have them. You
# > settle this before collection starts, because it is the one design flaw no later
# > analysis can repair.

# %% [markdown]
# ## Code from the chapter
#
# The cells below come from the chapter. Run them, then change something and run again — the numbers should move the way the chapter says they will.

# %% [markdown]
# *From the section “A worked example”.* **What this cell does:** exactly what the chapter walks through in that section; run it and compare with the chapter.

# %%
import numpy as np
from collections import Counter
SEED = 464
rng = np.random.default_rng(SEED)

n = 800
dept    = rng.integers(0, 12, n)      # 12 departments
year    = rng.integers(1, 5, n)       # 4 class years
country = rng.choice(np.arange(28), size=n,
                     p=np.r_[0.45, 0.10, 0.07, 0.05, 0.04, np.full(23, 0.29 / 23)])
age     = np.clip(rng.normal(20.5, 2.2, n).round().astype(int), 17, 35)

def share_unique(*cols):
    keys = list(zip(*cols))
    counts = Counter(keys)
    return sum(1 for k in keys if counts[k] == 1) / len(keys)

print(f"unique on department alone:            {share_unique(dept):.1%}")
print(f"unique on department + year:           {share_unique(dept, year):.1%}")
print(f"unique on department + year + country: {share_unique(dept, year, country):.1%}")
print(f"and adding age:                        {share_unique(dept, year, country, age):.1%}")

# %% [markdown]
# **Reading the output.** The chapter reads this output in the same section; check yours against it, then change one input and rerun. The numbers should move the way the chapter says they will.

# %% [markdown]
# *From the section “A worked example”.* **What this cell does:** exactly what the chapter walks through in that section; run it and compare with the chapter.

# %%
rare = country >= 5                    # students from less-common countries
common = country == 0                  # students from the most common one

print(f"unique among less-common-country students: "
      f"{share_unique(dept[rare], year[rare], country[rare], age[rare]):.1%}")
print(f"unique among most-common-country students: "
      f"{share_unique(dept[common], year[common], country[common], age[common]):.1%}")

# %% [markdown]
# **Reading the output.** The chapter reads this output in the same section; check yours against it, then change one input and rerun. The numbers should move the way the chapter says they will.

# %% [markdown]
# ## It is your turn
#
# <!-- station-pointer:begin -->
# > **You are working inside [Studio 4: Declare and diagnose provisionally](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/studios/studio04-declare-and-diagnose.html).**
# > Keep what you write here; the studio's milestone chapter is
# > where it joins the other lessons' pieces into one artifact
# > you can defend.
# <!-- station-pointer:end -->
#
# Write your project's permission status and its handling rules. This goes in your
# dossier, and every later stage of the project depends on it being honest.
#
# The hands-on half of this section lives in the chapter's **companion notebook**: open it in Colab with the badge at the top, and work the steps there.
#
# > **Do not delegate.**
# >
# > - **The determination.** Only your competent authority can rule on your project. No
# >   tool, and no confident classmate, can do it for you.
# > - **What you promise participants.** You will be held to those words, so they must be
# >   yours.
# > - **What leaves your machine.** Every paste is a decision about somebody else's data.

# %% [markdown]
# **Step 1.** **Run the determination.** Answer the three questions in writing: is your knowledge
# meant to travel, do identifiable living people enter your study, and how do the data
# reach you.
#
# > 💡 **AI Prompt:** "Here is my research question, who my units are, and exactly how I
# > plan to obtain data about them: [paste yours]. Ask me the questions a research ethics
# > committee would ask about this plan. Do not tell me whether I need approval, and do
# > not reassure me — just produce the questions, including the uncomfortable ones."
# >
# > **After running, verify:**
# > - [ ] Answer each question in writing yourself. A question you cannot answer is the
# >   one to bring to your competent authority first.
# > - [ ] Check whether any question reveals data you planned to collect but do not need.
# >   Drop those columns now, while dropping them is free.
# > - [ ] Take the determination to a human. A tool cannot rule on your project, and a
# >   confident answer from one is worth nothing in a meeting.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# ✍️ **Your work for step 1.** Double-click this cell and write your answer here.

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **Step 2.** **Declare one permission status** — cleared, formal determination required, pending,
# or not authorized — and name the competent authority at your institution who covers
# student projects. If your status is anything but cleared, write the date you
# contacted them.

# %% [markdown]
# ✍️ **Your work for step 2.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 3.** **List your columns and minimise them.** Write every variable you plan to collect,
# then cross out the ones your declared analysis does not require. For anything left
# that could single someone out, say how you will coarsen it.

# %% [markdown]
# ✍️ **Your work for step 3.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 4.** **Run the uniqueness check** on your planned quasi-identifiers, using the companion
# notebook. Report the share of units that would be unique, and say which group in
# your data carries the most risk.
#
# > 💡 **AI Prompt:** "Here are the column names, types, and value ranges of my dataset —
# > no actual records: [paste the schema only]. Write code that checks how many rows are
# > unique on each combination of my quasi-identifier columns, and flag combinations that
# > single out fewer than five people."
# >
# > **After running, verify:**
# > - [ ] Confirm you pasted a schema and not data. If you pasted values, treat it as a
# >   disclosure and record it.
# > - [ ] Run the code yourself on your own machine and read the counts. The risk is in
# >   your data, not in the tool's description of it.
# > - [ ] Decide which columns to coarsen or drop. That decision is a research decision
# >   about what your analysis needs.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# ✍️ **Your work for step 4.** Double-click this cell and write your answer here.

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **Step 5.** **Write your AI boundary** in two lines: what you will send to an AI tool on this
# project, and what you will never send. Then write the ledger field you will use to
# record each send.

# %% [markdown]
# ✍️ **Your work for step 5.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 6.** **Write your four governance decisions** — where the data live, who can open them,
# how long you keep them, and what happens at the end. Give the retention date as an
# actual date.

# %% [markdown]
# ✍️ **Your work for step 6.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 7.** **Write your stop plan.** In one sentence: if your determination comes back "not
# authorized", what is the version of this question you would ask instead?
#
# <!-- studio-continue:begin -->
# > **Milestone next.** This was the last lesson of Studio 4.
# > [Milestone 4: Your research contract, v0](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/studios/milestone04-declare-and-diagnose.html#milestone) is where
# > the lessons' pieces become the studio's versioned artifact.
# > Produce it before you move on.
# <!-- studio-continue:end -->

# %% [markdown]
# ✍️ **Your work for step 7.** Double-click this cell and write your answer here.

# %% [markdown]
# ### How this section is graded
#
# Each row scores **0** (missing), **1** (attempted but incomplete, generic, or unverified), or **2** (complete, specific to your own project, and verified where a check applies). **16 points total.**
#
# | # | Criterion | 0–2 |
# |---|---|---|
# | Step 1 | **Run the determination.** Answer the three questions in writing: is your knowledge meant to travel, do identifiable living people enter your study,… | |
# | Step 2 | **Declare one permission status** — cleared, formal determination required, pending, or not authorized — and name the competent authority at your… | |
# | Step 3 | **List your columns and minimise them.** Write every variable you plan to collect, then cross out the ones your declared analysis does not require | |
# | Step 4 | **Run the uniqueness check** on your planned quasi-identifiers, using the companion notebook | |
# | Step 5 | **Write your AI boundary** in two lines: what you will send to an AI tool on this project, and what you will never send | |
# | Step 6 | **Write your four governance decisions** — where the data live, who can open them, how long you keep them, and what happens at the end | |
# | Step 7 | **Write your stop plan.** In one sentence: if your determination comes back "not authorized", what is the version of this question you would ask… | |
# | + | Craft and verification record: AI use logged in your AI Research Ledger, claims stated with their uncertainty, and each key claim verified with a named method | |

# %%
# Scratch space — use this cell for any code your steps need.

# %% [markdown]
# **Before you leave this notebook:** add today's rows to your AI Research Ledger, and verify your key claim with a named method from the [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html). AI can review AI — but the last decision is human.
#
# Next: [Chapter 14 — Observational Descriptive Research](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part3-pathways/11-observational-descriptive-research.html).
