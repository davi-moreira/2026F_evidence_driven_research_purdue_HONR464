# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 36 — Agentes en conflicto y escalamiento humano
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 36 — Agentes en conflicto y escalamiento humano](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part6-after-conference/36-conflicting-agents-and-human-escalation.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Escrito por [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html).
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part6-after-conference/36-conflicting-agents-and-human-escalation.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.
# 6. Tu IA puede ser más que un chatbot: las herramientas agénticas ejecutan trabajo de varios pasos por ti. Delegar con audacia está bien; revisar, curar y decidir siguen siendo tuyos.

# %% [markdown]
# > **La decisión de investigación.** Tus bucles volvieron y no coinciden, o coinciden
# > demasiado bien. Decides cuál de tres cosas estás viendo (desacuerdo real, error
# > correlacionado o consenso fabricado), y decides el momento exacto de detener los bucles
# > y tomar la decisión con tus propias manos.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propio diagnóstico y después delega. Cada prompt abre un
# bucle, y con varios bucles en juego la disciplina es la misma que con uno: lee la
# salida, interrógala, refina, córrelo otra vez, y nunca dejes que un bucle cierre una
# pregunta que te pertenece. Cada prompt es una tarea verificable, no una petición de
# veredicto.

# %% [markdown]
# **Localiza las decisiones que deben escalar.**
#
# ```text
# Act as a research-integrity assistant. Here is my draft's headline claim and the three
# never-delegate decisions I think it contains: [paste]. Using standard research-defense
# criteria, list which decisions in this draft an AI output should never be allowed to
# settle, and which of my three I mislabeled. Do not settle any of them for me.
# ```
# Después de ejecutarlo, verifica: contrasta su lista con los disparadores de escalamiento
# que escribiste por tu cuenta; la decisión que omite es la que hay que cuidar con más
# fuerza. Contrarresta la *ilusión de exhaustividad* (una lista ordenada que en silencio
# suelta la decisión que más importa).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Enumera los acuerdos para verificarlos.**
#
# ```text
# Here are three reviewer outputs on the same draft: [paste all three]. For each pair,
# name one specific way they could be wrong the SAME way: a shared assumption, a shared
# anchor, or a shared prompt. Rank the pairs from most to least likely to share a blind
# spot.
# ```
# Después de ejecutarlo, verifica: para el par que encabeza, vuelve a correr un rol con
# otro planteamiento y otro contexto, y mira si el acuerdo sobrevive. Contrarresta los
# *errores correlacionados entre herramientas o roles* (un acuerdo que es una sola falla
# devuelta como eco).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Hazle red team (revisión adversaria) al consenso.**
#
# ```text
# Act as a hostile reviewer who believes my three roles only agreed because my prompt led
# them. Argue that their consensus is manufactured, name the leading words in my original
# ask, and give me a neutral rewrite. Do not reassure me.
# ```
# Después de ejecutarlo, verifica: si no encuentra una sola palabra que guíe, empuja de
# vuelta y exige la peor, y después vuelve a correr la revisión de forma neutral.
# Contrarresta el *acuerdo complaciente* (elogio que ensaya tu ego, no tu evidencia).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Qué afirmaciones puede defender tu borrador, dónde debe detenerse cada afirmación, si un
# > acuerdo entre tus roles fue alguna vez independiente, y el momento de escalar: eso se
# > queda contigo. Ningún rol decide qué tan confiable es él mismo, y ningún conteo de
# > cabezas de roles decide el límite de tu afirmación ni tu ética. Cuando una salida de IA
# > *zanjaría* una de esas cosas en vez de informarla, te detienes y decides.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Tu proyecto ya tiene un pequeño equipo de IA corriendo sobre una sección; este paso
# decide de antemano dónde deben detenerse esos bucles y devolverte la decisión.*

# %% [markdown]
# **Paso 1.** Escribe tus reglas de escalamiento antes de que empiece la siguiente ronda. Enumera
# las decisiones específicas que ningún bucle puede cerrar: el límite de tu afirmación,
# tu incertidumbre, cuáles fuentes son reales, qué cuenta como terminado y cualquier
# cosa con filo ético. Deja la lista lo bastante corta como para recordarla bajo
# presión.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Añade las condiciones de parada que no son de contenido. Cuántos turnos puede correr
# un bucle antes de que lo leas, y qué tiene permitido cambiar una herramienta agéntica
# sin preguntarte primero.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Encuentra un desacuerdo real en lo que tus roles ya devolvieron, y diagnostícalo
# dejando constancia: desacuerdo real, error correlacionado o un consenso que tu propio
# prompt fabricó. Di cuál y por qué.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Resuélvelo por tu cuenta con una comprobación que los bucles no puedan correr:
# recalcula el número, abre la fuente o compara contra una cifra que nunca estuvo en
# ningún prompt. Escribe juntas la resolución y la comprobación, porque una sin la otra
# es solo una opinión.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Toma un lugar donde tus roles coincidieron en algo que importaba y pon a prueba si el
# acuerdo fue independiente. Vuelve a correr uno de ellos con otro planteamiento y otro
# contexto, o verifica el punto por tu cuenta fuera de las herramientas.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** Registra el conflicto, el diagnóstico y la anulación en tu AI Research Ledger
# (registro de investigación con IA), y verifica al menos una salida con un método
# nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). Un revisor de IA
# puede hacer la comprobación contigo; la decisión de aceptar o rechazar sigue siendo
# tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **14 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Escribe tus reglas de escalamiento antes de que empiece la siguiente ronda | |
# | Paso 2 | Añade las condiciones de parada que no son de contenido | |
# | Paso 3 | Encuentra un desacuerdo real en lo que tus roles ya devolvieron, y diagnostícalo dejando constancia: desacuerdo real, error correlacionado o un… | |
# | Paso 4 | Resuélvelo por tu cuenta con una comprobación que los bucles no puedan correr: recalcula el número, abre la fuente o compara contra una cifra que… | |
# | Paso 5 | Toma un lugar donde tus roles coincidieron en algo que importaba y pon a prueba si el acuerdo fue independiente | |
# | Paso 6 | Registra el conflicto, el diagnóstico y la anulación en tu AI Research Ledger (registro de investigación con IA), y verifica al menos una salida con… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 37 — Investigación final y portafolio de gestión de IA](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part6-after-conference/37-final-research-and-ai-management-portfolio.html).
