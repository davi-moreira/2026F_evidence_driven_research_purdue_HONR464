# %% [markdown]
# # Capítulo 2 — El estudiante como director de investigación
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 2 — El estudiante como director de investigación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part1-research-with-ai/02-the-student-as-research-director.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Pertenece al libro, no a ningún curso: todo lo que necesitas es este cuaderno, el capítulo y Colab gratuito.
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part1-research-with-ai/02-the-student-as-research-director.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.

# %% [markdown]
# > **La decisión de investigación.** Cada tarea de tu proyecto cae en una de tres
# > canastas: segura de delegar, delegar y luego verificar, o nunca delegar. Tu decisión
# > aquí es dónde va cada tarea. Ordenas la lista antes de abrir la herramienta, no a
# > mitad de usarla, y defiendes cada ubicación línea por línea.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Cada prompt de abajo es de **compromiso primero**: escribe tu propia respuesta antes
# de abrir la herramienta, para que su respuesta tenga algo tuyo con qué discrepar.
# Espera correr cada uno más de una vez. Lees la respuesta, encuentras el punto débil,
# afilas el prompt y vas de nuevo. El bucle es normal; detener el bucle antes de haber
# revisado algo es el error.

# %% [markdown]
# **Localizar un recurso de laboratorio (delegable).**
#
# ```text
# Act as a lab-methods assistant in microbiology. I am measuring bacterial growth
# by optical density (OD600). List 3 published, retrievable protocols or textbook
# methods for reading a growth curve. For each, give authors or source, year, and
# where it appears. Only include work you are confident exists; mark anything
# uncertain. Then tell me which one to verify first.
# ```
#
# Después de ejecutarlo, verifica (contrarresta la *fabricación confiada*): abre cada
# protocolo por tu cuenta antes de citarlo; una fuente que no puedes recuperar está
# inventada hasta que se abre.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Convertir tu triaje en una lista revisable.**
#
# ```text
# Here are eight tasks in my project: [paste your list]. For each, label it "safe to
# delegate," "delegate then verify," or "never delegate," and give a one-line reason.
# Return it as a table so I can audit each row on its own.
# ```
#
# Después de ejecutarlo, verifica (contrarresta la *ilusión de exhaustividad*): compara
# la tabla con el triaje que escribiste antes y con tu lista de lo que nunca se delega;
# una tabla ordenada puede archivar mal, en silencio, la única decisión que importaba.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Hacerle red team (revisión adversaria) a tu propia frontera.**
#
# ```text
# I marked this task "never delegate": [paste one task]. Act as a hostile reviewer
# and argue that it is actually safe to hand to an AI. Give your strongest case. Do
# not agree with me.
# ```
#
# Después de ejecutarlo, verifica (contrarresta el *acuerdo complaciente*): si quien
# revisa se rinde y elogia tu llamada, insiste, y después lleva su objeción más fuerte a
# un colega o mentor en lugar de confiar en la aprobación de la herramienta.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Llenar las canastas te toca a ti, y tres llamadas nunca salen de la canasta "nunca
# > delegar": **qué pregunta persigue tu proyecto**, **si tu evidencia sostiene la
# > afirmación que quieres hacer**, y **cuánta incertidumbre reportas**. Puedes pedirle a
# > una herramienta que despliegue opciones, pero elegir entre ellas, y responder por la
# > elección, es el trabajo que te hace quien dirige.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Ya tienes un registro y tres curiosidades. Ahora tomas el puesto de quien decide
# quién hace qué.*

# %% [markdown]
# **Paso 1.** Elige la curiosidad del Capítulo 1 que más te atraiga, y lista cada tarea que
# necesitaría el proyecto construido alrededor de ella: encontrar fuentes, reunir o
# limpiar datos, elegir medidas, calcular, redactar, interpretar, decidir. Apunta a al
# menos diez líneas, y todavía no filtres.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Clasifica cada línea en segura de delegar, delegar y luego verificar, o nunca
# delegar, con una razón de una línea al lado. Esa lista clasificada es tu lista de
# tareas como quien dirige, y la seguirás enmendando por el resto del libro.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Para cada línea de "delegar y luego verificar", nombra la revisión ahora, mientras
# es barata: qué documento vas a abrir, qué número vas a recalcular, qué segundo
# método vas a correr.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Marca con una estrella las dos líneas que defenderías con más fuerza como "nunca
# delegar", y escribe una oración sobre cada una explicando por qué esas llamadas son
# lo que hace tuyo el proyecto.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Entrégale la misma lista a una herramienta de IA, pídele que discuta tus
# ubicaciones, y quédate solo con los cambios que puedas justificar en voz alta.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** Registra ese intercambio en tu AI Research Ledger (tu registro de investigación con
# IA) y verifica al menos una ubicación con un método con nombre de la
# [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). Un triaje es un juicio, así que
# el método que encaja es el razonamiento con pares: pasea tus tres canastas frente a
# un colega o mentor y deja que cuestionen una ubicación. Una IA revisora puede correr
# la revisión contigo; la decisión de aceptar o rechazar sigue siendo tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 3 — Especificar, Delegar, Interrogar, Inspeccionar, Verificar, Documentar, Defender](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part1-research-with-ai/03-specify-delegate-interrogate-inspect-verify-document-defend.html).
