# %% [markdown]
# # Capítulo 18 — Medición y operacionalización
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 18 — Medición y operacionalización](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part4-credible-evidence/18-measurement-and-operationalization.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Pertenece al libro, no a ningún curso: todo lo que necesitas es este cuaderno, el capítulo y Colab gratuito.
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part4-credible-evidence/18-measurement-and-operationalization.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.

# %% [markdown]
# > **La decisión de investigación.** Decide cómo convertir la idea abstracta sobre la
# > que trata tu pregunta en un número concreto que puedas registrar, repetir y
# > defender. Nombra el concepto, nombra el constructo más estrecho que lo va a
# > representar, nombra el indicador que de verdad vas a medir, y luego di con claridad
# > qué captura ese indicador y qué deja fuera en silencio.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propio borrador y luego delega. Cada prompt es una tarea
# verificable, no un veredicto en el que confiar. Córrelos como un **bucle de IA**, el
# ciclo prompt → respuesta → interrogación → refinamiento → nueva ejecución: la primera
# respuesta nombra los instrumentos obvios, y la pasada útil es la segunda, donde dices
# qué faceta se saltó la herramienta y le pides que lo intente de nuevo. Las herramientas
# agénticas darán con gusto tres o cuatro vueltas y devolverán un plan de medición
# pulido. El pulido no es validez, y la oración que nombra lo que tu número deja fuera
# sigue teniendo que escribirla tú.

# %% [markdown]
# **Localiza los indicadores estándar.**
#
# ```text
# Act as a survey-methods assistant. I want to measure the construct "willingness to
# recommend one's workplace" in an organizational study. Name the standard, published
# instruments researchers use for this construct, with the instrument name, how it is
# scored, and a real source I can open. Only list instruments you are confident
# exist; mark anything uncertain.
# ```
# Después de ejecutarlo, verifica: abre una de las fuentes nombradas y confirma que el
# instrumento existe y mide lo que la herramienta dice. Contrarresta la *fabricación
# confiada* (*confident fabrication*): el nombre de una escala inventada llega con la
# misma fluidez que uno real.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Enumera los límites, para que puedas verificarlos.**
#
# ```text
# Here is my operationalization: concept = employee engagement, construct =
# willingness to recommend the workplace, indicator = mean of a single 1-7 agreement
# item. Return a table of every facet of engagement this indicator does NOT capture,
# one row each, with why it matters and who it fails to hear from.
# ```
# Después de ejecutarlo, verifica: contrasta la tabla con un marco publicado sobre
# compromiso laboral que recuperes por tu cuenta. Contrarresta la *ilusión de
# exhaustividad*: una lista ordenada que aun así omite la faceta que más amenaza tu
# afirmación.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Haz red team al intercambio.**
#
# ```text
# Act as a hostile reviewer. Here is my claim: "the pilot sites are more engaged,
# because more people there would recommend the company." Name every place my
# indicator fails to support the word "engaged." Do not rewrite the claim for me.
# ```
# Después de ejecutarlo, verifica: si solo elogia el diseño, insiste y exige el peor
# hueco. Contrarresta el *acuerdo complaciente*: elogios que revisan tu ego, no tu
# medición.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Sobre qué **concepto** trata tu pregunta, qué **constructo** lo representa con
# > honestidad y dónde debe detenerse el significado de tu **indicador** son cosas solo
# > tuyas. La herramienta puede listar instrumentos y nombrar limitaciones, pero solo tú
# > decides que una calificación de recomendar a una amistad es un sustituto justo de la
# > faceta del compromiso que de verdad te importa, y solo tú escribes la oración que se
# > niega a llamar concepto entero a una sola faceta. Nombrar lo que tu número deja fuera
# > es trabajo de quien investiga, no del modelo.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Ya sabes de dónde vienen tus datos. Este paso fija qué significan de verdad tus
# números, y qué no.*

# %% [markdown]
# **Paso 1.** Enumera cada concepto que contiene tu pregunta y marca con un círculo los
# abstractos, las palabras que ningún instrumento lee: compromiso, salud,
# participación, calidad, competitividad. Esos son los que necesitan una escalera.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Debajo de cada concepto marcado escribe el constructo que de verdad vas a medir,
# más una línea sobre por qué esa faceta y no una vecina. Elegir una faceta no es
# hacer trampa. Fingir que mediste el concepto entero, sí.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Debajo de cada constructo escribe el indicador: el procedimiento exacto y el número
# exacto que produce, lo bastante específico como para que alguien desconocido pueda
# repetirlo y obtener un valor comparable.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Debajo de cada indicador completa esta oración con tus propias palabras: "este
# número no captura ___". Usa la faceta que más te preocupa, y agrega a quiénes tu
# medición nunca alcanza.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Planea una comprobación de confiabilidad que de verdad puedas correr, y luego
# córrela: las mismas unidades medidas dos veces, dos personas codificando los mismos
# ítems, o dos mitades de una muestra comparadas.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** Registra el paso en tu AI Research Ledger (registro de investigación con IA) y
# verifica al menos una medida con un método nombrado de la [Guía de
# Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La lectura de la fuente primaria encaja
# con este capítulo: encuentra el instrumento o el método publicado detrás de tu
# indicador, ábrelo y confirma que mide lo que estás afirmando antes de citarlo. Una
# IA revisora puede hacer la comprobación contigo; la decisión de aceptar o rechazar
# es tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **14 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Enumera cada concepto que contiene tu pregunta y marca con un círculo los abstractos, las palabras que ningún instrumento lee: compromiso, salud,… | |
# | Paso 2 | Debajo de cada concepto marcado escribe el constructo que de verdad vas a medir, más una línea sobre por qué esa faceta y no una vecina | |
# | Paso 3 | Debajo de cada constructo escribe el indicador: el procedimiento exacto y el número exacto que produce, lo bastante específico como para que alguien… | |
# | Paso 4 | Debajo de cada indicador completa esta oración con tus propias palabras: "este número no captura ___" | |
# | Paso 5 | Planea una comprobación de confiabilidad que de verdad puedas correr, y luego córrela: las mismas unidades medidas dos veces, dos personas… | |
# | Paso 6 | Registra el paso en tu AI Research Ledger (registro de investigación con IA) y verifica al menos una medida con un método nombrado de la Guía de… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 19 — La IA como programadora](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part4-credible-evidence/19-ai-as-programmer.html).
