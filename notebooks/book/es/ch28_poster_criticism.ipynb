# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 28 — Crítica del póster
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 28 — Crítica del póster](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/28-poster-criticism.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Escrito por [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html).
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/28-poster-criticism.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.
# 6. Tu IA puede ser más que un chatbot: las herramientas agénticas ejecutan trabajo de varios pasos por ti. Delegar con audacia está bien; revisar, curar y decidir siguen siendo tuyos.

# %% [markdown]
# > **La decisión de investigación.** Antes de que tu borrador se convierta en la versión
# > que otras personas leen, decides si está listo o si necesita un arreglo más. Corres la
# > auditoría que correría un desconocido hostil: ¿el titular se queda dentro de la
# > evidencia?, ¿la imagen coincide con los números?, ¿la incertidumbre está junto a la
# > afirmación?, ¿cada número se rastrea hasta una celda?, ¿todo el mundo puede recibirlo?
# > Después tomas la decisión de cierre y la defiendes en voz alta.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propia auditoría y después delega. Cada prompt le entrega a la
# herramienta una tarea que puedes verificar, con una nota de verificación que nombra la falla
# contra la que te defiende.
#
# Trata cada prompt como una jugada de apertura. Cuando la respuesta vuelva pobre, di qué se le
# escapó y pregunta de nuevo. Quien revisa se afila en la segunda pasada, humano o máquina por
# igual. Algunas herramientas ya corren ese bucle internamente y devuelven solo la crítica
# final, lo cual es cómodo y también esconde el razonamiento que de otro modo podrías
# cuestionar.

# %% [markdown]
# **Genera las preguntas hostiles (tú asignas cada una a una auditoría).**
#
# ```text
# Act as a hostile poster reviewer. My headline figure is a bar chart comparing
# mean corn yield for compost-amended versus control plots on a y-axis that starts
# at 180, titled "Compost RAISES corn yield," with no interval shown and the two
# bars told apart by red versus green only. Generate the six hardest skeptic
# questions you would ask, then name the single flaw this figure cannot answer.
# ```
#
# Después de ejecutarlo, verifica (contrarresta la *ilusión de exhaustividad*): asigna cada
# pregunta a una auditoría (límite de la afirmación, honestidad de la figura, recorrido de
# lectura, incertidumbre, accesibilidad). Una auditoría entera que la lista ordenada se salta es
# el hueco. Después contrasta las sobrevivientes con la brecha real y el factor de exageración
# que imprimió tu propia celda del notebook.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Enumera las codificaciones de color a verificar (tú las contrastas con la figura
# renderizada).**
#
# ```text
# Here is the code that draws my poster's headline figure: [paste the cell]. List
# every place it encodes a meaningful distinction with color, and for each, say what
# a red-green color-blind reader and a screen-reader user would fail to receive.
# Then propose one redundant encoding that carries the same distinction.
# ```
#
# Después de ejecutarlo, verifica (contrarresta el *método plausible pero equivocado*): lee cada
# codificación que nombre contra tu figura renderizada. Los consejos de accesibilidad genéricos
# que no corresponden a cómo está dibujada tu figura están mal para tu caso, así que confía en
# la imagen que puedes ver y vuelve a renderizar después de aplicar uno de los arreglos
# propuestos.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Haz red team (revisión adversaria) a tu respuesta hablada (tú te quedas con las palabras).**
#
# ```text
# Here is my written headline: "[paste it]". Here is what I plan to say when a
# skeptic asks whether something else could explain it: "[paste it]". Find every
# place my spoken answer claims more than my written headline. Do not rewrite it;
# list the exact words.
# ```
#
# Después de ejecutarlo, verifica (contrarresta el *cambio silencioso de alcance*): lee cada
# frase señalada junto a tu posición en la brújula. Conserva cada captura de un "causa" hablado
# que tu póster escrito nunca dijo, y rechaza cualquier empujón a conceder un punto que tu
# diseño sí autoriza.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Estas cosas se quedan contigo, por fluida que suene la herramienta. Las palabras de tu
# > afirmación titular, y el verbo que la mantiene dentro de tu posición en la brújula. La
# > decisión, tomada en voz alta, de defender un punto o conceder. Y la decisión de que el póster
# > es lo bastante honesto para cerrarse. La herramienta puede generar preguntas difíciles y
# > revisar una figura en busca de trampas de color; decidir qué autoriza tu evidencia, y
# > responder por ello frente al tablero, es tuyo.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Tienes una página borrador y una figura principal; este paso es la auditoría que decide si
# alguna de las dos sobrevive a un desconocido hostil.*

# %% [markdown]
# **Paso 1.** Corre la auditoría de recorrido de galería sobre tu propio borrador como si nunca lo
# hubieras visto: límite de la afirmación, honestidad de la figura, recorrido de lectura,
# incertidumbre, accesibilidad. Anota cada golpe, localizado con la precisión suficiente para
# arreglarlo.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Ordena los golpes por qué tan lejos viaja el error. Un verbo causal que tu diseño nunca
# compró viaja más lejos, porque quien atrapa una exageración deja de confiar en todo lo
# demás.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Enfrenta las tres lentes en voz alta: alguien de fuera, una persona especialista y alguien
# escéptico con una explicación rival. Para cada pregunta, decide defender o conceder, y
# escribe la redacción más angosta a la que concederías.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Revisa una vez, arreglando los golpes en orden de prioridad, y después toma la decisión de
# cierre. Cada número rastreado y cada cita abierta, o todavía no.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Regístralo en tu AI Research Ledger (registro de investigación con IA) y verifica al menos
# un número corregido con un método nombrado de la [Guía de
# Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). Un revisor de IA puede hacer la comprobación
# contigo; la decisión de aceptar o rechazar sigue siendo tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **12 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Corre la auditoría de recorrido de galería sobre tu propio borrador como si nunca lo hubieras visto: límite de la afirmación, honestidad de la… | |
# | Paso 2 | Ordena los golpes por qué tan lejos viaja el error | |
# | Paso 3 | Enfrenta las tres lentes en voz alta: alguien de fuera, una persona especialista y alguien escéptico con una explicación rival | |
# | Paso 4 | Revisa una vez, arreglando los golpes en orden de prioridad, y después toma la decisión de cierre | |
# | Paso 5 | Regístralo en tu AI Research Ledger (registro de investigación con IA) y verifica al menos un número corregido con un método nombrado de la Guía de… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 29 — Pitches de investigación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/29-research-pitches.html).
