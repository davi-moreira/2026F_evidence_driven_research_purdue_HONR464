# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 8 — Encontrar y verificar la evidencia previa
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 8 — Encontrar y verificar la evidencia previa](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/08-finding-and-verifying-prior-evidence.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Escrito por [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html).
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/08-finding-and-verifying-prior-evidence.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.
# 6. Tu IA puede ser más que un chatbot: las herramientas agénticas ejecutan trabajo de varios pasos por ti. Delegar con audacia está bien; revisar, curar y decidir siguen siendo tuyos.

# %% [markdown]
# > **La decisión de investigación.** Cuáles de tus pistas candidatas sobreviven a la
# > recuperación y a la lectura, y por lo tanto se vuelven evidencia sobre la que puedes
# > construir, y si el punto silencioso que dejan en tu mapa es un vacío genuino o una
# > búsqueda que detuviste demasiado pronto.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propia respuesta y solo después delega. La verificación
# tampoco es un solo prompt. Es un **bucle de IA**: el ciclo prompt → respuesta →
# interrogación → refinamiento → nueva ejecución. Preguntas, lees la salida contra el
# artículo, le dices a la herramienta exactamente dónde se pasó de la raya, y vuelves a
# preguntar. La segunda pasada suele ser donde aparece la respuesta honesta, porque la
# primera todavía está tratando de agradarte.
#
# ```text
# My research question is: [paste it]. The claim I need sources for is:
# [paste the claim]. List the five published studies most relevant to this
# claim, each with authors, year, exact title, and venue, so I can retrieve
# and verify each one myself.
# ```
# *Después de ejecutarlo, verifica:* busca cada título exacto entre comillas antes de
# creer que existe. Esto contrarresta la **fabricación confiada** (*confident
# fabrication*), una cita que suena real de un artículo que nunca se escribió.
#
# ```text
# Here are the five sources I retrieved and read: [paste them]. For each, state
# the single claim its evidence actually supports, and flag any where my
# one-line summary reaches further than the study does.
# ```
# *Después de ejecutarlo, verifica:* lee cada afirmación marcada contra la sección de
# resultados del propio artículo. Esto contrarresta la **fuente mal caracterizada**
# (*mischaracterized source*) y el **cambio silencioso de alcance** (*silent scope
# change*), una correlación reportada calladamente como una causa.
#
# ```text
# Here is my research question and the gap I placed: [paste them]. Argue the gap
# is NOT real: name up to three published studies that may already fill it, with
# authors, year, title, and venue. Do not reassure me.
# ```
# *Después de ejecutarlo, verifica:* recupera cada estudio que nombre; una fuente que no
# puedes abrir no cierra nada. Esto contrarresta el **acuerdo complaciente**
# (*sycophantic agreement*): una IA que elogia tu vacío te ha halagado, no lo ha puesto
# a prueba.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Dos decisiones son solo tuyas, porque tu nombre va en el mapa. Primera, **si una
# > fuente cuenta como verificada**: la recuperaste, la abriste y leíste la afirmación por
# > tu cuenta, así que ningún resumen de IA sustituye al artículo. Segunda, **si tu vacío
# > es genuino**: recorriste un enlace hacia atrás y uno hacia adelante desde cada fuente
# > verificada y la pregunta sigue sin respuesta. Una IA puede señalar; solo tú puedes
# > responder por ella.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Entraste con una lista de pistas candidatas. Sales con una base de evidencia que
# abriste personalmente, y con un vacío que puedes defender en voz alta.*

# %% [markdown]
# **Paso 1.** Intenta recuperar cada candidata de tu lista. Busca el título exacto entre comillas
# en la base de datos de tu biblioteca y en Google Scholar. Lo que no aparezca sigue
# siendo una pista y nunca entra en tu base de evidencia. Anota por qué falló.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Abre las que sí aparecen y léelas. Como mínimo: el resumen, la sección de diseño y
# los resultados. Luego escribe la afirmación central de cada fuente en una oración,
# con tus palabras. Si no puedes escribir esa oración, todavía no la has leído.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Critica cada una. Nombra la población que estudió, el diseño que usó y la única
# cosa que *no* concluirías a partir de ella. Una fuente que no puedes criticar es
# una fuente que no has entendido.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Dibuja tu mapa de evidencia: un nodo por fuente verificada, líneas entre las que
# coinciden, y una línea marcada entre cualquier par que se contradiga. Las
# contradicciones se dibujan, nunca se maquillan.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Encuentra el punto silencioso del mapa y escribe tu vacío como una oración acotada:
# «Entre las fuentes que recuperé y verifiqué, ___ no ha sido establecido para ___».
# Si la versión honesta es «mi búsqueda todavía está inconclusa», escribe eso en su
# lugar. Eso es un hallazgo sobre tu búsqueda, no un fracaso.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** Registra el trabajo de verificación en tu AI Research Ledger (registro de
# investigación con IA), nombrando el método que usaste de la
# [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html); la lectura de la fuente
# primaria es el que le corresponde a cada cita. Una IA revisora puede intentar contigo argumentar
# en contra de tu vacío; la decisión de conservarlo o descartarlo es tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **14 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Intenta recuperar cada candidata de tu lista | |
# | Paso 2 | Abre las que sí aparecen y léelas | |
# | Paso 3 | Critica cada una | |
# | Paso 4 | Dibuja tu mapa de evidencia: un nodo por fuente verificada, líneas entre las que coinciden, y una línea marcada entre cualquier par que se contradiga | |
# | Paso 5 | Encuentra el punto silencioso del mapa y escribe tu vacío como una oración acotada: «Entre las fuentes que recuperé y verifiqué, ___ no ha sido… | |
# | Paso 6 | Registra el trabajo de verificación en tu AI Research Ledger (registro de investigación con IA), nombrando el método que usaste de la Guía de… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 9 — Modelo, indagación, estrategia de datos y estrategia de respuesta](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/09-model-inquiry-data-strategy-and-answer-strategy.html).
