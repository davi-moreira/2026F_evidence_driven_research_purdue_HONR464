# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 9 — Modelo, indagación, estrategia de datos y estrategia de respuesta
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 9 — Modelo, indagación, estrategia de datos y estrategia de respuesta](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/09-model-inquiry-data-strategy-and-answer-strategy.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Escrito por [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html).
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/09-model-inquiry-data-strategy-and-answer-strategy.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.
# 6. Tu IA puede ser más que un chatbot: las herramientas agénticas ejecutan trabajo de varios pasos por ti. Delegar con audacia está bien; revisar, curar y decidir siguen siendo tuyos.

# %% [markdown]
# > **La decisión de investigación.** Las cuatro partes de tu propio diseño, escritas
# > antes de que exista dato alguno: un modelo del mundo, la única cantidad con nombre
# > que quieres sacar de él, un plan de cómo llegan los datos y un plan para convertir
# > esos datos en tu cantidad. Y luego la decisión más difícil: si esas cuatro partes de
# > verdad apuntan a lo mismo.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Escribe primero tu propio borrador de cada parte y solo después pregunta.
# Comprometerte primero le da a la salida de la IA algo con lo que estar en desacuerdo.
# Y cuenta con dar más de una vuelta: redactas, lees la respuesta, corriges la única
# parte que salió mal, pegas tu corrección de vuelta y vuelves a preguntar. Ese es el
# **bucle de IA**: el ciclo prompt → respuesta → interrogación → refinamiento → nueva
# ejecución. Cada vuelta debería afilar la indagación hacia menos palabras, no hacia
# más.
#
# ```
# Act as a research-design tutor. Here is my research question: [paste it].
# Draft the four MIDA parts as a labeled list — Model, Inquiry, Data strategy,
# Answer strategy. State the Inquiry as one exact quantity. Mark each part
# "confident" or "guessing." Do not smooth over gaps.
# ```
#
# Después de ejecutarlo, verifica: lee las palabras de la indagación redactada junto a
# las palabras de tu pregunta. ¿Coinciden el tipo y el alcance? Esto contrarresta el
# **cambio silencioso de alcance** (*silent scope change*), donde la herramienta
# responde una pregunta vecina más fácil que la que hiciste.
#
# ```
# Act as a hostile methodologist. Here are my four MIDA parts: [paste them].
# Name the single worst misalignment — a place where my data or answer strategy
# cannot reach my stated inquiry. Give one concrete way my design fails, not
# praise.
# ```
#
# Después de ejecutarlo, verifica: contrasta la objeción con tu propia nota de
# alineación. Esto contrarresta el **acuerdo complaciente** (*sycophantic agreement*),
# donde la herramienta declara sólido un diseño porque tú lo propusiste.
#
# ```
# Find one real, published study that used a design like mine to answer a similar
# question. Give title, authors, year, and venue. If you are not confident it
# exists, say so instead of inventing one.
# ```
#
# Después de ejecutarlo, verifica: abre una base de datos de biblioteca y localiza el
# estudio exacto antes de citarlo. Esto contrarresta la **fabricación confiada**
# (*confident fabrication*), donde la herramienta devuelve una cita plausible de un
# artículo que no existe.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Tres elecciones siguen siendo tuyas. **Qué mundo supone tu pregunta** (el modelo, y
# > por lo tanto qué podría confundirlo). **Qué única cantidad quieres** (la indagación,
# > nombrada con tus palabras, no con la paráfrasis de la IA). Y **si tus cuatro partes se
# > alinean**, y por lo tanto si el límite de tu afirmación es *causa*, solo *está
# > asociado con*, o *causal, pero todavía no identificada por este diseño*. Ese tercer
# > estado es una respuesta de verdad, y conservar tu pregunta admitiendo que el diseño
# > no la alcanza es más honesto que encoger la pregunta para que quepa en los datos.
# > Una IA puede redactar partes candidatas. Decidir que coinciden, y
# > hacerte cargo de la afirmación que se desprende, es un juicio de investigación que no
# > puedes ceder.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Tienes una pregunta y un vacío que puedes defender. Este paso los convierte en un
# diseño, en una página, en cuatro partes que tienen que coincidir entre sí.*

# %% [markdown]
# **Paso 1.** Escribe tu **modelo** en tres o cuatro oraciones de lenguaje llano. Qué unidades
# existen, qué podría afectar a qué, y qué puede variar. No hacen falta ecuaciones.
# Después dibújalo como cajas y flechas, aunque quede feo.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Escribe tu **indagación** como una oración que nombre una cantidad: un promedio,
# una diferencia, una tasa, una proporción. Si necesitas la palabra «y» para
# enunciarla, tienes dos indagaciones. Elige la que defenderías primero.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Escribe tu **estrategia de datos**: quién o qué se muestrea, de qué lista, y quién
# recibe cada condición, si es que hay condiciones. Di con honestidad si algo se
# aleatoriza o si el mundo asignó las condiciones por ti.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Escribe tu **estrategia de respuesta**: la aritmética que convierte tus datos en tu
# indagación. Restar dos promedios cuenta. Aquí lo simple es una virtud.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Audita la alineación por tu cuenta y escribe la oración que importa: «Como mi estrategia
# de datos es ___, la redacción honesta más fuerte de mi resultado es ___». Si esa
# oración aterriza en *está asociado con* en lugar de *causa*, no fracasaste:
# encontraste temprano el límite de tu afirmación, que es justamente el punto.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** Registra el borrador en tu AI Research Ledger (registro de investigación con IA) y
# después verifica la afirmación de alineación con un método nombrado de la
# [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html); tanto el razonamiento con pares
# como un diagrama causal encajan. Una IA revisora puede discutir contigo la desalineación;
# la decisión de aceptar o rechazar la objeción es tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **14 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Escribe tu **modelo** en tres o cuatro oraciones de lenguaje llano | |
# | Paso 2 | Escribe tu **indagación** como una oración que nombre una cantidad: un promedio, una diferencia, una tasa, una proporción | |
# | Paso 3 | Escribe tu **estrategia de datos**: quién o qué se muestrea, de qué lista, y quién recibe cada condición, si es que hay condiciones | |
# | Paso 4 | Escribe tu **estrategia de respuesta**: la aritmética que convierte tus datos en tu indagación | |
# | Paso 5 | Audita la alineación por tu cuenta y escribe la oración que importa: «Como mi estrategia de datos es ___, la redacción honesta más fuerte de mi… | |
# | Paso 6 | Registra el borrador en tu AI Research Ledger (registro de investigación con IA) y después verifica la afirmación de alineación con un método… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 10 — Declarar y diagnosticar un diseño de investigación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/10-declaring-and-diagnosing-a-research-design.html).
