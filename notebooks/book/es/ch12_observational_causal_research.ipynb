# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 12 — Investigación observacional causal
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 12 — Investigación observacional causal](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part3-pathways/12-observational-causal-research.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Escrito por [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html).
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part3-pathways/12-observational-causal-research.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.
# 6. Tu IA puede ser más que un chatbot: las herramientas agénticas ejecutan trabajo de varios pasos por ti. Delegar con audacia está bien; revisar, curar y decidir siguen siendo tuyos.

# %% [markdown]
# > **La decisión de investigación.** Si tu comparación observacional se ganó la palabra
# > *porque* o tiene que detenerse en *asociado con*. Lo resuelves nombrando el único
# > factor de confusión del que depende la comparación y escribiendo el argumento de
# > identificación que cierra la puerta trasera, o admitiendo por escrito que no tienes
# > ninguno.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propia respuesta cada vez, y solo después delega. Trata cada
# uno de estos como el movimiento de apertura de un **bucle de IA** (el ciclo prompt →
# respuesta → interrogación → refinamiento → nueva ejecución), no como una pregunta suelta.
# Pregunta, lee, nombra la única cosa que la respuesta entendió mal sobre tu contexto y
# vuelve a preguntar con esa corrección en la mano. En las preguntas causales la segunda
# pasada importa más que en ninguna otra parte de este libro, porque la primera respuesta
# casi siempre acepta tu encuadre, y tu encuadre es justamente lo que hay que atacar.

# %% [markdown]
# **Localizar un diseño real (comprométete primero con tu propia apuesta sobre la palanca).**
#
# ```
# Act as a research librarian in biology. Find peer-reviewed observational studies
# that used a natural experiment or a discontinuity to estimate the causal effect of
# a gut microbe on a host trait. For each: title, authors, year, venue, and the
# as-if-random source. Only include work you are confident exists; mark anything
# uncertain.
# ```
# *Después de ejecutarlo, verifica (contrarresta la **fabricación confiada**): abre cada
# fuente y lee tú la línea antes de citarla, que es lectura de la fuente primaria.
# Descarta las que no puedas encontrar.*

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Listar los factores de confusión que hay que verificar (haz primero tu propia lista).**
#
# ```
# I claim a gut microbe causes leanness in wild mice. List traits that plausibly raise
# both microbe presence and leanness, in a table with the trait and the direction it
# would bias a naive comparison. Then, as a hostile reviewer, name the one trait you
# are most likely wrong to include and the important one you left out.
# ```
# *Después de ejecutarlo, verifica (contrarresta la **ilusión de exhaustividad**):
# compara la lista con la que redactaste primero y mapea cada rasgo a un camino de puerta
# trasera (rasgo → microbio, rasgo → delgadez). Un rasgo con una sola flecha no es un
# factor de confusión.*

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Red team a la oración causal que escribiste (escribe tú la oración; no dejes que la IA la redacte).**
#
# ```
# Here is a causal sentence I wrote: "[paste your sentence]." Act as a hostile peer
# reviewer. Name every place it over-reaches or claims more than my observational
# design identifies. Do not rewrite it for me; list the weaknesses so I fix them.
# ```
# *Después de ejecutarlo, verifica (contrarresta el **acuerdo complaciente**): si todas
# las objeciones son suaves, insiste con «supón que la oración es incorrecta; nombra el
# peor defecto». El elogio sin una objeción es una señal de alerta.*

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Tres decisiones son solo tuyas. **Si tu diseño identifica un efecto causal** es un juicio
# > sobre cómo se asignó realmente el tratamiento, y solo tú lo sabes. **Cuál factor de
# > confusión amenaza más tu comparación** depende del mecanismo, que un modelo no puede ver
# > en tus datos. Y **si tu hallazgo se gana el *porque* o tiene que detenerse en *asociado
# > con*** es toda la destreza de este capítulo. Una herramienta llamará encantada
# > «experimento natural» a tu comparación porque tú escribiste esas palabras. Ganarse el
# > *porque* es tu firma, no la del modelo.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Tu diseño está declarado y diagnosticado. Este capítulo de ruta es donde una pregunta
# causal obtiene por escrito su argumento de identificación, o recibe en su lugar un límite
# honesto.*

# %% [markdown]
# **Paso 1.** Decide en cuál caso estás. Si tu indagación pregunta *qué pasaría si* algo cambiara,
# y nadie aleatorizó el cambio, esta es tu ruta. Si tu indagación es descriptiva,
# predictiva o genuinamente experimental, no lo es, y entonces corres el ejercicio del
# paso 6.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** **Si esta es tu ruta**, escribe tu pregunta causal como exactamente dos cosas: un
# tratamiento (lo que varía) y un resultado (lo que mides). Una oración, sin rodeos.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Dibuja el diagrama causal. Pon tratamiento y resultado en los extremos y agrega cada
# tercera variable que se te ocurra que empuje sobre ambos. Encierra en un círculo el
# factor de confusión que más temes. Después escribe, en una línea, si puedes medirlo.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Nombra tu palanca y su precio. Selección sobre observables, un experimento natural,
# diferencias en diferencias, regresión discontinua o variables instrumentales, y
# debajo la lista corta de supuestos estructurales en los que se apoya, cada uno en
# lenguaje llano con el que alguien escéptico pueda discutir. Empieza por el que más
# dudas te dé. Si no tienes palanca, escribe en su lugar la
# oración del límite del lenguaje causal: qué muestra tu comparación y qué *porque*
# estás declinando afirmar.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Anota un número que volverías a calcular por una segunda vía para comprobar
# cualquier estimación que te entregue alguien de tu equipo o una IA, y di qué
# resultado te haría abandonar por completo la lectura causal.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** **Si esta no es tu ruta**, corre el ejercicio de clasificación. Escribe de todos
# modos la versión causal de tu pregunta, nombra el factor de confusión del que
# dependería y di qué supuesto tendrías que defender para responderla. Saber qué no
# estás afirmando vale tanto como saber qué sí.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 7.** Registra todo en tu AI Research Ledger (registro de investigación con IA) y verifica
# con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html); el
# diagrama causal es el método construido para este capítulo, y la simulación con un
# factor de confusión que plantas tú es la segunda comprobación fuerte. Una IA revisora
# puede atacar el supuesto junto a ti; la decisión de conservar el *porque* o replegarse
# a *asociado con* es tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 7.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **16 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Decide en cuál caso estás | |
# | Paso 2 | **Si esta es tu ruta**, escribe tu pregunta causal como exactamente dos cosas: un tratamiento (lo que varía) y un resultado (lo que mides) | |
# | Paso 3 | Dibuja el diagrama causal | |
# | Paso 4 | Nombra tu palanca y su precio | |
# | Paso 5 | Anota un número que volverías a calcular por una segunda vía para comprobar cualquier estimación que te entregue alguien de tu equipo o una IA, y di… | |
# | Paso 6 | **Si esta no es tu ruta**, corre el ejercicio de clasificación | |
# | Paso 7 | Registra todo en tu AI Research Ledger (registro de investigación con IA) y verifica con un método nombrado de la Guía de Verificación; el diagrama… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 13 — Investigación experimental descriptiva](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part3-pathways/13-experimental-descriptive-research.html).
