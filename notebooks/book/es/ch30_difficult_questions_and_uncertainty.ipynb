# %% [markdown]
# # Capítulo 30 — Preguntas difíciles e incertidumbre
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 30 — Preguntas difíciles e incertidumbre](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/30-difficult-questions-and-uncertainty.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Pertenece al libro, no a ningún curso: todo lo que necesitas es este cuaderno, el capítulo y Colab gratuito.
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/30-difficult-questions-and-uncertainty.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.

# %% [markdown]
# > **La decisión de investigación.** Decide, antes de que alguien pregunte, cómo vas a
# > decir lo que tu estudio no puede mostrar. Escribes por adelantado la incertidumbre, los
# > límites y las respuestas a las preguntas justas más difíciles, para que la versión que
# > sale de tu boca bajo presión sea la que elegiste y no la que escribió la adrenalina. Esa
# > respuesta la preparas; nunca la improvisas.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propia respuesta y después delega. Cada prompt de abajo es una tarea
# verificable, no una petición de aprobación.
#
# Estos funcionan mejor como conversación. Pregunta, lee, después nombra lo que la respuesta evitó
# y pregunta de nuevo. Un banco de preguntas construido en tres rondas es notablemente más duro
# que uno construido de una sola pasada. Cuando una herramienta corre esas rondas por su cuenta,
# las preguntas llegan ya pulidas, y por eso contrastas la lista con la pregunta que de verdad
# temes, y no al revés.

# %% [markdown]
# **Enumera tus preguntas más difíciles, para contrastarlas con tu propio miedo.**
#
# ```text
# Play a skeptical but fair conference visitor. My project: "[one-paragraph summary
# of question, design, and headline finding]". Write the single hardest FAIR question
# for each type: method, alternative explanation, why-it-matters, generalization,
# AI-use. For each, flag whether an honest two-sentence answer exists.
# ```
# Después de ejecutarlo, verifica: compara las cinco con la única pregunta que escribiste y que
# más temes. Si falta, el conjunto no está completo. Contrarresta la *ilusión de exhaustividad*
# (unas cinco muy ordenadas que omiten justo la pregunta que temes).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Fuerza a que la incertidumbre salga a la luz.**
#
# ```text
# Here is my headline number and how I got it: "[paste]". Do not restate it.
# List what is missing before I can state its uncertainty honestly: the sample
# size, the source of wobble, and the one limitation a reviewer would raise first.
# ```
# Después de ejecutarlo, verifica: confirma cada punto contra tus propios datos antes de decirlo
# en voz alta. Contrarresta la *incertidumbre ausente* (un número limpio reportado sin ningún
# margen).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Haz red team (revisión adversaria) a tu respuesta.**
#
# ```text
# Here is my two-sentence reply to "does it cause it?": "[paste]". Act as a hostile
# reviewer. Name every word that still claims more than an association supports.
# Do not rewrite it for me.
# ```
# Después de ejecutarlo, verifica: si solo elogia la respuesta, insiste y exige la única peor
# palabra. Contrarresta la *adulación complaciente* (el elogio revisa tu ego, no tu evidencia).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Tres decisiones nunca salen de tus manos: **qué afirmación respalda realmente tu evidencia**,
# > **dónde tiene que detenerse esa afirmación** y **cómo reconoces su incertidumbre y sus
# > limitaciones**. La herramienta puede redactar una pregunta o señalar una palabra, pero solo tú
# > decides la posición en la brújula que tu diseño puede sostener y la única palabra que debes
# > rechazar en voz alta. Tu no-sé honesto es tuyo para sostenerlo, no para recitarlo.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Ya puedes decir tu afirmación en dos longitudes; este paso prepara la parte de la conversación
# que no controlas.*

# %% [markdown]
# **Paso 1.** Escribe las cinco preguntas justas más difíciles que alguien podría hacerte, una por cada
# tipo: método, explicación alternativa, y-esto-para-qué, generalización, uso de IA.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Redacta una respuesta de dos frases para cada una y márcala como defender o conceder. Una
# respuesta de conceder nombra la afirmación más angosta a la que te replegarías en el momento.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Escribe tu declaración de incertidumbre y limitaciones en forma ULN: cuánto podría oscilar tu
# número y por qué, la única cosa que tu diseño no puede mostrar y el estudio que lo
# resolvería.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Léela en voz alta y corta cada palabra que te borra, reemplazándola por el límite exacto que
# estaba escondiendo. Después escribe completo un no-sé honesto, para la pregunta que más
# temes.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Regístralo en tu AI Research Ledger (registro de investigación con IA) y verifica al menos una
# respuesta preparada con un método nombrado de la [Guía de
# Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html), por ejemplo el razonamiento con pares. Un revisor de
# IA puede hacer la comprobación contigo; la decisión de aceptar o rechazar sigue siendo tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **12 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Escribe las cinco preguntas justas más difíciles que alguien podría hacerte, una por cada tipo: método, explicación alternativa, y-esto-para-qué,… | |
# | Paso 2 | Redacta una respuesta de dos frases para cada una y márcala como defender o conceder | |
# | Paso 3 | Escribe tu declaración de incertidumbre y limitaciones en forma ULN: cuánto podría oscilar tu número y por qué, la única cosa que tu diseño no puede… | |
# | Paso 4 | Léela en voz alta y corta cada palabra que te borra, reemplazándola por el límite exacto que estaba escondiendo | |
# | Paso 5 | Regístralo en tu AI Research Ledger (registro de investigación con IA) y verifica al menos una respuesta preparada con un método nombrado de la Guía… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 31 — Declaración de uso de IA e integridad de la investigación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/31-ai-disclosure-and-research-integrity.html).
