# %% [markdown]
# # Capítulo 31 — Declaración de uso de IA e integridad de la investigación
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 31 — Declaración de uso de IA e integridad de la investigación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/31-ai-disclosure-and-research-integrity.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Pertenece al libro, no a ningún curso: todo lo que necesitas es este cuaderno, el capítulo y Colab gratuito.
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part5-communicating/31-ai-disclosure-and-research-integrity.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.

# %% [markdown]
# > **La decisión de investigación.** Decide exactamente qué vas a decir sobre cada
# > herramienta de IA que usaste: cuál herramienta, en qué tarea y cómo comprobaste lo que
# > volvió. Después regístralo, para que cuando alguien pregunte *"¿usaste IA y cómo la
# > verificaste?"* respondas desde un registro comprobable y no desde la memoria.

# %% [markdown]
# ## Código del capítulo
#
# Las celdas de abajo vienen del capítulo. Córrelas, luego cambia algo y corre de nuevo — los números deben moverse como dice el capítulo.

# %% [markdown]
# *De la sección “Un ejemplo resuelto”.*

# %%
# The number the AI code reported, recomputed by hand.
operating_income = 276    # USD millions, confirmed against the annual report
interest_expense = 131    # USD millions, from the same annual report
coverage_ratio   = operating_income / interest_expense
print(round(coverage_ratio, 2))   # 2.11 — matches the AI-generated cell

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propia respuesta y después delega. Cada prompt es una tarea
# verificable, no una petición de veredicto.
#
# Corre el bucle y regístralo. Cada ronda es un prompt, una salida, una objeción y una nueva
# ejecución, y la fila del registro anota qué aceptaste finalmente y por qué. Eso importa aquí más
# que en ningún otro lugar del libro. Si una herramienta agéntica corrió diez rondas invisibles
# para producir tu párrafo, tu declaración igual tiene que describir solo aquello por lo que puedes
# responder personalmente.

# %% [markdown]
# **Localiza el estándar.**
#
# ```text
# Act as a research-integrity assistant. Name the elements a complete AI-use
# disclosure should contain for a research poster, and cite one real, retrievable
# source such as a university research-integrity office or a major publisher's AI
# policy. Only name a source you are confident exists.
# ```
# Después de ejecutarlo, verifica: abre la política citada y confirma que cada elemento nombrado
# está realmente en ella. Contrarresta la *fabricación confiada* (un elemento de política inventado
# llega con la misma seguridad que uno real).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Convierte tus notas en una tabla de declaración para verificar.**
#
# ```text
# Here are my raw notes on every time I used an AI tool on this project: [paste].
# Build a table with columns tool, task, and verification method, one row per use.
# Do not invent a verification I did not mention. If a use has no check, leave that
# cell blank and flag the row.
# ```
# Después de ejecutarlo, verifica: contrasta cada fila con tu registro; una verificación llenada
# donde tus notas no tenían ninguna es fabricada, así que elimínala. Contrarresta la *ilusión de
# exhaustividad* (una tabla ordenada que reporta en silencio comprobaciones que nunca hiciste).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Haz red team (revisión adversaria) a tu declaración.**
#
# ```text
# Here is my drafted AI-use disclosure: [paste]. Act as a hostile reviewer who
# suspects I am hiding a use or overstating my checks. Name every place I claim a
# verification I have not shown, or omit a use a reviewer would expect. Do not
# rewrite it for me.
# ```
# Después de ejecutarlo, verifica: para cada línea señalada, presenta la fila del registro que la
# respalda o borra la afirmación. Contrarresta la *adulación complaciente* (un revisor que elogia
# tu honestidad en lugar de ponerla a prueba).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > La honestidad de la declaración es solo tuya. Tú decides **qué usos declarar** (incluido el que
# > preferirías no mencionar), **si una verificación que afirmas de verdad ocurrió** y **si el
# > enunciado final es cierto**. Una herramienta puede dar formato a tu registro y convertirlo en un
# > párrafo limpio. No puede saber qué hiciste realmente ni certificar que lo comprobaste. Firmar con
# > tu nombre una declaración que no puedes respaldar es la falla de integridad que este capítulo
# > existe para prevenir.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Ya tienes respuestas listas para las preguntas más difíciles que la gente te hará; este paso
# escribe la que trata de la IA y la respalda con un registro.*

# %% [markdown]
# **Paso 1.** Lee tu AI Research Ledger de principio a fin y enumera cada uso, incluido el que preferirías no
# mencionar.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Para cada uso, escribe las tres partes que necesita una declaración: qué herramienta, para qué
# tarea y cómo verificaste el resultado. Un uso sin comprobación se queda en blanco. No lo
# llenes de memoria.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Convierte las filas en un enunciado breve con tus propias palabras, y después contrasta cada
# frase con una fila. Cualquier frase que afirme una comprobación que no puedes señalar se va.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Di lo que no verificaste. Nombrar el único dato asistido por IA que nunca confirmaste de manera
# independiente es lo que vuelve creíble el resto del enunciado.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Regístralo en tu AI Research Ledger y verifica el enunciado terminado con un método nombrado de
# la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html), por ejemplo el razonamiento con pares. Un
# revisor de IA puede hacer la comprobación contigo; la decisión de aceptar o rechazar sigue
# siendo tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **12 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Lee tu AI Research Ledger de principio a fin y enumera cada uso, incluido el que preferirías no mencionar | |
# | Paso 2 | Para cada uso, escribe las tres partes que necesita una declaración: qué herramienta, para qué tarea y cómo verificaste el resultado | |
# | Paso 3 | Convierte las filas en un enunciado breve con tus propias palabras, y después contrasta cada frase con una fila | |
# | Paso 4 | Di lo que no verificaste | |
# | Paso 5 | Regístralo en tu AI Research Ledger y verifica el enunciado terminado con un método nombrado de la Guía de Verificación, por ejemplo el razonamiento… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 32 — Replicación y reproducción](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part6-after-conference/32-replication-and-reproduction.html).
