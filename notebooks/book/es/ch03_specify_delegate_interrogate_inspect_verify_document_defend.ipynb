# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 3 — Especificar, Delegar, Interrogar, Inspeccionar, Verificar, Documentar, Defender
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 3 — Especificar, Delegar, Interrogar, Inspeccionar, Verificar, Documentar, Defender](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part1-research-with-ai/03-specify-delegate-interrogate-inspect-verify-document-defend.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Escrito por [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html).
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part1-research-with-ai/03-specify-delegate-interrogate-inspect-verify-document-defend.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.
# 6. Tu IA puede ser más que un chatbot: las herramientas agénticas ejecutan trabajo de varios pasos por ti. Delegar con audacia está bien; revisar, curar y decidir siguen siendo tuyos.

# %% [markdown]
# > **La decisión de investigación.** Cada vez que le entregas trabajo a una herramienta
# > de IA, decides cómo se enruta ese trabajo: qué fijas antes de preguntar, qué abres y
# > lees cuando vuelve la respuesta, y qué estás dispuesta o dispuesto a decir con tus
# > propias palabras al final. Tu decisión en este capítulo es dejar de improvisar esa
# > ruta y correr la misma lista de control de siete pasos siempre.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propia respuesta y después delega. Cada prompt de abajo es
# un encargo revisable, no una petición de veredicto, y cada uno es el movimiento de
# apertura de un bucle, no la conversación entera.

# %% [markdown]
# **Localizar el método estándar.**
#
# ```text
# Act as a business-analytics assistant. I need to compare conversion rates for two
# versions of a checkout page. Before any code, name the standard statistical test
# for comparing two proportions and the exact library function that implements it,
# citing the official documentation section. Only name functions you are confident
# exist.
# ```
# Después de ejecutarlo, verifica: abre la documentación oficial y confirma que la
# función y sus valores por defecto existen. Contrarresta la *fabricación confiada* (un
# nombre de función inventado llega con la misma seguridad que uno real).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Delegar, con una lista de control para verificar.**
#
# ```text
# Write the script that computes the conversion rate for version A and version B
# from this session log. Then return a table of every assumption your calculation
# makes: which sessions are included and excluded, how you count a purchase, whether
# both versions ran over the same days, and how repeat visits are handled.
# ```
# Después de ejecutarlo, verifica: recalcula a mano la tasa de una versión para un solo
# día y revisa que coincida. Contrarresta el *método plausible pero equivocado* (un
# cálculo que en silencio compara condiciones desiguales).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Hacerle red team (revisión adversaria) a tu aumento.**
#
# ```text
# Here is my claim: "the new checkout page converts about 6 percent better."
# Act as a hostile reviewer. Name every way this comparison could be unfair or this
# number could mislead. Do not rewrite the claim for me.
# ```
# Después de ejecutarlo, verifica: si solo elogia la afirmación, insiste y exige el peor
# defecto, uno solo. Contrarresta el *acuerdo complaciente* (elogio que revisa tu ego,
# no tu evidencia).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Especificar y Defender nunca salen de tus manos. Tú decides **qué pregunta responde la
# > comparación**, **qué cuenta como una comparación justa** y **si los datos detrás de
# > ella son honestos** para la afirmación que quieres hacer. Eres dueña o dueño de la
# > oración final, de su límite y de su incertidumbre. La herramienta puede calcular las
# > tasas, pero no puede decidir que la prueba fue justa ni que la afirmación se ganó.
# > Esas son tuyas.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Ya tienes una lista de tareas que dice qué estás dispuesta o dispuesto a delegar.
# Ahora delegas algo real, y mantienes el mando desde la primera palabra hasta la
# última.*

# %% [markdown]
# **Paso 1.** Elige una afirmación genuina y revisable de tu propia área: una tasa, un total, una
# comparación, cualquier cosa que una fuente o un cálculo pudieran zanjar. Escríbela
# como una sola oración.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** **Especificar.** Antes de abrir ninguna herramienta, escribe tu propia respuesta
# esperada y cómo se vería una manera justa de obtenerla.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** **Delegar, Interrogar, Inspeccionar.** Entrega la tarea. Pregúntale a la salida qué
# supone. Después abre lo que produjo de verdad, la fuente o el código o la tabla, en
# lugar de su resumen de sí misma. Espera varias pasadas por ese bucle, y anota qué
# cambió en cada una.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** **Verificar.** Corre una revisión independiente. Si la revisión y la salida no
# coinciden, no las promedies; averigua cuál está equivocada.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** **Defender.** Con la herramienta cerrada, escribe una oración que enuncie el
# resultado con tus propias palabras, y una oración que nombre qué no establece.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** **Documenta** la corrida completa en tu AI Research Ledger (tu registro de
# investigación con IA), nombrando el método de verificación que usaste de la
# [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html) y el paso donde atrapaste algo que
# la herramienta hizo mal. Una IA revisora puede correr la revisión contigo; la
# decisión de aceptar o rechazar sigue siendo tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **14 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Elige una afirmación genuina y revisable de tu propia área: una tasa, un total, una comparación, cualquier cosa que una fuente o un cálculo pudieran… | |
# | Paso 2 | **Especificar.** Antes de abrir ninguna herramienta, escribe tu propia respuesta esperada y cómo se vería una manera justa de obtenerla | |
# | Paso 3 | **Delegar, Interrogar, Inspeccionar.** Entrega la tarea | |
# | Paso 4 | **Verificar.** Corre una revisión independiente | |
# | Paso 5 | **Defender.** Con la herramienta cerrada, escribe una oración que enuncie el resultado con tus propias palabras, y una oración que nombre qué no… | |
# | Paso 6 | **Documenta** la corrida completa en tu AI Research Ledger (tu registro de investigación con IA), nombrando el método de verificación que usaste de… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 4 — Responsabilidad en la investigación y autoría intelectual](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part1-research-with-ai/04-research-responsibility-and-intellectual-ownership.html).
