# %% [markdown]
# # Capítulo 7 — La investigación se construye sobre la investigación
#
# Este es el **cuaderno de acompañamiento** del [Capítulo 7 — La investigación se construye sobre la investigación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/07-research-builds-on-research.html) de **EDR|AI — Investigación Guiada por la Evidencia en la Era de la IA**. Pertenece al libro, no a ningún curso: todo lo que necesitas es este cuaderno, el capítulo y Colab gratuito.
#
# [Abrir el capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/07-research-builds-on-research.html) · [Inicio del libro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html) · [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html)
#
# *La IA es tu brazo y tu asistente de investigación, no tu cerebro.*

# %% [markdown]
# ## Cómo usar este cuaderno
#
# 1. Trabaja de arriba hacia abajo, con el capítulo abierto en otra pestaña.
# 2. Copia cada **prompt de IA** en tu herramienta de IA, córrelo, y registra en la celda de respuesta qué volvió y qué verificaste.
# 3. Corre las celdas de código; cambia algo y corre de nuevo.
# 4. Termina el espacio de trabajo **Ahora te toca a ti** del final — es el paso de este capítulo en tu propio proyecto de investigación.
# 5. Registra cada uso de IA en tu **AI Research Ledger**: tarea · herramienta · prompt · resumen del resultado · decisión · método de verificación · preocupación restante · tú como responsable de la investigación.

# %% [markdown]
# > **La decisión de investigación.** A qué conversación se suma tu pregunta, y cuáles
# > de las fuentes candidatas que te entrega una búsqueda o una IA valen la pena
# > perseguir. Tú decides qué entra en la lista y qué se descarta. Nada de esa lista
# > cuenta todavía como evidencia.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprométete primero con tu propia respuesta y solo después delega. Y no trates estos
# prompts como pedidos de un solo tiro. Una búsqueda es un **bucle de IA**: el ciclo
# prompt → respuesta → interrogación → refinamiento → nueva ejecución. Escribes el
# prompt, lees lo que volvió, le dices a la herramienta qué quedó fuera de blanco y por
# qué, y vuelves a preguntar. Dos o tres pasadas le ganan siempre a un prompt largo.
# Algunas herramientas ya corren ese bucle solas: navegan y vuelven a buscar sin
# consultarte entre paso y paso. Eso cambia quién escribe las consultas; no cambia quién
# abre los artículos. Cada pasada te gana una mejor lista. Ninguna se gana tu confianza.

# %% [markdown]
# **Localizar.** Pide pistas que perseguir, no una bibliografía terminada.
#
# ```text
# Act as a literature scout in [your field]. My question is: [paste it].
# List the five published studies most relevant to it, each with authors,
# year, exact title, and venue, so I can retrieve and verify each myself.
# Only include work you are confident exists; mark anything uncertain.
# ```
#
# *Después de ejecutarlo, verifica:* recupera cada cita buscando su título exacto entre
# comillas antes de creer que existe. Contrarresta la **fabricación confiada**
# (*confident fabrication*), una cita que suena real de un artículo que nunca se
# escribió.

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Listar para verificar (bola de nieve).** Parte de una fuente que ya hayas leído.
#
# ```text
# Here is one source I have verified: [authors, year, exact title, venue].
# Name three older works from its reference list it likely built on, and
# three newer works that likely cite it, each with authors, year, title,
# and venue, plus one line on why it belongs on the chain.
# ```
#
# *Después de ejecutarlo, verifica:* contrasta los nombres «hacia atrás» con la lista de
# referencias real de la fuente semilla y recupera el resto. Una cadena ordenada puede
# omitir en silencio el único estudio que contradice. Contrarresta la **ilusión de
# exhaustividad** (*illusion of completeness*).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# **Red team (revisión adversaria).** Haz que la herramienta ataque tu vacío en vez de
# halagarlo.
#
# ```text
# Here is my question and the gap I placed: [one or two sentences].
# Argue that this gap is NOT real. Name up to three published studies that
# may already answer it, with authors, year, title, and venue, and say what
# each would have to show to close it. Do not reassure me.
# ```
#
# *Después de ejecutarlo, verifica:* si solo coincide en que el vacío está abierto y no
# nombra nada, insiste y oblígala a intentar cerrarlo; luego recupera cada estudio que
# mencione. Contrarresta el **acuerdo complaciente** (*sycophantic agreement*).

# %% [markdown]
# ✍️ **Tu registro.** Haz doble clic en esta celda y anota: qué devolvió la IA (una o dos líneas), qué verificaste y cómo, y tu fila del ledger.

# %% [markdown]
# > **No delegues.**
# >
# > Dos decisiones nunca salen de tus manos. Si una fuente cuenta como **verificada**: eso
# > solo lo zanja leerla por tu cuenta. Y si tu **vacío es real**: solo una recuperación
# > que vuelve vacía se gana esa palabra. Lo que tu proyecto puede afirmar se desprende de
# > esas dos. Una IA puede señalar; no puede certificar.

# %% [markdown]
# ## Ahora te toca a ti
#
# *Llegaste con una pregunta guía del capítulo anterior. Este paso la rodea de la
# conversación a la que pertenece: un conjunto de fuentes candidatas, reunidas rápido,
# con la IA haciendo el trabajo de campo.*

# %% [markdown]
# **Paso 1.** Escribe tu pregunta guía al inicio de una hoja en blanco. Debajo, escribe la única
# oración que ya crees que dice la literatura. Esa creencia es lo que tu búsqueda va
# a confirmar o a dejar en ridículo.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 1.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 2.** Busca una vez por tu cuenta antes de delegar. Usa la base de datos de tu biblioteca
# o Google Scholar con las palabras de tu propia pregunta, y quédate con lo mejor que
# encuentres. Esa es tu semilla.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 2.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 3.** Pídele a una IA cinco candidatas más sobre la misma pregunta, cada una con autoría,
# año, título exacto y lugar de publicación. Luego corre el bucle: lee lo que volvió,
# dile a la herramienta cuáles dos están fuera de blanco y por qué, y vuelve a
# preguntar. Detente cuando una pasada deje de agregar algo nuevo.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 3.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 4.** Aplica la bola de nieve a tu semilla a mano. Lee su lista de referencias hacia
# atrás para hallar los trabajos más antiguos en los que se apoya, y sigue su rastro
# de «Citado por» hacia adelante para los más nuevos. Agrega todo lo que toque tu
# pregunta.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 4.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 5.** Pon todo en una sola lista de candidatas con una columna de estado, y escribe
# `lead` en cada fila. Aquí todavía nada es una fuente. El capítulo siguiente es
# donde se ganan el ascenso.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 5.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# **Paso 6.** Registra la delegación en tu AI Research Ledger (registro de investigación con IA)
# y verifica al menos una candidata ahora con un método nombrado de la
# [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html); la lectura de la fuente
# primaria es el que corresponde. Una IA revisora puede hacer la comprobación contigo; la decisión
# de aceptar o rechazar es tuya.

# %% [markdown]
# ✍️ **Tu trabajo en el paso 6.** Haz doble clic en esta celda y escribe tu respuesta aquí.

# %% [markdown]
# ### Cómo se califica esta sección
#
# Cada fila vale **0** (ausente), **1** (intentada pero incompleta, genérica o sin verificar) o **2** (completa, específica de tu propio proyecto y verificada donde aplique una comprobación). **14 puntos en total.**
#
# | # | Criterio | 0–2 |
# |---|---|---|
# | Paso 1 | Escribe tu pregunta guía al inicio de una hoja en blanco | |
# | Paso 2 | Busca una vez por tu cuenta antes de delegar | |
# | Paso 3 | Pídele a una IA cinco candidatas más sobre la misma pregunta, cada una con autoría, año, título exacto y lugar de publicación | |
# | Paso 4 | Aplica la bola de nieve a tu semilla a mano | |
# | Paso 5 | Pon todo en una sola lista de candidatas con una columna de estado, y escribe `lead` en cada fila | |
# | Paso 6 | Registra la delegación en tu AI Research Ledger (registro de investigación con IA) y verifica al menos una candidata ahora con un método nombrado de… | |
# | + | Cuidado y registro de verificación: uso de IA registrado en tu AI Research Ledger, afirmaciones declaradas con su incertidumbre, y cada afirmación clave verificada con un método nombrado | |

# %%
# Espacio de borrador — usa esta celda para cualquier código que necesiten los pasos.

# %% [markdown]
# **Antes de salir de este cuaderno:** agrega las filas de hoy a tu AI Research Ledger, y verifica tu afirmación principal con un método nombrado de la [Guía de Verificación](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/verification-guide.html). La IA puede revisar a la IA — pero la última decisión es humana.
#
# Siguiente: [Capítulo 8 — Encontrar y verificar la evidencia previa](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/part2-curiosity-to-design/08-finding-and-verifying-prior-evidence.html).
