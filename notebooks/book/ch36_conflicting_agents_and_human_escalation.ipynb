# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Chapter 37 — Conflicting Agents and Human Escalation
#
# This is the **companion notebook** of [Chapter 37 — Conflicting Agents and Human Escalation](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part6-after-conference/36-conflicting-agents-and-human-escalation.html) from **EDR|AI — Evidence-Driven Research in the Age of AI**. Authored by [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html).
#
# [Open the chapter](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part6-after-conference/36-conflicting-agents-and-human-escalation.html) · [Book home](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html) · [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html)
#
# *AI is your arm and your research assistant, not your brain.*

# %% [markdown]
# ## How to use this notebook
#
# 1. Work top to bottom, with the chapter open in another tab.
# 2. Copy each **AI prompt** into your AI tool, run it, then record in the response cell what came back and what you verified.
# 3. Run the code cells; change something and run again.
# 4. Finish the **It is your turn** workspace at the end — that is this chapter's step of your own research project.
# 5. Log every AI use in your **AI Research Ledger**: task · tool · prompt · output summary · decision · verification method · remaining concern · you as the responsible researcher.
# 6. Your AI can be more than a chatbot: agentic tools can run multi-step work for you. Delegating boldly is fine; reviewing, curating, and deciding stay yours.

# %% [markdown]
# > **The research decision.** Your loops have come back and they do not match, or they
# > match a little too well. You decide which of three things you are looking at (real
# > disagreement, correlated error, or manufactured consensus), and you decide the exact
# > moment to stop the loops and take the call into your own hands.

# %% [markdown]
# ## Recommended AI prompts

# %% [markdown]
# Commit your own diagnosis first, then delegate. Each prompt starts a loop, and with
# several loops in play the discipline is the same as with one: read the output,
# interrogate it, refine, run again, and never let a loop close a question that belongs
# to you. Each prompt is a checkable job, not a request for a verdict.

# %% [markdown]
# **Locate the decisions that must escalate.**
#
# ```text
# Act as a research-integrity assistant. Here is my draft's headline claim and the three
# never-delegate decisions I think it contains: [paste]. Using standard research-defense
# criteria, list which decisions in this draft an AI output should never be allowed to
# settle, and which of my three I mislabeled. Do not settle any of them for me.
# ```
# After running, verify: check its list against the escalation triggers you wrote
# yourself; a decision it omits is the one to guard hardest. Counters *illusion of
# completeness* (a tidy list that quietly drops the call that matters most).

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **List the agreements to verify.**
#
# ```text
# Here are three reviewer outputs on the same draft: [paste all three]. For each pair,
# name one specific way they could be wrong the SAME way: a shared assumption, a shared
# anchor, or a shared prompt. Rank the pairs from most to least likely to share a blind
# spot.
# ```
# After running, verify: for the top pair, rerun one role with a different framing and
# different context and see whether the agreement survives. Counters *correlated errors
# across tools or roles* (agreement that is one flaw echoed back).

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **Red-team the consensus.**
#
# ```text
# Act as a hostile reviewer who believes my three roles only agreed because my prompt led
# them. Argue that their consensus is manufactured, name the leading words in my original
# ask, and give me a neutral rewrite. Do not reassure me.
# ```
# After running, verify: if it cannot find a single leading word, push back and demand the
# worst one, then rerun the review neutrally. Counters *sycophantic agreement* (praise
# that rehearses your ego, not your evidence).

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# > **Do not delegate.**
# >
# > Which claims your draft can defend, where each claim must stop, whether an agreement
# > among your roles was ever independent, and the moment to escalate: those stay yours. No
# > role decides its own trustworthiness, and no head-count of roles decides your claim
# > boundary or your ethics. When an AI output would *settle* one of those rather than
# > inform it, you stop and you decide.

# %% [markdown]
# ## It is your turn
#
# *Your project already has a small AI team running on one section; this step decides in
# advance where those loops must stop and hand the call back to you.*

# %% [markdown]
# **Step 1.** Write your escalation rules before the next round starts. List the specific
# decisions no loop may close: your claim boundary, your uncertainty, which sources
# are real, what counts as done, and anything with an ethical edge. Keep the list
# short enough to remember under pressure.

# %% [markdown]
# ✍️ **Your work for step 1.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 2.** Add the stopping conditions that are not about content. How many turns a loop may
# run before you read it, and what an agentic tool is allowed to change without
# asking you first.

# %% [markdown]
# ✍️ **Your work for step 2.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 3.** Find one real disagreement in what your roles have already returned, and diagnose
# it on the record: real disagreement, correlated error, or a consensus your own
# prompt manufactured. Say which and why.

# %% [markdown]
# ✍️ **Your work for step 3.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 4.** Resolve it yourself with a check the loops cannot run: recompute the number, open
# the source, or compare against a figure that was never in any prompt. Write the
# resolution and the check together, because one without the other is just an
# opinion.

# %% [markdown]
# ✍️ **Your work for step 4.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 5.** Take one place your roles agreed on something that mattered and test whether the
# agreement was independent. Rerun one of them with a different framing and different
# context, or verify the point yourself outside the tools.

# %% [markdown]
# ✍️ **Your work for step 5.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 6.** Log the conflict, the diagnosis, and the override in your AI Research Ledger, and
# verify at least one output with a named method from the
# [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html). An AI reviewer may run the check
# with you; the decision to accept or reject stays yours.

# %% [markdown]
# ✍️ **Your work for step 6.** Double-click this cell and write your answer here.

# %% [markdown]
# ### How this section is graded
#
# Each row scores **0** (missing), **1** (attempted but incomplete, generic, or unverified), or **2** (complete, specific to your own project, and verified where a check applies). **14 points total.**
#
# | # | Criterion | 0–2 |
# |---|---|---|
# | Step 1 | Write your escalation rules before the next round starts | |
# | Step 2 | Add the stopping conditions that are not about content | |
# | Step 3 | Find one real disagreement in what your roles have already returned, and diagnose it on the record: real disagreement, correlated error, or a… | |
# | Step 4 | Resolve it yourself with a check the loops cannot run: recompute the number, open the source, or compare against a figure that was never in any prompt | |
# | Step 5 | Take one place your roles agreed on something that mattered and test whether the agreement was independent | |
# | Step 6 | Log the conflict, the diagnosis, and the override in your AI Research Ledger, and verify at least one output with a named method from the… | |
# | + | Craft and verification record: AI use logged in your AI Research Ledger, claims stated with their uncertainty, and each key claim verified with a named method | |

# %%
# Scratch space — use this cell for any code your steps need.

# %% [markdown]
# **Before you leave this notebook:** add today's rows to your AI Research Ledger, and verify your key claim with a named method from the [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html). AI can review AI — but the last decision is human.
#
# Next: [Chapter 38 — Final Research and AI-Management Portfolio](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part6-after-conference/37-final-research-and-ai-management-portfolio.html).
