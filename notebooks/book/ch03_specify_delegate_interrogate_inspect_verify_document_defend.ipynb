# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Chapter 3 — Specify, Delegate, Interrogate, Inspect, Verify, Document, Defend
#
# This is the **companion notebook** of [Chapter 3 — Specify, Delegate, Interrogate, Inspect, Verify, Document, Defend](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part1-research-with-ai/03-specify-delegate-interrogate-inspect-verify-document-defend.html) from **EDR|AI — Evidence-Driven Research in the Age of AI**. Authored by [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html).
#
# [Open the chapter](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part1-research-with-ai/03-specify-delegate-interrogate-inspect-verify-document-defend.html) · [Book home](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html) · [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html)
#
# *AI is your arm and your research assistant, not your brain.*

# %% [markdown]
# ## How to use this notebook
#
# 1. Work top to bottom, with the chapter open in another tab.
# 2. Copy each **AI prompt** into your AI tool, run it, then record in the response cell what came back and what you verified.
# 3. Run the code cells; change something and run again.
# 4. Finish the **It is your turn** workspace at the end — that is this chapter's step of your own research project.
# 5. Log every AI use in your **AI Research Ledger**: task · tool · prompt · output summary · decision · verification method · remaining concern · you as the responsible researcher.
# 6. Your AI can be more than a chatbot: agentic tools can run multi-step work for you. Delegating boldly is fine; reviewing, curating, and deciding stay yours.

# %% [markdown]
# > **The research decision.** Every time you hand work to an AI tool, you decide how
# > that work gets routed: what you pin down before you ask, what you open and read when
# > the answer comes back, and what you are willing to say in your own words at the end.
# > Your decision in this chapter is to stop improvising that route and run the same
# > seven-step checklist every time.

# %% [markdown]
# ## Recommended AI prompts

# %% [markdown]
# Commit your own answer first, then delegate. Each prompt below is a checkable job,
# not a request for a verdict, and each is the opening move of a loop rather than the
# whole conversation.

# %% [markdown]
# **Locate the standard method.**
#
# ```text
# Act as a business-analytics assistant. I need to compare conversion rates for two
# versions of a checkout page. Before any code, name the standard statistical test
# for comparing two proportions and the exact library function that implements it,
# citing the official documentation section. Only name functions you are confident
# exist.
# ```
# After running, verify: open the official docs and confirm the function and its
# defaults exist. Counters *confident fabrication* (an invented function name arrives
# as confidently as a real one).

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **Delegate, with a checklist to verify.**
#
# ```text
# Write the script that computes the conversion rate for version A and version B
# from this session log. Then return a table of every assumption your calculation
# makes: which sessions are included and excluded, how you count a purchase, whether
# both versions ran over the same days, and how repeat visits are handled.
# ```
# After running, verify: recompute one version's rate for a single day by hand and check
# that it matches. Counters *plausible-but-wrong-method* (a calculation that quietly
# compares unequal conditions).

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **Red-team your lift.**
#
# ```text
# Here is my claim: "the new checkout page converts about 6 percent better."
# Act as a hostile reviewer. Name every way this comparison could be unfair or this
# number could mislead. Do not rewrite the claim for me.
# ```
# After running, verify: if it only praises the claim, push back and demand the single
# worst flaw. Counters *sycophantic agreement* (praise that reviews your ego, not your
# evidence).

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# > **Do not delegate.**
# >
# > Specify and Defend never leave your hands. You decide **what question the comparison
# > answers**, **what counts as a fair comparison**, and **whether the data behind it is
# > honest** for the claim you want to make. You own the final sentence, its boundary, and
# > its uncertainty. The tool can compute the rates, but it cannot decide the test was
# > fair or the claim was earned. Those are yours.

# %% [markdown]
# ## It is your turn
#
# <!-- station-pointer:begin -->
# > **You are working inside [Studio 1: Govern the work](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/studios/studio01-govern-the-work.html).**
# > Keep what you write here; the studio is where it joins the
# > other lessons' pieces into one artifact you can defend.
# <!-- station-pointer:end -->
#
# *You have a task list that says what you are willing to delegate. Now you delegate
# something real, and keep command of it from the first word to the last.*

# %% [markdown]
# **Step 1.** Pick one genuine, checkable claim in your own area: a rate, a total, a comparison,
# anything a source or a calculation could settle. Write it as a single sentence.

# %% [markdown]
# ✍️ **Your work for step 1.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 2.** **Specify.** Before you open any tool, write your own expected answer and what a
# fair way of getting it would look like.

# %% [markdown]
# ✍️ **Your work for step 2.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 3.** **Delegate, Interrogate, Inspect.** Hand the task over. Ask the output what it
# assumes. Then open what it actually produced, the source or the code or the table,
# rather than its summary of itself. Expect several passes around that loop, and note
# what changed on each one.

# %% [markdown]
# ✍️ **Your work for step 3.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 4.** **Verify.** Run one independent check. If the check and the output disagree, do not
# average them; find out which one is wrong.

# %% [markdown]
# ✍️ **Your work for step 4.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 5.** **Defend.** With the tool closed, write one sentence stating the result in your own
# words, and one sentence naming what it does not establish.

# %% [markdown]
# ✍️ **Your work for step 5.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 6.** **Document** the whole run in your AI Research Ledger, naming the verification
# method you used from the [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html) and the
# step where you caught something the tool got wrong. An AI reviewer may run the check
# with you; the decision to accept or reject stays yours.

# %% [markdown]
# ✍️ **Your work for step 6.** Double-click this cell and write your answer here.

# %% [markdown]
# ### How this section is graded
#
# Each row scores **0** (missing), **1** (attempted but incomplete, generic, or unverified), or **2** (complete, specific to your own project, and verified where a check applies). **14 points total.**
#
# | # | Criterion | 0–2 |
# |---|---|---|
# | Step 1 | Pick one genuine, checkable claim in your own area: a rate, a total, a comparison, anything a source or a calculation could settle | |
# | Step 2 | **Specify.** Before you open any tool, write your own expected answer and what a fair way of getting it would look like | |
# | Step 3 | **Delegate, Interrogate, Inspect.** Hand the task over | |
# | Step 4 | **Verify.** Run one independent check | |
# | Step 5 | **Defend.** With the tool closed, write one sentence stating the result in your own words, and one sentence naming what it does not establish | |
# | Step 6 | **Document** the whole run in your AI Research Ledger, naming the verification method you used from the Verification Guide and the step where you… | |
# | + | Craft and verification record: AI use logged in your AI Research Ledger, claims stated with their uncertainty, and each key claim verified with a named method | |

# %%
# Scratch space — use this cell for any code your steps need.

# %% [markdown]
# **Before you leave this notebook:** add today's rows to your AI Research Ledger, and verify your key claim with a named method from the [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html). AI can review AI — but the last decision is human.
#
# Next: [Chapter 4 — Research Responsibility and Intellectual Ownership](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part1-research-with-ai/04-research-responsibility-and-intellectual-ownership.html).
