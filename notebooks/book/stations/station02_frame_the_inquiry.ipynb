# %% [markdown]
# # Station 2: Frame the inquiry
#
# **What you can defend when you leave.** Turn a curiosity into a question whose answer you could recognize, and say what kind of answer it would be.
#
# **This station produces.** An objective, your units, outcomes and conditions, your target and reach, and a provisional claim boundary.
#
# A checkpoint is a *version*, not a pass. Date it, number it, and write why this version exists.

# %% [markdown]
# ## Step 1
#
# State your objective in one sentence a stranger could repeat back.

# %% [markdown]
# ✍️ **Your work for step 1.** Double-click this cell and write your answer here.

# %% [markdown]
# ## Step 2
#
# Name your units, your outcome, and the conditions you are comparing or describing.

# %% [markdown]
# ✍️ **Your work for step 2.** Double-click this cell and write your answer here.

# %% [markdown]
# ## Step 3
#
# Declare kind and reach, and write the words in your question that fix each one.

# %% [markdown]
# ✍️ **Your work for step 3.** Double-click this cell and write your answer here.

# %% [markdown]
# ## Step 4
#
# {'Write your provisional claim boundary': 'the sentence you hope to defend, and the sentence you will not be able to.'}

# %% [markdown]
# ✍️ **Your work for step 4.** Double-click this cell and write your answer here.

# %%
# Scratch space — any code this station's steps need.

# %% [markdown]
# ## Write your checkpoint version
#
# Checkpoint: `question-declared-v0`
#
# Record: the version number, today's date, what this version says, and **why it differs from the previous one**. A first version says why you are starting here.

# %% [markdown]
# ✍️ **Checkpoint version.** Double-click and write it here.

# %% [markdown]
# ## Before you leave
#
# Add this station's rows to your **AI Research Ledger** — task, tool, prompt, output summary, decision, verification method, remaining concern, and you as the responsible researcher — and file the artifact above in your **Research Dossier**.
