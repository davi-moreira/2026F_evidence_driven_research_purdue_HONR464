# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 30 — Perguntas Difíceis e Incerteza
#
# Este é o **notebook companheiro** do [Capítulo 30 — Perguntas Difíceis e Incerteza](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part5-communicating/30-difficult-questions-and-uncertainty.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. De autoria de [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html).
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part5-communicating/30-difficult-questions-and-uncertainty.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.
# 6. A sua IA pode ser mais do que um chatbot: ferramentas agênticas executam trabalho de várias etapas para você. Delegar com ousadia é bom; revisar, fazer a curadoria e decidir continuam com você.

# %% [markdown]
# > **A decisão de pesquisa.** Decida, antes de alguém perguntar, como você vai dizer o
# > que o seu estudo não consegue mostrar. Você escreve a incerteza, os limites e as
# > respostas às perguntas justas mais difíceis com antecedência, para que a versão que
# > sai da sua boca sob pressão seja a que você escolheu, e não a que a adrenalina
# > escreveu. Você prepara essa resposta; você nunca a improvisa.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se primeiro com a sua própria resposta e só depois delegue. Cada prompt
# abaixo é uma tarefa verificável, não um pedido de aprovação.
#
# Estes funcionam melhor como conversa. Pergunte, leia, depois nomeie o que a resposta
# evitou e pergunte de novo. Um banco de perguntas construído em três voltas é
# visivelmente mais duro do que um construído numa passada só. Quando uma ferramenta roda
# essas voltas sozinha, as perguntas chegam já polidas, e é por isso que você confronta a
# lista com a pergunta que de fato te dá medo, e não o contrário.

# %% [markdown]
# **Liste as suas perguntas mais difíceis, para verificar contra o seu próprio medo.**
#
# ```text
# Play a skeptical but fair conference visitor. My project: "[one-paragraph summary
# of question, design, and headline finding]". Write the single hardest FAIR question
# for each type: method, alternative explanation, why-it-matters, generalization,
# AI-use. For each, flag whether an honest two-sentence answer exists.
# ```
# Depois de rodar, verifique: compare as cinco com a única pergunta que você anotou como a
# que mais teme. Se ela estiver faltando, o conjunto não está completo. Neutraliza a
# *ilusão de completude* (um conjunto arrumadinho de cinco que omite exatamente a pergunta
# que você teme).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Force a incerteza para fora.**
#
# ```text
# Here is my headline number and how I got it: "[paste]". Do not restate it.
# List what is missing before I can state its uncertainty honestly: the sample
# size, the source of wobble, and the one limitation a reviewer would raise first.
# ```
# Depois de rodar, verifique: confirme cada item contra os seus próprios dados antes de
# falá-lo. Neutraliza a *incerteza ausente* (um número limpo relatado sem nenhum limite).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Faça red team na sua resposta.**
#
# ```text
# Here is my two-sentence reply to "does it cause it?": "[paste]". Act as a hostile
# reviewer. Name every word that still claims more than an association supports.
# Do not rewrite it for me.
# ```
# Depois de rodar, verifique: se ela só elogiar a resposta, insista e exija a pior
# palavra, uma só. Neutraliza a *concordância bajuladora* (elogio que revisa o seu ego,
# não a sua evidência).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > Três decisões nunca saem das suas mãos: **qual alegação a sua evidência de fato
# > sustenta**, **onde essa alegação precisa parar** e **como você reconhece a incerteza e
# > as limitações dela**. A ferramenta pode rascunhar uma pergunta ou sinalizar uma palavra,
# > mas só você decide a posição na bússola que o seu desenho aguenta e a palavra que você
# > precisa recusar em voz alta. O seu "não sei" honesto é seu para dizer com convicção, não
# > para recitar.

# %% [markdown]
# ## Agora é a sua vez
#
# *Você já consegue dizer a sua alegação em dois tamanhos; este passo prepara a parte da
# conversa que você não controla.*

# %% [markdown]
# **Passo 1.** Escreva as cinco perguntas justas mais difíceis que alguém poderia te fazer, uma para
# cada tipo: método, explicação alternativa, e-daí, generalização, uso de IA.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** Rascunhe uma resposta de duas frases para cada uma e marque-a como defender ou
# conceder. Uma resposta de conceder nomeia a alegação mais estreita para a qual você
# recuaria ali mesmo.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** Escreva a sua declaração de incerteza e limitações em forma ULN: o quanto o seu
# número pode oscilar e por quê, a única coisa que o seu desenho não consegue mostrar e
# o estudo que resolveria a questão.

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** Leia em voz alta e corte toda palavra de autoapagamento, substituindo cada uma pela
# fronteira exata que ela estava escondendo. Depois escreva por inteiro um "não sei"
# honesto, para a pergunta que você mais teme.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** Registre isso no seu AI Research Ledger (registro de uso de IA) e verifique pelo
# menos uma resposta preparada com um método nomeado do
# [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html), como o raciocínio com pares. Uma IA
# revisora pode fazer a checagem junto com você; a decisão de aceitar ou rejeitar
# continua sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **12 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Escreva as cinco perguntas justas mais difíceis que alguém poderia te fazer, uma para cada tipo: método, explicação alternativa, e-daí,… | |
# | Passo 2 | Rascunhe uma resposta de duas frases para cada uma e marque-a como defender ou conceder | |
# | Passo 3 | Escreva a sua declaração de incerteza e limitações em forma ULN: o quanto o seu número pode oscilar e por quê, a única coisa que o seu desenho não… | |
# | Passo 4 | Leia em voz alta e corte toda palavra de autoapagamento, substituindo cada uma pela fronteira exata que ela estava escondendo | |
# | Passo 5 | Registre isso no seu AI Research Ledger (registro de uso de IA) e verifique pelo menos uma resposta preparada com um método nomeado do Guia de… | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# A seguir: [Capítulo 31 — Declaração de Uso de IA e Integridade em Pesquisa](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part5-communicating/31-ai-disclosure-and-research-integrity.html).
