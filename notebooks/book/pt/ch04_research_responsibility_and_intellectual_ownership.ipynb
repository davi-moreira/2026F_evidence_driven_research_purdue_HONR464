# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 4 — Responsabilidade na Pesquisa e Propriedade Intelectual
#
# Este é o **notebook companheiro** do [Capítulo 4 — Responsabilidade na Pesquisa e Propriedade Intelectual](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part1-research-with-ai/04-research-responsibility-and-intellectual-ownership.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. De autoria de [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html).
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part1-research-with-ai/04-research-responsibility-and-intellectual-ownership.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.
# 6. A sua IA pode ser mais do que um chatbot: ferramentas agênticas executam trabalho de várias etapas para você. Delegar com ousadia é bom; revisar, fazer a curadoria e decidir continuam com você.

# %% [markdown]
# > **A decisão de pesquisa.** Para cada frase que uma IA ajudou a produzir, você
# > decide duas coisas: se você vai pessoalmente sustentá-la como sua, e o que a sua
# > declaração vai dizer sobre como ela surgiu. O seu nome no trabalho significa que
# > você responde por ele, seja qual for a ferramenta que ajudou.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se primeiro com a sua própria resposta, e só então delegue. Cada prompt
# abaixo entrega à ferramenta alcance, não julgamento.

# %% [markdown]
# **Localize a fonte real.**
#
# ```
# Act as a research assistant in freshwater ecology. I need the current U.S. EPA
# aquatic-life criterion for chloride. Give the exact value, the document it comes
# from, and a link. Only state a figure you are confident is published; if you are
# unsure, say so and tell me where to look.
# ```
#
# Depois de rodar, verifique: abra o documento da EPA e leia o número você mesmo
# (leitura da fonte primária). Combate a **fabricação confiante**, um número citado
# com uma fonte inventada.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Liste toda alegação a verificar.**
#
# ```
# Here is my draft results paragraph: [paste]. List every empirical claim in it as a
# table: the claim, the number or source it rests on, and whether that number came from
# my data or from you. Do not add any new claims.
# ```
#
# Depois de rodar, verifique: confira a tabela contra a sua própria lista do que você
# de fato mediu. Combate a **ilusão de completude**, uma alegação que o rascunho
# enfiou no texto e que não aparece na prestação de contas da própria ferramenta.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Faça o red team (revisão adversária) da sua propriedade.**
#
# ```
# Act as a hostile reviewer. Read my draft and name every sentence I could NOT defend
# myself if someone asked how I know it is true. Do not rewrite anything. List the weak
# spots.
# ```
#
# Depois de rodar, verifique: para cada frase sinalizada, produza a sua própria
# checagem ou corte a alegação. Combate a **concordância bajuladora**, o elogio que
# revisa o seu ego em vez da sua evidência.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > A ferramenta pode buscar, rascunhar e calcular. Ela nunca pode decidir em quais
# > alegações você põe o seu nome, se a sua evidência sustenta uma palavra como
# > "inseguro", a ética da sua amostragem, como você enuncia a sua incerteza, ou o que
# > diz a sua declaração de uso de IA. Autoria é uma responsabilidade, não uma tarefa, e
# > ela não se transfere.

# %% [markdown]
# ## Agora é a sua vez
#
# *Você já tem um registro, uma lista de tarefas de quem dirige e uma delegação que
# rodou de ponta a ponta. Este passo põe o seu nome em tudo isso, de propósito, por
# escrito.*

# %% [markdown]
# **Passo 1.** Escreva a sua **declaração de propriedade**: três ou quatro frases nomeando o
# trabalho em que você pretende colocar o seu nome, por que você vai responder
# pessoalmente, e o que você não vai alegar ter feito.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** Escreva a sua **lista do que nunca se delega** para este projeto específico.
# Cinco linhas já bastam. Faça de cada uma uma escolha, não um tema: qual pergunta
# você persegue, o que conta como uma comparação justa, onde a alegação para.
# Guarde a lista em um lugar onde você vá de fato vê-la.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** Rascunhe a declaração de uso de IA que você anexaria ao seu trabalho como ele
# está hoje, construída a partir das linhas do seu registro e não da memória.
# Nomeie cada ferramenta, o que ela fez e como você a conferiu. Se um agente rodou
# um loop longo em seu nome, diga isso, e diga o que você abriu e inspecionou
# quando ele terminou.

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** Leia a declaração e o registro lado a lado. Onde eles discordarem, o registro
# está certo. Corrija a declaração.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** Encontre uma frase que você já escreveu e que não conseguiria defender se alguém
# perguntasse como você sabe que ela é verdadeira. Produza a checagem, ou corte a
# frase.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 6.** Registre tudo isso no seu **AI Research Ledger** e verifique pelo menos uma
# alegação sobrevivente com um método nomeado do [Guia de
# Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html): leitura da fonte primária se ela se
# apoia em uma fonte, cálculo direto se ela se apoia em um número. Uma IA revisora
# pode rodar a checagem com você; a decisão de aceitar ou rejeitar continua sendo
# sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 6.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **14 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Escreva a sua **declaração de propriedade**: três ou quatro frases nomeando o trabalho em que você pretende colocar o seu nome, por que você vai… | |
# | Passo 2 | Escreva a sua **lista do que nunca se delega** para este projeto específico | |
# | Passo 3 | Rascunhe a declaração de uso de IA que você anexaria ao seu trabalho como ele está hoje, construída a partir das linhas do seu registro e não da… | |
# | Passo 4 | Leia a declaração e o registro lado a lado | |
# | Passo 5 | Encontre uma frase que você já escreveu e que não conseguiria defender se alguém perguntasse como você sabe que ela é verdadeira | |
# | Passo 6 | Registre tudo isso no seu **AI Research Ledger** e verifique pelo menos uma alegação sobrevivente com um método nomeado do Guia de Verificação:… | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# A seguir: [Capítulo 5 — Da Curiosidade a um Problema de Pesquisa](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part2-curiosity-to-design/05-from-curiosity-to-a-research-problem.html).
