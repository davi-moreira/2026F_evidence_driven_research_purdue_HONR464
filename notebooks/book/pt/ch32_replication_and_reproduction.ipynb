# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 32 — Replicação e Reprodução
#
# Este é o **notebook companheiro** do [Capítulo 32 — Replicação e Reprodução](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part6-after-conference/32-replication-and-reproduction.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. De autoria de [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html).
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part6-after-conference/32-replication-and-reproduction.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.

# %% [markdown]
# > **A decisão de pesquisa.** Sem nada além dos arquivos que um estudo entregou, seu ou
# > de outra pessoa, você decide se o número relatado de fato volta a aparecer. Depois,
# > você ordena as fragilidades que encontrou pelo tamanho da ameaça que cada uma
# > representa para a alegação principal, não pela facilidade de corrigir cada uma.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se primeiro com a sua própria resposta, depois delegue. Nenhum destes
# prompts é um tiro único. Você manda o prompt, lê o que volta, interroga, afia o pedido
# e roda de novo. Isso é o loop de IA, e uma auditoria costuma levar duas ou três voltas
# antes de a ferramenta parar de chutar e começar a apontar para linhas de verdade. Cada
# prompt é uma tarefa verificável, não um veredito que você terceiriza.

# %% [markdown]
# **Localize cada insumo que está faltando.**
#
# ```text
# Act as a cold reproducibility auditor. Here is everything a peer's package
# shipped: [paste the README, the data description, the code, and the headline
# claim]. List every input or step a stranger needs and might not find: the data
# file and its version, the exact run order, any random seed, any hard-coded path.
# Put it in a table with the item, whether the package supplies it, and the cell
# where I should check.
# ```
# Depois de rodar, verifique: mapeie cada item para uma célula real e depois pergunte
# "qual é a coisa mais importante que você deixou de fora?". Combate a *ilusão de
# completude* (uma lista de lacunas bem-arrumada ainda pode omitir o único ponteiro que
# falta e que trava a execução inteira).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Percorra a célula do número principal e depois confirme por fora.**
#
# ```text
# Here is the cell that computes the package's headline number: [paste the cell].
# Explain line by line what it computes, and name which printed value is the
# headline a reader should compare against the write-up. Then give me one
# independent way to confirm that value without rerunning this exact code.
# ```
# Depois de rodar, verifique: confirme que o valor apontado bate com o número que a sua
# execução de fato imprimiu, e então faça você mesmo a checagem independente sugerida.
# Combate a *fabricação confiante* (uma explicação fluente pode descrever um número que
# o código nunca produziu).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Faça red team (revisão adversária) da suposição oculta.**
#
# ```text
# This analysis treats every measured larva as an independent observation, though
# the probiotic was assigned by tank. Act as a hostile methods reviewer. Name the
# one assumption most likely to inflate the reported certainty, say what the honest
# experimental unit is, and do not reassure me the design is fine.
# ```
# Depois de rodar, verifique: recalcule você mesmo o intervalo no nível do tanque e veja
# se ele alcança o zero. Combate o *método plausível mas errado* (supor observações
# independentes em dados agrupados encolhe silenciosamente todos os intervalos).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > Uma ferramenta de IA não roda o código, então ela nunca consegue resolver se o número
# > de fato se reproduziu. Só o seu próprio restart-and-run-all faz isso. Você também
# > guarda três julgamentos: **qual fragilidade mais ameaça a alegação**, **como você
# > ordena as recomendações** e **o veredito final** sobre o que o pacote sustenta e o que
# > não sustenta. Uma ferramenta propõe suspeitos. Você decide quais deles a evidência
# > condena.

# %% [markdown]
# ## Agora é a sua vez
#
# *O seu projeto já tem alegações que você consegue defender e uma divulgação escrita de
# como a IA ajudou você a chegar até elas; este passo transforma tudo isso em arquivos
# que uma pessoa desconhecida conseguiria rodar sem você na sala.*

# %% [markdown]
# **Passo 1.** Junte tudo em uma pasta só: os dados, o código, a ordem de execução, a semente
# aleatória e um texto curto que enuncie o seu número principal em palavras.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** Reproduza a frio você mesmo. Limpe o kernel, rode cada célula desde o topo sem
# nenhum conserto manual e, se possível, faça isso em outra máquina que não a que você
# usou para construir tudo. Anote se o seu número principal voltou exatamente, mais ou
# menos, ou não voltou.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** Alinhe cada frase do seu texto com um número que o seu código de fato imprime.
# Sinalize cada divergência, inclusive o arredondamento que você não teve a intenção
# de esconder.

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** Mude uma escolha defensável que você nunca revelou, uma regra de exclusão, um ponto
# de corte ou um subconjunto, e registre o quanto o seu número principal se move.
# Relate a faixa inteira, não a ponta mais simpática dela.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** Nomeie a suposição sem a qual o seu resultado desmoronaria e ordene tudo o que você
# encontrou pela ameaça à alegação, não pela facilidade de conserto. Se você tiver
# um colega, troquem as pastas e rodem a frio a do outro. O número que a outra pessoa
# obtiver, colocado ao lado do número que você relatou, é a sua evidência de
# reprodução.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 6.** Registre a auditoria no seu **AI Research Ledger** (registro de pesquisa com IA), e
# verifique pelo menos um resultado com um método nomeado do
# [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). Um revisor de IA pode rodar a
# checagem com você; a decisão de aceitar ou rejeitar continua sendo sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 6.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **14 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Junte tudo em uma pasta só: os dados, o código, a ordem de execução, a semente aleatória e um texto curto que enuncie o seu número principal em… | |
# | Passo 2 | Reproduza a frio você mesmo | |
# | Passo 3 | Alinhe cada frase do seu texto com um número que o seu código de fato imprime | |
# | Passo 4 | Mude uma escolha defensável que você nunca revelou, uma regra de exclusão, um ponto de corte ou um subconjunto, e registre o quanto o seu número… | |
# | Passo 5 | Nomeie a suposição sem a qual o seu resultado desmoronaria e ordene tudo o que você encontrou pela ameaça à alegação, não pela facilidade de conserto | |
# | Passo 6 | Registre a auditoria no seu **AI Research Ledger** (registro de pesquisa com IA), e verifique pelo menos um resultado com um método nomeado do Guia… | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# A seguir: [Capítulo 33 — Do Pôster à Nota de Pesquisa](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part6-after-conference/33-from-poster-to-research-note.html).
