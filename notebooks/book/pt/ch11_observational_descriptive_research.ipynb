# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 11 — Pesquisa Observacional Descritiva
#
# Este é o **notebook companheiro** do [Capítulo 11 — Pesquisa Observacional Descritiva](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part3-pathways/11-observational-descriptive-research.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. De autoria de [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html).
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part3-pathways/11-observational-descriptive-research.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.

# %% [markdown]
# > **A decisão de pesquisa.** Por qual grupo os seus dados observados podem falar
# > honestamente, e onde exatamente cai a linha depois da qual uma descrição da sua
# > amostra não tem mais permissão de virar uma alegação sobre uma população mais
# > ampla. Você traça essa linha, e escreve a frase do outro lado dela que se recusa a
# > dizer.

# %% [markdown]
# ## Código do capítulo
#
# As células abaixo vêm do capítulo. Rode-as, depois mude algo e rode de novo — os números devem se mover do jeito que o capítulo diz.

# %% [markdown]
# *Da seção “Uma simulação com semente”.*

# %%
import numpy as np
import matplotlib.pyplot as plt

SEED = 464
rng = np.random.default_rng(SEED)

populacao = np.clip(rng.normal(49, 17, size=100_000), 18, 90)
verdade = populacao.mean()

medias_aleatorias = [rng.choice(populacao, 500, replace=False).mean()
                     for _ in range(10)]

pesos = np.exp(-(populacao - 25) ** 2 / (2 * 12 ** 2))  # jovem = mais provável
conveniencia = rng.choice(populacao, 500, replace=False,
                          p=pesos / pesos.sum())

fig, ax = plt.subplots(figsize=(7.6, 2.9))
ax.scatter(medias_aleatorias, np.ones(10), s=60, color="#2a78d6", zorder=3)
ax.scatter([conveniencia.mean()], [0], s=60, color="#eb6834", zorder=3)
ax.axvline(verdade, color="#333333", ls="--", lw=1.2)
ax.text(verdade + .5, 1.55, f"média verdadeira = {verdade:.1f}",
        color="#333333", fontsize=9)
ax.set_yticks([0, 1], ["Canal de\nconveniência (n = 500)",
                       "Amostras aleatórias\n(n = 500)"], fontsize=9)
ax.set_xlabel("Idade média da amostra (anos)")
ax.set_ylim(-.7, 1.9)
plt.show()

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se com a sua própria resposta primeiro, depois delegue. Cada prompt abaixo
# deixa o julgamento com você e entrega à IA apenas o trabalho de perna. Trabalhe-os
# como um loop, não como tiro único: a primeira lista de grupos que ficam de fora é
# sempre a óbvia, e a resposta útil costuma chegar na segunda ou terceira passagem,
# depois que você disse à ferramenta qual grupo ela esqueceu e pediu que tentasse de
# novo com isso em mente.

# %% [markdown]
# **Localizar.** Encontre respaldo metodológico real em vez de confiar em um parágrafo.
#
# ```
# Act as a research-methods assistant. List real, retrievable references on
# survivorship and nonresponse bias in observational studies. For each, give
# title, authors, year, and venue, and mark any you are not confident exist.
# ```
#
# Depois de rodar, verifique abrindo cada fonte em uma base de dados de biblioteca antes
# de citá-la. Isso enfrenta a *fabricação confiante*: uma citação fluente para um artigo
# que não existe é idêntica a uma real até você tentar recuperá-la.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Listar para verificar.** Transforme uma preocupação vaga em uma lista checável de
# quem fica de fora.
#
# ```
# I am drawing a selection diagram for an observational study. My target
# population is [X], my frame is [Y], my sample is [Z]. List each group that
# drops out between target and sample, in a table, with whether their absence
# pushes my estimate up or down.
# ```
#
# Depois de rodar, verifique mapeando cada grupo nomeado para um passo real do seu
# próprio diagrama, e conferindo que o grupo que você mais temia está na lista. Isso
# enfrenta a *ilusão de completude*: uma lista longa e bem arrumada que omite em
# silêncio justamente o grupo que mais importa.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Red team.** Faça a IA atacar a sua frase de fronteira em vez de elogiá-la.
#
# ```
# Here is a boundary sentence I wrote: "[your sentence]". Act as a hostile peer
# reviewer. Name every place it over-reaches, under-states the bias, or hides the
# direction of the drift. Do not rewrite it for me.
# ```
#
# Depois de rodar, verifique conferindo cada objeção contra os seus próprios números e
# insistindo se todas as objeções forem brandas. Isso enfrenta a *concordância
# bajuladora*: uma IA que chama a sua ressalva de "bem equilibrada" revisou o seu ego,
# não a sua evidência.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > Três decisões continuam só suas. Primeira, **sobre qual população o seu projeto
# > realmente trata**: a IA não conhece a intenção da sua pergunta. Segunda, **qual marco
# > amostral você consegue honestamente alcançar**, e portanto a lacuna de cobertura que
# > você precisa revelar. Terceira, **a própria linha de fronteira**: a frase exata em que
# > a sua descrição para e a alegação populacional que você se recusa a fazer. Você pode
# > pedir a uma IA que ataque essa linha, nunca que a trace por você.

# %% [markdown]
# ## Agora é a sua vez
#
# *Você chega com um desenho de pesquisa declarado e diagnosticado. Este é o primeiro
# dos capítulos de caminho, então o seu trabalho agora é ou desenvolver o seu desenho
# neste caminho, ou usá-lo para testar sob estresse o caminho que você escolheu.*

# %% [markdown]
# **Passo 1.** Decida em qual caso você está. Leia as palavras da sua indagação. Se ela pergunta
# *quanto, quantos, com que frequência*, sobre um grupo que você vai observar em vez
# de atribuir, este é o seu caminho. Se ela pergunta *por quê* ou *o que aconteceria
# se*, não é, e você faz o exercício do passo 5 no lugar.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** **Se este é o seu caminho**, escreva as suas quatro caixas, uma linha cada:
# população-alvo, população acessível, marco amostral, amostra. Seja concreto sobre o
# marco. Nomeie a lista, o banco de dados ou o feed de onde os seus dados vão vir.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** Desenhe o seu diagrama de seleção: uma seta de cada caixa para a seguinte, com o
# filtro que remove pessoas escrito sobre a seta. Circule o filtro que você mais teme
# que curve *tanto* quem você alcança quanto o que você mede. É esse que você vai ter
# de revelar.

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** Escreva as duas frases que definem a sua alegação. A primeira é a alegação
# populacional que o seu marco de fato autoriza, enunciada com a sua incerteza. A
# segunda é o upgrade silencioso que o seu desenho proíbe, escrito por extenso para
# que você o reconheça e o recuse quando um coautor ou uma IA o devolver a você.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** **Se este não é o seu caminho**, faça o exercício de classificação. Escreva a sua
# pergunta como se fosse uma pergunta observacional descritiva, nomeie as quatro
# caixas de que ela precisaria, e diga precisamente o que essa versão não conseguiria
# te dizer. A frase que você não consegue escrever aqui é a razão pela qual o caminho
# que você escolheu tem de merecer as suposições extras dele.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 6.** Registre o trabalho no seu **AI Research Ledger** (registro de pesquisa com IA), e
# verifique a alegação-chave com um método nomeado do
# [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html); a simulação se encaixa aqui,
# porque a alegação é sobre como um procedimento de amostragem se comporta, e não
# sobre um número fixo. Um revisor de IA pode atacar a sua frase de fronteira junto
# com você; a decisão de manter a linha ou movê-la continua sendo sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 6.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **14 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Decida em qual caso você está | |
# | Passo 2 | **Se este é o seu caminho**, escreva as suas quatro caixas, uma linha cada: população-alvo, população acessível, marco amostral, amostra | |
# | Passo 3 | Desenhe o seu diagrama de seleção: uma seta de cada caixa para a seguinte, com o filtro que remove pessoas escrito sobre a seta | |
# | Passo 4 | Escreva as duas frases que definem a sua alegação | |
# | Passo 5 | **Se este não é o seu caminho**, faça o exercício de classificação | |
# | Passo 6 | Registre o trabalho no seu **AI Research Ledger** (registro de pesquisa com IA), e verifique a alegação-chave com um método nomeado do Guia de… | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# A seguir: [Capítulo 12 — Pesquisa Observacional Causal](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part3-pathways/12-observational-causal-research.html).
