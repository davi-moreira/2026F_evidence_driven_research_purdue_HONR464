# %% [markdown]
# # Capítulo 3 — Especificar, Delegar, Interrogar, Inspecionar, Verificar, Documentar, Defender
#
# Este é o **notebook companheiro** do [Capítulo 3 — Especificar, Delegar, Interrogar, Inspecionar, Verificar, Documentar, Defender](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part1-research-with-ai/03-specify-delegate-interrogate-inspect-verify-document-defend.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. Ele pertence ao livro, não a curso nenhum: tudo de que você precisa é este notebook, o capítulo e o Colab gratuito.
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part1-research-with-ai/03-specify-delegate-interrogate-inspect-verify-document-defend.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.

# %% [markdown]
# > **A decisão de pesquisa.** Toda vez que você entrega um trabalho a uma
# > ferramenta de IA, você decide o caminho que esse trabalho vai seguir: o que você
# > fixa antes de perguntar, o que você abre e lê quando a resposta chega, e o que
# > você está disposto a dizer com as suas próprias palavras no fim. A sua decisão
# > neste capítulo é parar de improvisar esse caminho e rodar a mesma lista de sete
# > etapas toda vez.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se primeiro com a sua própria resposta, e só então delegue. Cada prompt
# abaixo é um serviço conferível, não um pedido de veredito, e cada um é o movimento
# de abertura de um loop, não a conversa inteira.

# %% [markdown]
# **Localize o método padrão.**
#
# ```text
# Act as a business-analytics assistant. I need to compare conversion rates for two
# versions of a checkout page. Before any code, name the standard statistical test
# for comparing two proportions and the exact library function that implements it,
# citing the official documentation section. Only name functions you are confident
# exist.
# ```
# Depois de rodar, verifique: abra a documentação oficial e confirme que a função e
# os seus padrões existem. Combate a *fabricação confiante* (um nome de função
# inventado chega com a mesma confiança de um real).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Delegue, com uma lista de checagem para verificar.**
#
# ```text
# Write the script that computes the conversion rate for version A and version B
# from this session log. Then return a table of every assumption your calculation
# makes: which sessions are included and excluded, how you count a purchase, whether
# both versions ran over the same days, and how repeat visits are handled.
# ```
# Depois de rodar, verifique: recalcule à mão a taxa de uma das versões em um único
# dia e confira se bate. Combate o *método plausível mas errado* (um cálculo que, sem
# alarde, compara condições desiguais).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Faça o red team (revisão adversária) do seu ganho.**
#
# ```text
# Here is my claim: "the new checkout page converts about 6 percent better."
# Act as a hostile reviewer. Name every way this comparison could be unfair or this
# number could mislead. Do not rewrite the claim for me.
# ```
# Depois de rodar, verifique: se a ferramenta só elogiar a alegação, conteste e exija
# o pior defeito, um só. Combate a *concordância bajuladora* (elogio que revisa o seu
# ego, não a sua evidência).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > Especificar e Defender nunca saem das suas mãos. Você decide **que pergunta a
# > comparação responde**, **o que conta como uma comparação justa** e **se os dados
# > por trás dela são honestos** para a alegação que você quer fazer. A frase final, o
# > limite dela e a incerteza dela são seus. A ferramenta consegue calcular as taxas,
# > mas não consegue decidir que o teste foi justo ou que a alegação foi conquistada.
# > Isso é seu.

# %% [markdown]
# ## Agora é a sua vez
#
# *Você já tem uma lista de tarefas que diz o que você está disposto a delegar. Agora
# você delega algo de verdade, e mantém o comando do primeiro ao último passo.*

# %% [markdown]
# **Passo 1.** Escolha uma alegação genuína e conferível da sua própria área: uma taxa, um
# total, uma comparação, qualquer coisa que uma fonte ou um cálculo consiga
# resolver. Escreva-a como uma única frase.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** **Especificar.** Antes de abrir qualquer ferramenta, escreva a sua própria
# resposta esperada e como seria uma maneira justa de chegar até ela.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** **Delegar, Interrogar, Inspecionar.** Entregue a tarefa. Pergunte ao resultado o
# que ele pressupõe. Depois abra o que ele de fato produziu, a fonte, o código ou
# a tabela, em vez do resumo que ele faz de si mesmo. Espere várias passadas por
# esse loop, e anote o que mudou em cada uma.

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** **Verificar.** Rode uma checagem independente. Se a checagem e o resultado
# discordarem, não tire a média dos dois; descubra qual deles está errado.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** **Defender.** Com a ferramenta fechada, escreva uma frase enunciando o resultado
# com as suas próprias palavras, e uma frase nomeando o que ele não estabelece.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 6.** **Documente** a corrida inteira no seu **AI Research Ledger** (o registro de uso
# de IA), nomeando o método de verificação que você usou do [Guia de
# Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html) e a etapa em que você pegou algo que a
# ferramenta errou. Uma IA revisora pode rodar a checagem com você; a decisão de
# aceitar ou rejeitar continua sendo sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 6.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **14 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Escolha uma alegação genuína e conferível da sua própria área: uma taxa, um total, uma comparação, qualquer coisa que uma fonte ou um cálculo consiga… | |
# | Passo 2 | **Especificar.** Antes de abrir qualquer ferramenta, escreva a sua própria resposta esperada e como seria uma maneira justa de chegar até ela | |
# | Passo 3 | **Delegar, Interrogar, Inspecionar.** Entregue a tarefa | |
# | Passo 4 | **Verificar.** Rode uma checagem independente | |
# | Passo 5 | **Defender.** Com a ferramenta fechada, escreva uma frase enunciando o resultado com as suas próprias palavras, e uma frase nomeando o que ele não… | |
# | Passo 6 | **Documente** a corrida inteira no seu **AI Research Ledger** (o registro de uso de IA), nomeando o método de verificação que você usou do Guia de… | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# A seguir: [Capítulo 4 — Responsabilidade na Pesquisa e Propriedade Intelectual](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part1-research-with-ai/04-research-responsibility-and-intellectual-ownership.html).
