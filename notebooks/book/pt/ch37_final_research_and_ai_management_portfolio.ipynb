# %% [markdown]
# # Capítulo 37 — Pesquisa Final e Portfólio de Gestão de IA
#
# Este é o **notebook companheiro** do [Capítulo 37 — Pesquisa Final e Portfólio de Gestão de IA](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part6-after-conference/37-final-research-and-ai-management-portfolio.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. Ele pertence ao livro, não a curso nenhum: tudo de que você precisa é este notebook, o capítulo e o Colab gratuito.
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part6-after-conference/37-final-research-and-ai-management-portfolio.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.

# %% [markdown]
# > **A decisão de pesquisa.** De tudo o que o seu projeto produziu, você decide quais
# > alegações vai sustentar em público, e monta o registro que mostra como você comandou
# > o seu time de IA, o que manteve nas suas próprias mãos e como cada alegação
# > sobrevivente foi conferida.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se primeiro com a sua própria resposta, depois delegue. Cada prompt entrega
# alcance à ferramenta, não a decisão, e cada um abre um loop em vez de terminar em uma
# resposta única: você lê o que volta, aperta na parte mais fraca e roda de novo. Fechar o
# loop é um movimento seu, não da ferramenta.

# %% [markdown]
# **Localize a referência real.**
#
# ```
# Act as a research assistant in plant biology. I measured the germination rate of one
# packet of lettuce seed. I want a published or label-stated reference value to compare
# against. Give the value, the exact source it comes from, and a link. Only state a
# figure you are confident is real; if you are unsure, say so and tell me where to
# look.
# ```
#
# Depois de rodar, verifique: abra a fonte ou leia o pacote você mesmo antes de confiar no
# número (leitura da fonte primária). Combate a **fabricação confiante**, um valor de
# referência citado com uma fonte inventada.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Liste todas as alegações a verificar.**
#
# ```
# Here is my draft: [paste]. List every empirical claim in it as a table: the claim,
# the number or measurement it rests on, and whether that claim stays inside my single
# sample or reaches past it. Do not add any new claims.
# ```
#
# Depois de rodar, verifique: confira a tabela contra a sua própria lista do que você
# mediu, e confirme que nada vai além dos seus dados sem estar marcado. Combate a **ilusão
# de completude**, uma lista arrumadinha que omite a única alegação que exagera em
# silêncio.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Faça red team (revisão adversária) da defesa.**
#
# ```
# Act as a hostile but fair cross-examiner at a research defense. Here is my headline
# claim, its boundary, and my two weakest verification steps: [paste]. Ask me the five
# hardest questions you can, each tied to a specific claim or check. Do not soften them,
# and do not answer them for me.
# ```
#
# Depois de rodar, verifique: se toda pergunta for gentil ou se a sua alegação for chamada
# de "bem sustentada", insista e exija o elo mais fraco. Combate a **concordância
# bajuladora**, um parceiro que ensaia o seu ego em vez da sua defesa.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > As ferramentas podem redigir, revisar e trazer perguntas difíceis. Elas nunca podem
# > decidir quais alegações levam o seu nome, onde uma alegação como "88% de germinação"
# > precisa parar, se os seus revisores chegaram a ser independentes, qual é a sua regra de
# > parada, nem uma única palavra da defesa pública. Quando papéis concordantes abençoam uma
# > alegação, decidir se essa concordância é real ou apenas correlacionada é tarefa sua. E
# > também é sua a resposta que você dá quando a sala pergunta como você sabe.

# %% [markdown]
# ## Agora é a sua vez
#
# *O seu projeto já tem uma nota, uma cápsula, um time de IA gerenciado e regras de
# escalonamento que você escreveu; este último passo reúne tudo isso no artefato que você
# entrega e na defesa que você faz.*

# %% [markdown]
# **Passo 1.** Termine o artefato de pesquisa em si: o seu artigo, a sua nota ou o seu pôster, com
# cada alegação enunciada no seu limite e a sua incerteza na mesma frase do seu número
# de destaque. Este é o documento que leva o seu nome.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** Monte o seu portfólio de gestão de IA em quatro partes: a decomposição dos loops que
# você rodou, um conflito real e o override que você fez, com a checagem sem IA que o
# sustentou, a sua regra de parada junto da sua lista do que nunca se delega, e uma
# checagem de independência que fez uma concordância valer mais do que uma contagem de
# votos.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** Escreva a sua regra de parada como uma frase que você conseguiria ler em voz alta,
# formulada em torno do que você verificou, e não do que as suas ferramentas
# aprovaram. "Cada alegação sobrevivente tem uma checagem que eu mesmo fiz" é uma
# regra de parada. "Os revisores concordaram" não é.

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** Ensaie a defesa em três movimentos: a sua alegação e o limite dela, a escolha central
# que você fez e o caminho que você não seguiu, e a verificação com que você abre.
# Depois peça a alguém que faça a pergunta que você menos quer ouvir.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** Releia o artefato inteiro contra o seu AI Research Ledger (registro de pesquisa com
# IA) e corte tudo o que você não consegue rastrear até uma checagem. O que sobrar é o
# que você consegue defender.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 6.** Feche o registro com a última entrada, e verifique a sua alegação de destaque uma
# última vez com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html).
# Um revisor de IA pode rodar a checagem com você; a decisão de aceitar ou rejeitar
# continua sendo sua.
#
# É isso, o livro inteiro. Você começou com uma curiosidade que ainda não sabia responder,
# e agora tem uma pesquisa terminada, um registro de cada ferramenta que a tocou e um
# conjunto de alegações que você consegue defender nas bordas. As ferramentas foram
# rápidas. O julgamento foi seu do começo ao fim, e é essa parte que faz do trabalho o seu
# trabalho.

# %% [markdown]
# ✍️ **Seu trabalho no passo 6.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **14 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Termine o artefato de pesquisa em si: o seu artigo, a sua nota ou o seu pôster, com cada alegação enunciada no seu limite e a sua incerteza na mesma… | |
# | Passo 2 | Monte o seu portfólio de gestão de IA em quatro partes: a decomposição dos loops que você rodou, um conflito real e o override que você fez, com a… | |
# | Passo 3 | Escreva a sua regra de parada como uma frase que você conseguiria ler em voz alta, formulada em torno do que você verificou, e não do que as suas… | |
# | Passo 4 | Ensaie a defesa em três movimentos: a sua alegação e o limite dela, a escolha central que você fez e o caminho que você não seguiu, e a verificação… | |
# | Passo 5 | Releia o artefato inteiro contra o seu AI Research Ledger (registro de pesquisa com IA) e corte tudo o que você não consegue rastrear até uma checagem | |
# | Passo 6 | Feche o registro com a última entrada, e verifique a sua alegação de destaque uma última vez com um método nomeado do Guia de Verificação | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# Este era o último capítulo: as 37 seções **Agora é a sua vez** que você trabalhou são o seu projeto de pesquisa. Monte o portfólio, e defenda-o.
