# %% [markdown]
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/images/edrai_logo.png" alt="EDR|AI" width="300"/>
#
# # Capítulo 20 — A IA como Assistente Analítica
#
# Este é o **notebook companheiro** do [Capítulo 20 — A IA como Assistente Analítica](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part4-credible-evidence/20-ai-as-analytical-assistant.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. De autoria de [Davi Moreira](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html).
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part4-credible-evidence/20-ai-as-analytical-assistant.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.

# %% [markdown]
# > **A decisão de pesquisa.** Você decide **quais tarefas analíticas a assistente roda e
# > quais números você mesmo refaz** antes que qualquer um deles chegue a uma alegação. A
# > assistente fornece mão de obra aos baldes. Quais verificações contam, quais alertas
# > são reais e o que o número sobrevivente significa: isso fica do seu lado da mesa.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se com a sua própria expectativa primeiro, depois delegue. Cada prompt é uma
# tarefa conferível, não um pedido de veredito.

# %% [markdown]
# **Proponha as verificações que talvez me tenham escapado.**
#
# ```text
# Here is my robustness grid for one estimate: I vary the sample (all enrollees /
# drop those who enrolled with an offer in hand), the measurement (mean / median
# weeks to first offer), and the specification (raw gap / adjusted for prior work
# experience). Act as a hostile reviewer. Name up to three additional, equally
# defensible checks I did NOT list, and for each say which direction you expect it
# to move the estimate.
# ```
# Depois de rodar, verifique: confronte cada proposta com as suas quatro alavancas e
# confirme que você consegue de fato calculá-la nos seus dados. Contra-ataca a *ilusão de
# completude* (uma grade arrumadinha que ainda assim omite a única verificação capaz de
# quebrar a alegação).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Delegue o cálculo e mantenha os números conferíveis.**
#
# ```text
# Recompute my time-to-offer gap under each row of this grid and return a table:
# row label, the gap, and the exact columns and filter used for that row.
# Do not summarize; show one number and its code path per row.
# ```
# Depois de rodar, verifique: recalcule duas linhas na mão com uma segunda expressão e
# confirme que elas batem com a tabela. Contra-ataca o *método plausível mas errado* (uma
# linha cujo rótulo e cujo código discordam em silêncio).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Faça o loop confessar.**
#
# ```text
# Before I accept this table: list every version of this analysis you ran while
# producing it, in order, with what changed each time and why. If you tried a
# variant and set it aside, it goes on the list too.
# ```
# Depois de rodar, verifique: compare a lista dela com o seu próprio registro de ciclos e
# rode de novo qualquer variante que ela mencione e que você nunca viu. Contra-ataca uma
# *busca por especificações não registrada* (o loop testando opções em silêncio até uma
# ficar boa).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# **Faça o red team da alegação sobrevivente.**
#
# ```text
# Here is my claim: "the program gets people to a first offer about 0.7 SD sooner."
# Act as a hostile reviewer of labor-market program evaluations. Name the single
# worst way this result could mislead, and the exact data check that would confirm
# or kill it. Do not rewrite my claim.
# ```
# Depois de rodar, verifique: rode a checagem que ela nomear e trate a falha como real só
# se a sua própria saída confirmar. Contra-ataca a *concordância bajuladora* (elogio que
# revisa o seu ego, não a sua evidência).

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > Três decisões nunca saem das suas mãos. Você decide **quais verificações contam** para
# > a alegação que quer fazer, **quais problemas apontados os dados de fato confirmam** e
# > **a alegação final que você defende**, com o limite e o intervalo dela. A assistente
# > propõe e calcula. A evidência decide, e quem lê a evidência é você.

# %% [markdown]
# ## Agora é a sua vez
#
# *Seu projeto tem código verificado e um primeiro número. Este passo roda a análise de
# verdade com uma assistente ao seu lado, e guarda os comprovantes de cada volta do loop
# para que a sua análise continue sendo uma análise, e não uma busca silenciosa.*

# %% [markdown]
# **Passo 1.** Antes que a assistente toque em qualquer coisa, escreva a sua estimativa principal
# em uma frase e a resposta que você espera. Você está se comprometendo publicamente,
# para que um resultado surpreendente de fato o surpreenda.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** Entregue uma tarefa bem especificada por vez. Peça o número, as colunas exatas e o
# filtro por trás dele, nunca um veredito sobre o que aquilo significa.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** Mantenha um registro de ciclos enquanto trabalha: uma linha por volta, com o que
# você pediu, o que voltou, e o que você mudou e por quê. Se uma ferramenta agêntica
# rodou voltas que você não viu, obrigue-a a listá-las e acrescente-as ao seu registro.

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** Refaça pelo menos dois números você mesmo, na mão ou com uma segunda expressão
# simples, antes que qualquer um deles entre em uma alegação.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** Rode um placebo: embaralhe os rótulos de grupo, rode o mesmo código sem alterações e
# confirme que a diferença falsa desaba para perto de zero.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 6.** Registre a análise no seu **AI Research Ledger** (registro de pesquisa com IA), com
# o registro de ciclos anexado, e verifique pelo menos uma saída com um método nomeado
# do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). **Código alternativo** cai bem
# para uma diferença calculada. Uma IA revisora pode rodar a checagem com você; a
# decisão de aceitar ou rejeitar continua sendo sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 6.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **14 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Antes que a assistente toque em qualquer coisa, escreva a sua estimativa principal em uma frase e a resposta que você espera | |
# | Passo 2 | Entregue uma tarefa bem especificada por vez | |
# | Passo 3 | Mantenha um registro de ciclos enquanto trabalha: uma linha por volta, com o que você pediu, o que voltou, e o que você mudou e por quê | |
# | Passo 4 | Refaça pelo menos dois números você mesmo, na mão ou com uma segunda expressão simples, antes que qualquer um deles entre em uma alegação | |
# | Passo 5 | Rode um placebo: embaralhe os rótulos de grupo, rode o mesmo código sem alterações e confirme que a diferença falsa desaba para perto de zero | |
# | Passo 6 | Registre a análise no seu **AI Research Ledger** (registro de pesquisa com IA), com o registro de ciclos anexado, e verifique pelo menos uma saída… | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# A seguir: [Capítulo 21 — Robustez e Sensibilidade](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part4-credible-evidence/21-robustness-and-sensitivity.html).
