# %% [markdown]
# # Capítulo 13 — Pesquisa Descritiva Experimental
#
# Este é o **notebook companheiro** do [Capítulo 13 — Pesquisa Descritiva Experimental](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part3-pathways/13-experimental-descriptive-research.html) de **EDR|AI — Pesquisa Orientada por Evidências na Era da IA**. Ele pertence ao livro, não a curso nenhum: tudo de que você precisa é este notebook, o capítulo e o Colab gratuito.
#
# [Abrir o capítulo](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part3-pathways/13-experimental-descriptive-research.html) · [Início do livro](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html) · [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html)
#
# *A IA é o seu braço e a sua assistente de pesquisa, não o seu cérebro.*

# %% [markdown]
# ## Como usar este notebook
#
# 1. Trabalhe de cima para baixo, com o capítulo aberto em outra aba.
# 2. Copie cada **prompt de IA** para a sua ferramenta de IA, rode, e registre na célula de resposta o que voltou e o que você verificou.
# 3. Rode as células de código; mude algo e rode de novo.
# 4. Termine o espaço de trabalho **Agora é a sua vez** no final — ele é a etapa deste capítulo no seu próprio projeto de pesquisa.
# 5. Registre todo uso de IA no seu **AI Research Ledger**: tarefa · ferramenta · prompt · resumo do resultado · decisão · método de verificação · preocupação restante · você como pesquisador(a) responsável.

# %% [markdown]
# > **A decisão de pesquisa.** Um cara ou coroa não decide que tipo de pergunta você
# > fez. Quem decide se o seu estudo randomizado está **medindo** uma propriedade que
# > o mundo já tem ou **testando** uma intervenção que você implantaria é você, e é
# > você quem nomeia os artefatos que a sua mensuração ainda precisa descartar antes
# > que o número signifique alguma coisa.

# %% [markdown]
# ## Prompts de IA recomendados

# %% [markdown]
# Comprometa-se com a sua própria resposta primeiro, depois delegue. Cada prompt abaixo
# termina com uma checagem que você mesmo roda. E trate cada um deles como a jogada de
# abertura de um loop, não como um pedido de uma rodada só: leia a saída, conteste a
# parte mais fraca, afie o prompt, rode de novo. Ferramentas agênticas hoje rodam
# várias voltas desse loop por conta própria, o que não aposenta a sua checagem. Só
# significa que chega mais saída entre uma checagem e outra.
#
# ```text
# Act as a literature scout. List three real, published experiments used to MEASURE
# a latent characteristic (position bias in a ranking interface, a hidden prevalence,
# a preference weight) rather than to test a deployable intervention. For each give
# authors, year, venue, and the single quantity measured, in a table. Only include
# work you are confident exists; mark any row you are unsure about.
# ```
# Depois de rodar, verifique: abra uma base de dados e recupere você mesmo cada estudo;
# qualquer linha que você não achar em um minuto é uma **fabricação confiante**, então
# corte.
#
# ```text
# Here is code that estimates an interface's attention curve as the difference in
# play rate across randomly assigned slots: [paste]. Name every assumption this
# estimator needs to be valid, and for each, one concrete way it could fail in my
# logs.
# ```
# Depois de rodar, verifique: confronte cada suposição com o seu pipeline de verdade;
# um estimador que soa padrão mas supõe algo que os seus dados quebram é um **método
# plausível, porém errado**.
#
# ```text
# Act as a hostile measurement reviewer. Here is my construct and how I measure it:
# [plan]. List every demand effect and instrument effect that could produce my number
# even if the true value were different, and the redesign that rules each one out.
# ```
# Depois de rodar, verifique: compare a lista com o artefato que você anotou primeiro;
# se o seu não estiver ali, a saída bem arrumada acabou de falhar no teste da **ilusão
# de completude**, então recoloque-o.

# %% [markdown]
# ✍️ **Seu registro.** Clique duas vezes nesta célula e anote: o que a IA devolveu (uma ou duas linhas), o que você verificou e como, e a sua linha do ledger.

# %% [markdown]
# > **Não delegue.**
# >
# > Três decisões continuam sendo suas. Se a sua indagação é **descritiva ou causal**,
# > porque o tipo mora nas palavras da sua pergunta e nenhuma ferramenta lê a sua
# > intenção. Se o desenho mede mesmo o **seu** constructo, e não algo adjacente, o que é
# > um julgamento sobre significado, não sobre código. E quais **artefatos** você aceita
# > assinar embaixo como descartados. Uma parceria de IA pode rascunhar, localizar e
# > atacar. Declarar e defender é com você.

# %% [markdown]
# ## Agora é a sua vez
#
# *O seu desenho está declarado e diagnosticado. Este passo faz uma pergunta mais
# estreita a ele: o seu estudo está medindo uma propriedade que o mundo já tem e, se
# estiver, ele consegue fazer isso com honestidade?*

# %% [markdown]
# **Passo 1.** Leia a sua pergunta principal em voz alta e sublinhe o verbo. Ela pergunta quanto
# de algo já existe lá fora, ou o que mudaria se você interviesse? Escreva a
# resposta em uma linha. Essa linha decide se esta trilha é a sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 1.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 2.** Se for a sua, nomeie a característica latente que o seu projeto precisa revelar, a
# propriedade que ninguém publica em lugar nenhum, e o estímulo controlado que você
# vai atribuir ao acaso para revelá-la.

# %% [markdown]
# ✍️ **Seu trabalho no passo 2.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 3.** Escreva o seu estimando em uma frase: a quantidade exata, para quais unidades,
# descrita como ela está. Embaixo, escreva a frase causal que você se proíbe de
# dizer, aquela que começa com "se nós".

# %% [markdown]
# ✍️ **Seu trabalho no passo 3.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 4.** Nomeie o efeito de demanda e o efeito de instrumento que você mais teme, cada um
# com o redesenho que o descarta.

# %% [markdown]
# ✍️ **Seu trabalho no passo 4.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 5.** Se esta trilha não for a sua, rode os passos 2 a 4 como exercício mesmo assim,
# tratando a sua pergunta como se você tivesse que medi-la em vez de intervir. O que
# quebrar é a sua evidência de que a trilha escolhida encaixa melhor. Escreva isso
# em duas linhas.

# %% [markdown]
# ✍️ **Seu trabalho no passo 5.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# **Passo 6.** Registre o passo no seu **AI Research Ledger** (registro de pesquisa com IA), e
# verifique pelo menos uma saída com um método nomeado do
# [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). Um teste de falsificação cai bem
# neste capítulo: coloque o efeito verdadeiro em exatamente zero em uma versão de
# brinquedo do seu desenho e confirme que o seu instrumento relata mais ou menos
# zero. Um revisor de IA pode rodar a checagem com você; a decisão de aceitar ou
# rejeitar continua sendo sua.

# %% [markdown]
# ✍️ **Seu trabalho no passo 6.** Clique duas vezes nesta célula e escreva a sua resposta aqui.

# %% [markdown]
# ### Como esta seção é avaliada
#
# Cada linha vale **0** (ausente), **1** (tentada, mas incompleta, genérica ou não verificada) ou **2** (completa, específica do seu próprio projeto e verificada onde couber uma checagem). **14 pontos no total.**
#
# | # | Critério | 0–2 |
# |---|---|---|
# | Passo 1 | Leia a sua pergunta principal em voz alta e sublinhe o verbo | |
# | Passo 2 | Se for a sua, nomeie a característica latente que o seu projeto precisa revelar, a propriedade que ninguém publica em lugar nenhum, e o estímulo… | |
# | Passo 3 | Escreva o seu estimando em uma frase: a quantidade exata, para quais unidades, descrita como ela está | |
# | Passo 4 | Nomeie o efeito de demanda e o efeito de instrumento que você mais teme, cada um com o redesenho que o descarta | |
# | Passo 5 | Se esta trilha não for a sua, rode os passos 2 a 4 como exercício mesmo assim, tratando a sua pergunta como se você tivesse que medi-la em vez de… | |
# | Passo 6 | Registre o passo no seu **AI Research Ledger** (registro de pesquisa com IA), e verifique pelo menos uma saída com um método nomeado do Guia de… | |
# | + | Cuidado e registro de verificação: uso de IA registrado no seu AI Research Ledger, alegações declaradas com a sua incerteza, e cada alegação-chave verificada com um método nomeado | |

# %%
# Espaço de rascunho — use esta célula para qualquer código de que os passos precisarem.

# %% [markdown]
# **Antes de sair deste notebook:** acrescente as linhas de hoje ao seu AI Research Ledger, e verifique a sua alegação principal com um método nomeado do [Guia de Verificação](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/verification-guide.html). IA pode revisar IA — mas a última decisão é humana.
#
# A seguir: [Capítulo 14 — Predição e Generalização](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/part3-pathways/14-prediction-and-generalization.html).
