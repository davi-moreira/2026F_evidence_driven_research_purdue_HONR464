# %% [markdown]
# # Milestone 3: Your evidence base
#
# The milestone chapter of **Studio 3: Ground it in verified evidence**.
#
# **What you can defend when you leave.** Find out what is already known, verify that it is actually known, and let it change your question.
#
# **What this milestone produces.** An evidence registry of verified sources, your search log, an evidence map, and an explicit revision of your Studio 2 declaration.
#
# A milestone is a *version*, not a pass. Date it, number it, and write why this version exists.

# %% [markdown]
# ## A worked example
#
# Three rows from the restaurant-prices evidence registry, with the
# search log beside them.
#
# | Source | What it is | Status |
# |---|---|---|
# | BLS Consumer Price Index, food away from home | the national series for restaurant prices | verified: opened the table at bls.gov, read the values |
# | BLS Consumer Price Index, all items | the overall-prices comparison series | verified: same route |
# | "Campus dining price study" suggested by an AI sweep | a promising-sounding study | could not retrieve from the citation given: DROPPED |
#
# **Search log lines.** Where: agency site, library database, one
# AI sweep · terms: "restaurant price index", "food away from home
# CPI" · what was found and not found, with dates.
#
# **Map sentence.** Settled: the two national series exist and
# diverge over the period. Missing: any evidence specific to
# campus-area restaurants. **Gap.** "Across what I could retrieve,
# no source describes how menu prices near a campus moved relative
# to overall prices since 2019."
#
# The dropped third row is the point: a source that cannot be
# retrieved is not evidence, however fluent the suggestion was.

# %% [markdown]
# ## Now you, half the way
#
# Your registry needs one more candidate, and this time the AI
# supplies it live: ask your own AI tool for one additional
# published source on your question, with authors, year, and title.
# Take whatever row it returns and decide its status the only way
# that counts, by trying to retrieve it, and write the search-log
# line for the attempt. Then finish the revision sentence: "After
# the map, my Studio 2 declaration changes (or holds) because…"

# %% [markdown]
# ✍️ **Your finish of the faded task.** Double-click and complete it here.

# %% [markdown]
# ## Your starter
#
# Your registry columns: source · what it is · status (verified /
# could not retrieve / pending), with one search-log line per
# search: where, terms, found or not, date.

# %% [markdown]
# ## Step 1
#
# Search deliberately and log every search: where you looked, what terms, what you found and did not.

# %% [markdown]
# ✍️ **Your work for step 1.** Double-click this cell and write your answer here.

# %% [markdown]
# ## Step 2
#
# Verify each source you intend to cite by retrieving and reading it, never by trusting a summary.

# %% [markdown]
# ✍️ **Your work for step 2.** Double-click this cell and write your answer here.

# %% [markdown]
# ## Step 3
#
# Build the evidence map: what is settled, what is contested, what is missing.

# %% [markdown]
# ✍️ **Your work for step 3.** Double-click this cell and write your answer here.

# %% [markdown]
# ## Step 4
#
# Write the revision: how your question changed, or a defended statement of why it did not.

# %% [markdown]
# ✍️ **Your work for step 4.** Double-click this cell and write your answer here.

# %%
# Scratch space — any code this milestone's steps need.

# %% [markdown]
# ## Check yourself
#
# The retrievability audit: take each row marked verified and open
# its source again from the citation alone, as a stranger would.
# A row you cannot reopen goes back to pending, whatever you
# remember about it.

# %% [markdown]
# ## Write your milestone version
#
# Milestone record: `evidence-base-v0`
#
# Record: the version number, today's date, what this version says, and **why it differs from the previous one**. A first version says why you are starting here.

# %% [markdown]
# ✍️ **Milestone version.** Double-click and write it here.

# %% [markdown]
# ## How this milestone is assessed
#
# Each row scores **0**, **1**, or **2**. **10 points total.**
#
# | # | Criterion | 0 | 1 | 2 |
# |---|---|---|---|---|
# | 1 | The milestone artifact exists in full, specific to your own project | absent, or generic text that would fit any project | present but incomplete, or specific in some parts and generic in others | complete and unmistakably about your project |
# | 2 | The milestone is written as a dated, numbered version with its reason | no version, or a version with no reason given | versioned, but the reason is decorative rather than an account of what changed | versioned with a reason a reader could use to reconstruct your thinking |
# | 3 | Every judgment in the artifact is defended by you, not asserted by a tool | conclusions appear with no reasoning, or reproduce a tool's wording | reasoning present but thin where the decision was hardest | each judgment carries a reason you could defend under questioning |
# | 4 | The four rails are carried in the form this studio requires | one or more rails absent where this studio required them | all rails present but one is nominal | every rail addressed in the form this studio requires |
# | 5 | The milestone's own product is present and defensible: An evidence registry of verified sources, your search log, an evidence map, and an explicit revision of your Studio 2 declaration | the milestone's own product is missing | present but would not survive a careful question | present and defensible as stated |

# %% [markdown]
# ## Before you leave
#
# Add this milestone's rows to your **AI Research Ledger** — task, tool, prompt, output summary, decision, verification method, remaining concern, and you as the responsible researcher — and file the artifact above in your **Research Dossier**.
