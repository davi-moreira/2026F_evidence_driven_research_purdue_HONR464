# %% [markdown]
# # Chapter 7 — Research Builds on Research
#
# This is the **companion notebook** of [Chapter 7 — Research Builds on Research](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part2-curiosity-to-design/07-research-builds-on-research.html) from **EDR|AI — Evidence-Driven Research in the Age of AI**. It belongs to the book, not to any course: everything you need is this notebook, the chapter, and free Colab.
#
# [Open the chapter](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part2-curiosity-to-design/07-research-builds-on-research.html) · [Book home](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html) · [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html)
#
# *AI is your arm and your research assistant, not your brain.*

# %% [markdown]
# ## How to use this notebook
#
# 1. Work top to bottom, with the chapter open in another tab.
# 2. Copy each **AI prompt** into your AI tool, run it, then record in the response cell what came back and what you verified.
# 3. Run the code cells; change something and run again.
# 4. Finish the **It is your turn** workspace at the end — that is this chapter's step of your own research project.
# 5. Log every AI use in your **AI Research Ledger**: task · tool · prompt · output summary · decision · verification method · remaining concern · you as the responsible researcher.

# %% [markdown]
# > **The research decision.** Which conversation your question joins, and which of
# > the candidate sources a search or an AI hands you are worth chasing. You decide
# > what goes on the list and what gets dropped. Nothing on that list counts as
# > evidence yet.

# %% [markdown]
# ## Recommended AI prompts

# %% [markdown]
# Commit your own answer first, then delegate. And do not treat these as one-shot
# requests. A search is a loop: you prompt, you read what came back, you tell the tool
# what was off-target and why, and you ask again. Two or three passes beat one long
# prompt every time. Some tools now run that loop themselves, browsing and re-searching
# without asking you between steps. That changes who types the queries; it does not
# change who opens the papers. Each pass earns you a better list. None of them earns
# your trust.

# %% [markdown]
# **Locate.** Ask for leads to chase, not a finished bibliography.
#
# ```text
# Act as a literature scout in [your field]. My question is: [paste it].
# List the five published studies most relevant to it, each with authors,
# year, exact title, and venue, so I can retrieve and verify each myself.
# Only include work you are confident exists; mark anything uncertain.
# ```
#
# *After running, verify:* retrieve every citation by searching its exact title in
# quotes before you believe it exists. Counters **confident fabrication** (a
# real-sounding citation for a paper that was never written).

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **List-to-verify (snowball).** Start from one source you have already read.
#
# ```text
# Here is one source I have verified: [authors, year, exact title, venue].
# Name three older works from its reference list it likely built on, and
# three newer works that likely cite it, each with authors, year, title,
# and venue, plus one line on why it belongs on the chain.
# ```
#
# *After running, verify:* cross-check the "backward" names against the seed's real
# reference list and retrieve the rest. A tidy chain can quietly omit the one
# contradicting study. Counters **illusion of completeness**.

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# **Red-team.** Make the tool attack your gap, not flatter it.
#
# ```text
# Here is my question and the gap I placed: [one or two sentences].
# Argue that this gap is NOT real. Name up to three published studies that
# may already answer it, with authors, year, title, and venue, and say what
# each would have to show to close it. Do not reassure me.
# ```
#
# *After running, verify:* if it just agrees the gap is open and names nothing, push
# back and make it try to close the gap; then retrieve every study it names. Counters
# **sycophantic agreement**.

# %% [markdown]
# ✍️ **Your run.** Double-click this cell and record: what the AI returned (one or two lines), what you verified and how, and your ledger row.

# %% [markdown]
# > **Do not delegate.**
# >
# > Two decisions never leave your hands. Whether a source counts as **verified**: only
# > reading it yourself settles that. And whether your **gap is real**: only retrieval
# > that comes up empty earns the word. What your project may claim follows from those
# > two. An AI can point; it cannot certify.

# %% [markdown]
# ## It is your turn
#
# *You arrived with a lead question from the previous chapter. This step surrounds it
# with the conversation it belongs to: a pool of candidate sources, gathered fast, with
# AI doing the legwork.*

# %% [markdown]
# **Step 1.** Write your lead question at the top of a fresh page. Underneath it, write the one
# sentence you already believe the literature says. That belief is what your search
# will either confirm or embarrass.

# %% [markdown]
# ✍️ **Your work for step 1.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 2.** Search once yourself before you delegate. Use your library database or Google
# Scholar and your question's own words, and keep the single best thing you find.
# That is your seed.

# %% [markdown]
# ✍️ **Your work for step 2.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 3.** Ask an AI for five more candidates on the same question, each with authors, year,
# exact title, and venue. Then run the loop: read what came back, tell the tool which
# two are off-target and why, and ask again. Stop when a pass stops adding anything
# new.

# %% [markdown]
# ✍️ **Your work for step 3.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 4.** Snowball your seed by hand. Read its reference list backward for the older work it
# builds on, and follow its "Cited by" trail forward for the newer work. Add
# everything that touches your question.

# %% [markdown]
# ✍️ **Your work for step 4.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 5.** Put all of them in one candidate list with a status column, and write `lead` in
# every row. Nothing here is a source yet. The next chapter is where they earn the
# promotion.

# %% [markdown]
# ✍️ **Your work for step 5.** Double-click this cell and write your answer here.

# %% [markdown]
# **Step 6.** Log the delegation in your AI Research Ledger, and verify at least one candidate
# now with a named method from the [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html);
# primary-source reading is the one that fits. An AI reviewer may run the check with
# you; the decision to accept or reject stays yours.

# %% [markdown]
# ✍️ **Your work for step 6.** Double-click this cell and write your answer here.

# %%
# Scratch space — use this cell for any code your steps need.

# %% [markdown]
# **Before you leave this notebook:** add today's rows to your AI Research Ledger, and verify your key claim with a named method from the [Verification Guide](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/verification-guide.html). AI can review AI — but the last decision is human.
#
# Next: [Chapter 8 — Finding and Verifying Prior Evidence](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part2-curiosity-to-design/08-finding-and-verifying-prior-evidence.html).
