# %% [markdown]
# # Research Note v1 and Reusable Package
#
# **Milestone M14 · studio notebook**
#
# <hr>
#
# <center>
# <div>
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" width="300"/>
# </div>
# </center>
#
#
# <center>
# <div>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/notebooks/figures/honr_464_logo.png" width="200"/>
# </div>
# </center>
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/ms14_research_note_capsule_student.ipynb)
#
# ---
#
# This is your **writing-studio workbench** for Milestone M14. It is short by design.
# You bring your M9 note v0, the questions the Expo asked (with your M12 defense
# revision record), and your peer's M13 cold-run report; this notebook gives you a
# scaffold that checks the three floors your **note v1** and **reusable package** have
# to clear, prompts to speed up the tedious critique, and the Friday table-read
# protocol you run with a partner. The full brief, rubric, and due date live on
# Brightspace under **M14**.

# %% [markdown]
# > **Book Milestone bridge:** this milestone presents two artifacts.
# > **Book Milestone 9 — Your bounded claims** closes at version 2 (the
# > post-conference bounded note; a *revisit* of your note v0): work from its
# > [milestone page](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/studios/milestone09-write-bound-disclose.html#milestone).
# > And **Book Milestone 11, Your reproducible package** opens at version 1 (the
# > reusable package): work from its
# > [milestone page](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/studios/milestone11-reproduce-and-package.html#milestone).
# > One naming rule to hold: the course's **research note v1** and the book's
# > **Book Milestone 9, version 2** are the same object.

# %%
# Setup — run this cell first.
import numpy as np

SEED = 464  # course number — keeps every resample in this notebook reproducible
rng = np.random.default_rng(SEED)

print("✓ Setup complete — seed", SEED)

# %% [markdown]
# ## 🎯 Definition of Done
#
# You are done with this sprint when your submission carries both halves built from
# **your own** project: **research note v1**, revised where the public test and the
# cold run demand it, and **reusable package v1** with a fresh cold run behind it.
#
# **The research note v1:**
#
# 1. **The five-move spine, revised where the evidence demands it.** Question,
#    one-paragraph method, results with uncertainty in the same eye-span, the bounded
#    headline claim carrying its compass kind and range, then limitations and
#    retrievable references. Grown only where public questioning showed a reader
#    needed more; findings ordered strongest first, the exploratory labeled last.
# 2. **The revision record.** Dated, opening the note: every substantive change tied
#    to the Expo question, criticism hit, or M13 cold-run finding that drove it, and
#    every declined criticism listed with a reason you own. No caveat lost between v0
#    and v1: a sharper sentence is not a bigger finding.
# 3. **The updated claim–evidence table and AI disclosure.** Every changed sentence
#    re-traced to its row, and the disclosure redrafted from the full ledger, naming
#    what you sent to tools and what you did not verify.
#
# **The reusable package (version 1):**
#
# 4. **The five parts, audited.** A README a stranger enters by, the seeded notebook
#    (`SEED = 464`) that passes **restart-and-run-all**, your data or its access
#    recipe, the environment record, and the licence and permissions note with your
#    decision log. Audited against the **five package sins**, with the one sin you
#    found and fixed named.
# 5. **The second cold run.** Any change to the package makes its previous cold-run
#    record stale, so after your **last** change you run it cold once more and record
#    the date, environment, and result, reproducing the **uncertainty statement** and
#    not only the point estimate.
#
# Plus the **AI Research Ledger** rows and the **dossier update line**. At Friday's
# studio a partner table-reads your note v1 and reruns your package cold.
#
# > **A question that often comes up here:** *"I already wrote this note at M9.
# > Isn't v1 just proofreading?"* No, because v0 was written before anyone outside
# > the course had pushed on your claim. Version 1 answers evidence that did not
# > exist then: real questions from real readers at the Expo, and a stranger's cold
# > run of your own package. If nothing needed to change, that is itself a finding,
# > and your revision record must say why the criticism did not move the claim.

# %% [markdown]
# ### 🤝 AI Research Partner
#
# AI is your arm and your research assistant in this sprint, not your brain. This
# week it works as a **writing critic**, not a ghostwriter. A good use looks like
# this: you draft a paragraph, then ask a tool to red-team it, list the citations it
# proposes so you can retrieve each one yourself, or rank your limitations so you can
# check the order against your own interval. A bad use is letting it write your
# discussion, decide which finding leads, or hand you a source you never opened.
#
# **Good to delegate here:**
# - Red-teaming a discussion paragraph **you** already wrote, for any sentence that
#   claims more than your evidence supports.
# - Listing the inputs and steps a cold replicator would need from your package and
#   might not find.
# - Ranking your drafted limitations by how much each threatens the headline, so you
#   can check the ranking against your printed interval.
#
# **Never delegate (these are yours to decide):**
# - Which claim is your headline and how big it is allowed to be.
# - Which sources are real, and the words you put your name on.
# - The wording of your limitations. A caveat you did not reason to is one you cannot
#   defend at the table read.
#
# **Commit first, then ask.** Draft your own sentence before you open a tool, so its
# output has something of yours to disagree with. A cleaner sentence is not a bigger
# finding: keep only edits that leave the claim its size. Verify what comes back, and
# log it in the **AI Research Ledger** below. See
# `ai_resources/human_responsibility_checklist.md` for the full never-delegate list.

# %% [markdown]
# > 💡 **AI Prompt:** "Here is one discussion paragraph from my note and the
# > printout with my headline estimate and its 95% bootstrap interval: [paste the
# > paragraph and the scaffold output]. Act as a hostile reviewer. Name every
# > sentence that claims more than the printed estimate and interval support: a
# > bigger effect, a wider population, or a causal 'drives / causes' where the data
# > only show a relationship. Do not rewrite the sentences. List each over-reach so I
# > fix it myself, then tell me which of your own objections is weakest."
# >
# > **After running, verify (counters *silent scope change*: a sharper sentence that
# > upgrades 'related' to 'causes' has quietly answered a different question):**
# > - [ ] Check each flagged sentence against your printout. The interval is a range
# >   for your estimate, so reject any objection that treats a correlation as a proven
# >   cause, and confirm the bounds it quotes match the numbers your cell printed.
# > - [ ] Keep only edits that shrink a claim to fit the evidence. Reject any rewrite
# >   that makes the sentence bigger, even if it reads better. You own the boundary.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# > 💡 **AI Prompt:** "Here are the key lines of my reusable package and
# > the scaffold's package-sin readout on them: [paste the lines and the printout].
# > Playing a cold replicator who has only these lines, list every input, file, or
# > step you would need to rerun my headline number and might not find here. Then name
# > one reproducibility problem this line-scan can never catch, no matter how many
# > checks I add, that only a person running my package cold would hit."
# >
# > **After running, verify (counters *confident fabrication*: a fluent walkthrough
# > can describe checks the scan does not actually run, or a file that is already
# > present):**
# > - [ ] Match its list of missing inputs against the sins your cell actually
# >   flagged. A gap it names that maps to no real missing line, you drop; a real one
# >   it surfaces, you fix in the package.
# > - [ ] Confirm its "problem the scan cannot catch" is real by rereading your own
# >   package: the scan sees runnable, never *correct*. A clean pass is not proof the
# >   analysis is right, which is why a partner reruns it Friday.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# ### 🛠️ Run It Live: check the three floors your note v1 and package must clear
#
# Run the scaffold below on its default inputs first to see what it does. Then edit
# the **three inputs** at the top with the pieces of *your own* project, and rerun.
# Everything downstream is derived from those three edits, so there is one source of
# truth for every number: change an input once and the whole readout stays
# consistent. The scaffold checks three floors, not ceilings. Clearing them is
# necessary, never sufficient, and the rest of the milestone is where the grade
# lives.

# %%
# --- Note & package self-check — edit ONLY the three inputs below, then rerun.
# Everything after them is DERIVED, so there is one source of truth per number.

# EDIT ME (1) — the per-unit numbers BEHIND your headline finding: one value per
# independent unit (a respondent, a site, a trial). The defaults let the cell run.
headline_values = [4.2, 3.1, 5.0, 2.8, 4.6, 3.7, 5.3, 2.2, 4.0, 3.9,
                   4.8, 2.5, 3.3, 5.1, 4.4, 3.0, 4.7, 2.9, 3.6, 4.1]

# EDIT ME (2) — your synthesis paragraph. Mark each sentence that rests on a real,
# retrieved source with [verified: ...]; leave bare, unsourced claims unmarked.
synthesis_paragraph = (
    "Prior surveys documented the problem in urban settings [verified: retrieved]. "
    "One retrieved study measured part of it directly [verified: retrieved]. "
    "No retrieved work has measured it in the units my frame reaches. "
    "That untouched case is the gap my question closes."
)

# EDIT ME (3) — a few key lines from your package, exactly as they appear in it.
package_lines = [
    "SEED = 464",
    "rng = np.random.default_rng(SEED)",
    'df = load_course_data("your_data.csv")   # provenance + license in the ledger',
    'df = df[df["outcome"].notna()]   # reason: pre-registered complete cases; in the decision log',
]

# ---- everything below is DERIVED from the three edits above ----

# FLOOR 1 — the headline's uncertainty: a seeded 95% bootstrap interval on the mean.
vals = np.asarray(headline_values, dtype=float)
n = len(vals)
boot = np.array([rng.choice(vals, size=n, replace=True).mean() for _ in range(2000)])
lo, hi = np.percentile(boot, [2.5, 97.5])
print(f"FLOOR 1  headline (n = {n}): mean = {vals.mean():.2f}   "
      f"95% interval [{lo:.2f}, {hi:.2f}]   width {hi - lo:.2f}")
print("         Report the interval in the SAME sentence as the estimate.")
print("         A wider interval is a smaller claim, not a failed one.")

# FLOOR 2 — the synthesis floor: evidence density = sourced sentences / all sentences.
parts = [s.strip() for s in synthesis_paragraph.replace("?", ".").replace("!", ".").split(".") if s.strip()]
sourced = [s for s in parts if "[verified" in s.lower()]
density = len(sourced) / len(parts) if parts else 0.0
print(f"\nFLOOR 2  synthesis: {len(parts)} sentences, {len(sourced)} sourced "
      f"-> evidence density = {density:.2f}")
print("         Density is a FLOOR, never proof of quality: it cannot tell")
print("         whether a source actually says what you claim.")

# FLOOR 3 — the package floor: scan the pasted lines for the five package sins.
low = [ln.lower() for ln in package_lines]
joined = "\n".join(low)
sins = []
if any(("/users/" in ln) or ("/home/" in ln) for ln in low):
    sins.append("hard-coded path")
if not any(k in joined for k in ("seed", "random_state", "default_rng")):
    sins.append("missing seed")
if any((".loc[" in ln and "=" in ln) or ("by hand" in ln) for ln in low):
    sins.append("by-hand edit")
filtered = [ln for ln in low if (".drop(" in ln) or ("df[df[" in ln.replace(" ", ""))]
if filtered and not any("reason" in ln for ln in low):
    sins.append("undocumented exclusion")
loads_csv = any("read_csv" in ln for ln in low)
shareable = any(("http" in ln) or ("load_course_data" in ln) for ln in low)
if loads_csv and not shareable and not any(("version" in ln) or ("license" in ln) for ln in low):
    sins.append("stale/unversioned data")
print(f"\nFLOOR 3  package sins flagged: {sins if sins else 'none (runnable, not yet proven correct)'}")
print("         A zero-flag package is RUNNABLE, never proven CORRECT.")
print("         The partner who reruns it cold on Friday is the real proof.")

# %% [markdown]
# ### 🗡️ Red-Team Exchange
#
# The Friday studio's 29–41 minute block. Pair with one partner and run two rounds,
# with an AI reviewer as a third voice. The role for this milestone is the **Research
# Note Reviewer**, which reads the *written genre*: whether every claim carries its
# uncertainty and traces to your evidence (quick card in
# `ai_resources/agent_role_cards.md`; full briefing in
# `genai_studio/roles/research_note_reviewer.md`). It reviews the draft; it never
# writes it, and it cannot run your package.
#
# **First, the Research Note Reviewer pass (before the rounds).** Paste your full
# draft with your compass classification and, for each key number, one line on where
# it comes from. It returns a structure check, an uncertainty-and-limitations check,
# and a traceability check. Every flag is a **suspect you test yourself** against the
# M14 brief, not a verdict, and every missing claim or limitation it names is one
# **you** must write.
#
# **Round 1: attack the note's claims (about 15 minutes).** Your partner table-reads
# your note and leaves two margin notes: your **sharpest sentence** and your
# **weakest claim**. They challenge one claim you cannot trace to a number or a
# retrieved source: "show me the printout that says this headline is 3.9, not 4." You
# defend or concede, then revise so the weakest claim is disciplined by the evidence,
# not cosmetically reworded.
#
# **Round 2: rerun the package cold (about 15 minutes).** Your partner opens your
# package on a fresh kernel and runs **restart-and-run-all**, from your written
# instructions only and with no help from you. They log whether your headline number
# AND its uncertainty statement come back, and where, if anywhere, it broke. A
# package that runs for you and not for them is a finding you fix before Friday
# night, not a failure to hide. And remember the closing rule: any fix you make
# afterward stales this run, so your **second cold run** must be dated after your
# last change.
#
# **Mind the correlated-error trap.** If your AI polished your prose and the Research
# Note Reviewer calls it sound, that agreement is not confirmation your claims are
# bounded. Neither tool ran your package. Only the partner rerun settles whether the
# number reproduces.
#
# **What to log.** Write down the strongest hit you gave and the strongest you got
# back, the margin notes you received, and the one rerun that decided any
# disagreement. A challenge that changed nothing still earns a line saying why it did
# not land. That record is part of what you submit.
#
# > **A question that often comes up here:** *"What if the Research Note Reviewer and
# > my partner disagree about whether a claim is bounded?"* Your evidence settles it,
# > not either of them. The Reviewer read only your text and can miss a naked claim or
# > invent a structural worry; your partner read the page but not your ledger. Say in
# > one sentence which read your own printout and claim ledger support, and why. That
# > adjudication is stronger proof you understand your note than agreeing with a tool
# > would be.

# %% [markdown]
# ### 📒 AI Research Ledger
#
# Log every AI-assisted step in this sprint. One task per row. The **Decision** and
# **Verification method** columns carry the weight: the output is a proposal, and the
# verification is what makes it usable. A missing ledger scores Craft 0 and returns
# the submission (`ai_resources/ai_research_ledger_template.md`).
#
# ### YOUR ANSWER HERE:
#
# | Task delegated | Tool used | Prompt | Output summary | Decision | Verification method | Remaining concern | Responsible researcher |
# |---|---|---|---|---|---|---|---|
# |  |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |  |

# %% [markdown]
# ### ✅ Submission Checklist
#
# Before you submit on Brightspace under **M14**, confirm:
#
# - [ ] **Note v1** complete: the five-move spine intact, grown only where public
#   questioning demanded it; findings ordered strongest first, the exploratory
#   labeled last; no caveat lost between v0 and v1.
# - [ ] **Revision record** dated and opening the note: every substantive change tied
#   to the criticism or cold-run finding that drove it, declined criticisms listed
#   with owned reasons.
# - [ ] **Claim–evidence table updated** and the **AI disclosure redrafted from the
#   full ledger**, including what you sent to tools and what you did not verify.
# - [ ] **Reusable package** assembled with its five parts: README, seeded notebook
#   (restart-and-run-all), data or its access recipe, environment record, licence
#   and permissions note with the decision log.
# - [ ] **The one package sin** you found and fixed in your own package is named.
# - [ ] **Second cold run** recorded, dated after your last change to the package;
#   the headline number and its uncertainty statement both reproduce.
# - [ ] **Table-read margin notes** received (sharpest sentence, weakest claim) and
#   your **revision** disciplining the weakest claim included.
# - [ ] **AI Research Ledger** filled, one row per AI-assisted step, every
#   verification method named and tied to a printout or a retrieved source.
# - [ ] Every claim traces to your evidence and every number reruns from your package.
#   Nothing on the page the ledger does not license.
#
# **Dossier update line.** Record in your Research Project Dossier that your research
# record now carries research note v1 with its revision record, an updated
# claim–evidence table and AI disclosure, and reusable package v1 with its fresh
# cold-run record. Name the file or section where each now lives. That line is your
# bridge into M15, where the note expands into your final chapter, the package meets
# the release audit, and your full-semester ledger becomes the AI-management
# portfolio you defend.
#
# <center>
#
# Thank you!
#
# </center>
