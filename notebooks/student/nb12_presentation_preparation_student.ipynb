# %% [markdown]
# # Presentation Preparation
#
# **Topic 12 · 2 lectures**
#
# <hr>
#
# <center>
# <div>
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" width="300"/>
# </div>
# </center>
#
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/nb12_presentation_preparation_student.ipynb)
#
# ---

# %% [markdown]
# ## 🧭 Inquiry & Claim Boundary
#
# **Inquiry emphasis:** all positions (spoken delivery). Your board is printed and
# cannot change. What can still change is what comes out of your mouth beside it,
# and that is now the only place your claim can drift. A **compass position** is
# the kind and reach of the question your project answered. Example: a descriptive
# question about the cases you observed, not a causal claim about why.
#
# **Design pathway:** cross-cutting (communication under time pressure). A
# **cross-cutting** week adds no new design. This week's habit is that the short
# version of your finding stops exactly where the long version stops.
#
# | | |
# |---|---|
# | **A claim this topic PERMITS** | "My thirty-second version and my two-minute version use the same verb and state the same boundary. When asked something my design cannot settle, I say so and offer the smaller claim it does settle." |
# | **A claim this topic does NOT permit** | "Broadly, yes, it would hold elsewhere," said in a hallway to be agreeable. A concession the evidence never licensed is the same defect as an overstated poster, delivered faster. |
#
# **Where this sits in the course:** Week 12, the second week of the conference
# block. The poster locked over the weekend and went to print. This week you build
# the spoken editions and the question strategy, rehearse at the printed board on
# Friday, and submit the **go-public package (M14) at the Friday studio**. Next
# Monday is the dress rehearsal, and the Expo follows the day after. The dates are
# on the schedule page.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Write and time the **three spoken architectures**, each against a word
#    ceiling that stands in for a clock you do not control.
# 2. Keep a **boundary sentence** intact at all three lengths, and detect the
#    **spoken upgrade** when compression strengthens a verb.
# 3. Write an **audience analysis** that names who stops, what they already
#    believe, and what they will do with your answer.
# 4. Derive the **predictable question set** from your own design before anyone
#    asks it, and sort each question into a bound request or an attack.
# 5. Deliver the honest "my design cannot settle that" together with the
#    **smaller true claim** it does settle.
# 6. Direct an AI assistant to generate the questions your board invites, then
#    discard the ones your board does not actually invite.

# %%
# Setup — run this cell first.
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)
plt.rcParams["figure.figsize"] = (9, 5)

SEED = 464  # course number — keeps anything you simulate here reproducible
rng = np.random.default_rng(SEED)

# Data loads: GitHub raw URL first (works in Colab), local repo path as fallback.
DATA_URL = ("https://raw.githubusercontent.com/davi-moreira/"
            "2026F_evidence_driven_research_purdue_HONR464/main/notebooks/data/")

def load_course_data(filename):
    """Load a course dataset from GitHub, falling back to the local repo copy."""
    try:
        return pd.read_csv(DATA_URL + filename)
    except Exception:
        from pathlib import Path
        local = Path("notebooks/data") / filename
        if not local.exists():
            local = Path("../data") / filename
        return pd.read_csv(local)

print("✓ Setup complete — seed", SEED)

# %% [markdown]
# # Lecture 1

# %% [markdown]
# 🗺️ **Today's frame (Monday, 10 / 21 / 12 / 7):** open with the 📣 **lab meeting**: one reporter, one decision from their own project, the room's questions · then the 🧩 puzzle and 🔮 **Predict First** · investigate with 🛠️ **Run the Study** and your AI · verify with 🔍 **Read the Evidence** · drill 📝 **Practice** aloud and take ⚖️ **Make a Design Choice** · close in the room with 🎯 **Take It to Your Project**, 🛡️ **Defend Your Decision**, and your 📒 ledger row. All seven moves happen in class; 🏠-marked items and everything below the ⏸ line are optional depth.

# %% [markdown]
# ### 📣 Lab Meeting: Today's Reporter
#
# *This lecture opens with a ten-minute lab meeting. One of you is today's reporter: you bring a decision from your **own** project, the room questions it, and none of it is graded on how it goes. Fill in **📣 My Report Plan** below before class: lines 1 to 4 if the slot is yours, line 5 if it is not.*
#
# **The lab meeting (minutes 0–10).** Seven minutes for the reporter: the decision you reached since the last lab meeting, the evidence behind it, and the part you are least sure of. Three minutes for the room's questions. Your instructor keeps time and takes over the lesson at minute 10.
#
# **Where this lecture goes.** *(Your instructor leads from minute 10.)* The board is printed and gone. The only thing that can still
# move is what you say beside it. By minute 50, everyone has a thirty-second
# version written and counted. Everyone can also name the word it was upgrading,
# and the sentence they keep at every length.
#
# **Run of show (Monday: 10 / 21 / 12 / 7).**
#
# | Min | Section | What you do |
# |---|---|---|
# | 0–10 | 📣 Lab meeting | Today's reporter brings one decision from their own project and what backs it (7 min); the room questions it (3 min). |
# | 10–31 | Research puzzle + guided AI investigation | Your instructor puts the scan cell's two versions of one finding on the board and reads both aloud. Then everyone answers the puzzle below in writing, by minute 6. Which version did you lie in, and which one word did the upgrading? Three answers are taken aloud, and "they mean the same thing" is refused. The block closes by asking who can already hear themselves saying the short version at the Expo. Hands, not names. **Hard stop 9.** **If short:** two written answers are read aloud instead of waiting for volunteers. Then section 1 runs in its own order: the three ceilings, the boundary sentence, the spoken upgrade. Everyone is held to the 🔮 **Predict First** commitments before any counting starts. Your instructor runs the 🛠️ scan cell and reads its closing summary aloud, down to the last printed line. Then everyone pastes their own thirty-second draft in as `short_version` and runs it again. The block closes on Exercise 1 in 🔍 **Read the Evidence**. **Hard stop 31.** **If short:** everyone writes Exercise 1 questions 1 and 2, and question 3 is taken aloud. |
# | 31–43 | Verification + formalization | Section 2 first: the audience paragraph, three lines naming the three things, plus the block their hand points at. By 34, your instructor splits the room for 📝 **cut it twice**. Half take Cut A and half take Cut B, cutting the scan cell's 264-word version down to seventy-five; an odd person takes Cut B. Trade pages at 38, and each pair writes what Cut B cost. Those pages go to your instructor for the formalization, then the ⚖️ committed line is taken. **Hard stop 43.** **If short:** the trade is held to sixty seconds a pair and ⚖️ stays whole. |
# | 43–50 | Decision and defense | At 43 everyone sends the 🤖 upgrade check, so it runs while your instructor talks. Short is the thirty-second draft; long is the poster text if no two-minute one exists. Your instructor takes the 🎯 sentence, then goes round for 🛡️, two of the four lines aloud each. Read the flags and write the third 🔬 answer. The block closes on the 📒 ledger row and a spoken Claim Ticket, ten seconds each. **Hard stop 50.** **If short:** nothing back by 47 means you answer 🔬 from your own short version and say so in the ledger. |
#
# **Three questions that keep the room thinking.** Your instructor asks these; they wait in **🔎 Questions to Keep You Thinking**, just past the puzzle, so nobody reads what to listen for before committing an answer. Each one carries the minute to ask it.
#
# **One AI trap to watch for.** The prompt forbids a rewrite. If a polished version
# comes back anyway, do not paste it into your draft and do not read it aloud. A
# tighter sentence can also be a wider one. The flags are the only part you asked
# for, so take the flags and leave the prose.
#
# **Checkpoints.** By minute 9, one word is circled on every page. By minute 31,
# everyone has run the scan on their own thirty-second draft. By minute 43, every
# page holds a seventy-five-word cut and one sentence marked keep at every length.
# By minute 50, the ledger row is written and the Claim Ticket has been said
# aloud. Everyone leaves with one word saved for Wednesday, the one they hope
# nobody presses on.
#
# **Make it yours.** Your report is yours to stage: bring the decision you are
# least sure of, or the one that moved furthest since the last lab meeting. Your
# instructor has room to stage the lesson too. The scan cell carries a worked pair
# about patrols and trust in police, which can go on the board so the scan
# confirms what the room circled by ear. Or two versions can be written in a field
# this room cares about. 📝 **cut it twice** can also run as a race, with
# the two halves scoring each other on the boundary sentence, not on the word
# count. In **📣 My Report Plan** below, name the decision you are bringing and the question you want the room to answer.
#
# **Submitting.** You work this notebook in class. Submit it once a week, by 11:59 PM on the Sunday that ends the studio week, on the course platform. It is graded on completion: worked through and handed in, never on whether your answers came out right.

# %% [markdown]
# ### 📣 My Report Plan
#
# *If this lecture's lab-meeting slot is yours, fill lines 1–4 in before class. If it is not, fill in line 5, so you arrive with a real question. Either way the whole notebook is submitted at the end of the week on the course platform, and it is graded on completion.*
#
# Your report is seven minutes on **your own project**, not on this lecture's topic. You are the only person in the room who has been inside it, so there is no answer here you can get wrong.
#
# **1. The decision I am bringing** *(one my project has actually reached since the last lab meeting):*
#
#
# **2. The evidence behind it** *(the ledger row, the number, the source, or the check that licenses it):*
#
#
# **3. Where it is still uncertain** *(the part I would most like a second pair of eyes on):*
#
#
# **4. The question I want the room to answer for me:**
#
#
# **5. If I am not reporting today, the question I will ask the reporter:**

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(minutes 10–31, opening the investigation block)*
# *(Your instructor opens this right after the lab meeting. Think it through and
# commit an answer before we go further. No AI yet.)*
# A visitor gives you thirty seconds. A judge gives you two minutes. Both hear a
# version of the same research.
#
# Here is the trap. Qualifiers are long and verbs are short. When you cut for time,
# the qualifier goes first because it is where the words are, and what survives is
# a stronger sentence than the one you started with. Nobody decides to overstate.
# The clock does it.
#
# So the question for this lecture is: **if your short version says more than your
# long version licenses, which one did you lie in?**

# %% [markdown]
# ### 🔎 Questions to Keep You Thinking
#
# *Your instructor asks these as the lecture runs. Every item below opens with an **Ask after:** line naming the moment where that question belongs, so read each one only when its **Ask after:** point arrives rather than reading this cell straight through.*
#
# **Three questions that keep the room thinking.**
#
# 1. **Ask after:** the audience paragraph in section 2 is written, minute 34.
#    *"An undergraduate expo draws mostly non-specialists. What does that
#    change?"* Listen for: the first sentence changes, the claim does not.
#    Strangers need the question; specialists need the contribution. If silence:
#    ask what their opening sentence assumes a listener already knows. Watch out
#    for: widening a claim in the hallway to keep the conversation pleasant.
# 2. **Ask after:** both 📝 cuts are written and traded, minute 39.
#    *"A shorter pitch has to drop something. What may it drop, and what may it
#    never drop?"* Listen for: it may drop whole ideas, the setup, the second
#    finding; it may never drop a bound attached to whatever survives. If silence:
#    ask which of the two cuts they would be willing to hear quoted back to them.
#    Watch out for: "the hedges slow it down", which is a weakened claim sold as
#    style.
# 3. **Ask after:** the ⚖️ line is written, before it is spoken, minute 42.
#    *"The sentence you keep at every length: the finding, or the bound?"* Listen
#    for: a defended choice rather than a default. A visitor who leaves with your
#    finding and no bound repeats something you cannot defend. If silence: ask
#    what that visitor would say about the project back at their own lab. Watch
#    out for: keeping the finding only because it is the interesting sentence.

# %% [markdown]
# ## 1. Three Architectures, Not One Speech Cut Three Ways
#
# *(minutes 9–31)*
#
# Each length is a different job. A thirty-second pitch is not a two-minute pitch
# with the middle removed.
#
# | Length | Ceiling | The job |
# |---|---|---|
# | **30 seconds** | ≤ 75 words | Earn the next ninety seconds |
# | **90 seconds** | ≤ 200 words | The finding, with its bound |
# | **2 minutes** | ≤ 300 words | The finding, the bound, and the choice you would defend |
#
# **Word ceiling.** A stand-in for a clock you do not control. Example: at a normal
# speaking pace, 75 words runs about thirty seconds. If your "thirty-second"
# version is 110 words, it runs closer to fifty, and by then your visitor has read
# the board themselves and stopped listening to you.
#
# **Boundary sentence.** The one line that says where your evidence stops. It
# appears at **all three lengths**, in the same words. It is the first thing people
# cut and the last thing they should.
#
# **Spoken upgrade.** A verb, quantifier, or scope word that gets stronger when the
# version gets shorter. Example: "is higher among" becomes "raises"; "in this
# sample" quietly disappears. The upgrade is almost never deliberate, which is
# exactly why you check for it mechanically rather than trusting your ear.
#
# > **A question that often comes up here:** *"Isn't a thirty-second version
# > supposed to be simpler?"* Simpler, yes. Broader, no. Simplifying means fewer
# > ideas said plainly. Broadening means the same idea said about more of the
# > world than you looked at. The two feel identical while you are writing and are
# > completely different when someone repeats you.

# %% [markdown]
# ### 🔮 Predict First
#
# Before you draft anything, commit in writing:
#
# 1. Say your finding aloud once, the way you would to a visitor who has thirty
#    seconds. Write down what you said, then guess its word count and how far off
#    that guess will turn out to be.
# 2. Which word in your finding do you expect to get stronger under compression?
#    Write it down now, before you compress anything.
#
# You are about to check both mechanically.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# 1. Estimated word count, and how far off I expect to be:
# 2. The word I expect to strengthen under compression:

# %% [markdown]
# ### 🛠️ Run It Live: counting words and catching the upgrade
#
# The next cell does two things a human ear does badly. It counts, and it compares
# two versions of the same claim word by word against a list of strength markers.
#
# Two worked versions sit in the cell so the scan has something to work on. Swap
# in your own drafts as soon as they exist, then run it again.

# %%
# Two versions of the same finding, as they are usually first drafted.
long_version = (
    "The question behind this board is whether neighbourhoods with regular "
    "patrols report higher trust in police, and how far an answer to that "
    "question can honestly travel. The data are a national survey of ten "
    "thousand respondents, who each rated their trust in several institutions "
    "on a seven-point scale and also rated how responsive they find their "
    "government. The comparison on the board sets people who report regular "
    "patrols against people who do not. In this sample, trust in police runs "
    "about one point higher on that seven-point scale among the first group. "
    "The gap is well located: the interval around it is roughly plus or minus "
    "six hundredths of a point, so the number itself is not the fragile part "
    "of the story. The fragile part is what the number is allowed to mean. "
    "This is an observational comparison. Nobody assigned patrols to "
    "neighbourhoods, so the two groups may differ in many ways that were never "
    "measured. That means the result does not establish that patrols caused "
    "the difference in trust. The most obvious rival explanation sits in the "
    "data itself: people who rate their government as responsive report higher "
    "trust in police and are also more likely to live where patrols are "
    "regular, so responsive government may drive both sides of the "
    "association. To move from this comparison to a claim about what patrols "
    "do, the assignment would have to change, not the sample size. What the "
    "board reports, then, is a well-measured association in one survey, with "
    "its bounds attached and its rival explanation named rather than hidden."
)
short_version = (
    "Patrols raise trust in police by about one point on a seven-point scale. "
    "It is a big effect and it shows up clearly in a large national survey."
)

# Strength markers: words that assert more than an association.
STRONG = {"raise", "raises", "raised", "cause", "causes", "caused", "effect",
          "impact", "drives", "boosts", "proves", "always", "every", "clearly",
          "significantly", "big", "substantial"}
# Hedges and scope markers: the words compression eats first.
HEDGE = {"associated", "association", "observational", "does", "not", "may",
         "about", "roughly", "interval", "sample", "suggests", "appears",
         "correlation", "correlated"}

def scan(text, label):
    words = re.findall(r"[a-z']+", text.lower())
    strong = sorted({w for w in words if w in STRONG})
    hedge = sorted({w for w in words if w in HEDGE})
    return {"version": label, "words": len(words),
            "strength markers": ", ".join(strong) or "—",
            "hedges/scope": ", ".join(hedge) or "—"}

report = pd.DataFrame([scan(long_version, "2-minute (≤300)"),
                       scan(short_version, "30-second (≤75)")])
print(report.to_string(index=False))
print()

lw = {w for w in re.findall(r"[a-z']+", long_version.lower()) if w in STRONG}
sw = {w for w in re.findall(r"[a-z']+", short_version.lower()) if w in STRONG}
gained = sorted(sw - lw)
lost_hedges = sorted({w for w in re.findall(r"[a-z']+", long_version.lower()) if w in HEDGE}
                     - {w for w in re.findall(r"[a-z']+", short_version.lower()) if w in HEDGE})
print("Strength words the SHORT version gained:", ", ".join(gained) or "none")
print("Hedge/scope words the SHORT version dropped:", ", ".join(lost_hedges) or "none")
print()
print("Compression may drop blocks. It may not drop bounds." if gained or lost_hedges
      else "No upgrade detected on this word list.")

# %% [markdown]
# ### 🔍 Read the Evidence
#
# The scan is a word list, not a judge. It cannot tell you whether "clearly" is
# dishonest in your sentence; it can only tell you the short version has it and the
# long one does not.
#
# **Exercise 1.** Answer in two or three sentences each.
#
# 1. Which strength words did the short version gain, and what does each of them
#    claim that the long version deliberately refused to claim?
# 2. The short version dropped several hedges. Which single dropped word does the
#    most damage, and why that one?
# 3. Give one example of a word on the STRONG list that would be perfectly honest
#    in a different project. What would have to be true of the design?

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# 1.
# 2.
# 3.

# %% [markdown]
# ## 2. Who Is Standing There
#
# *(minutes 31–50)*
#
# Before the pitches, write the paragraph they are addressed to.
#
# **Audience analysis.** One paragraph naming three things: who stops at your
# board, what they already believe about your question, and what they will do with
# your answer. Example: at an undergraduate research expo, a large share of people
# who stop are faculty from unrelated fields and family members of other
# presenters. Neither group knows your literature. Both can tell instantly whether
# your sentence and your figure agree.
#
# That paragraph decides your first sentence. A room of specialists needs the
# contribution; a room of strangers needs the question. Most of your visitors will
# be strangers.
#
# > **A question that often comes up here:** *"How can I write an audience analysis
# > for people I have never met?"* You are not predicting individuals. You are
# > naming what the setting makes likely: an undergraduate research event draws
# > mostly non-specialists who are moving between boards. That is enough to decide
# > whether you open with your contribution or your question, which is the only
# > decision the paragraph has to support.
#
# **Poster integration.** Which block your hand points at, and when. A pitch that
# never touches the board leaves the board doing nothing, and a visitor who is
# never shown where a number lives has no way to check it. Write the hand
# movements into the plan; you will not invent them under pressure.

# %% [markdown]
# ### 📝 Practice: cut it twice
#
# Take the two-minute version from the scan cell and cut it to seventy-five words
# twice.
#
# - **Cut A: drop blocks.** Remove whole ideas. Keep every qualifier attached to
#   whatever survives.
# - **Cut B: weaken bounds.** Keep every idea. Shorten by removing hedges and scope
#   markers.
#
# Then write one sentence naming what Cut B cost that Cut A did not.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# Cut A (≤75 words, blocks dropped):
#
# Cut B (≤75 words, bounds weakened):
#
# What Cut B cost:

# %% [markdown]
# ### ⚖️ Make a Design Choice
#
# Commit, in writing, to the sentence you will not cut at any length.
#
# Most people pick the finding. Consider picking the boundary instead. A visitor
# who leaves with your finding and no bound will repeat a claim you cannot defend;
# a visitor who leaves with your bound and a vaguer finding will repeat something
# true.
#
# One line, defended aloud:
#
# > "The sentence I keep at every length is ______, because ______."

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# The sentence I keep at every length is … because …

# %% [markdown]
# ### 🎯 Take It to Your Project
#
# One sentence:
#
# > "During my thirty-second version my hand points at ______, and the word I
# > caught myself upgrading is ______."

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# During my thirty-second version my hand points at … and the word I caught myself
# upgrading is …

# %% [markdown]
# ### 🛡️ Defend Your Decision
#
# Four one-liners, spoken, in about a minute:
#
# 1. My counted word totals at all three lengths, said as numbers.
# 2. My boundary sentence, said in the same words I will use on Tuesday.
# 3. The block my hand lands on first, and why that one.
# 4. The word my draft was upgrading, and what I replaced it with.

# %% [markdown]
# ### 🤖 AI Prompt — the upgrade check across your own drafts
#
# Paste this into your AI assistant with your own drafts. This is the lecture's one
# live prompt.
#
# > 💡 **AI Prompt:** "Here are two versions of the same research claim, written
# > by me. LONG, two minutes: [paste]. SHORT, thirty seconds: [paste]. The design
# > behind them is: [one line, what kind of comparison produced the number]. Do
# > not rewrite either version. List every verb, quantifier, or scope word that is
# > stronger in the SHORT version than in the LONG one, and every hedge or scope
# > marker present in the LONG version and absent from the SHORT one. For each,
# > say in one clause what the short version now claims that the long one does
# > not."
#
# **After running, verify:**
#
# - [ ] Check every flagged word against your own claim–evidence table. A flag is a
#       hypothesis about your sentence; you decide.
# - [ ] Check for false positives: a strong word your design genuinely licenses is
#       not an upgrade, and dismissing it is a decision you record.
# - [ ] Check what it missed by reading your short version once more, looking only
#       at the verb.
# - [ ] Count the words yourself. Do not accept a count from a tool.
# - [ ] Record a row in your AI Research Ledger: what you delegated, what came
#       back, what you accepted, what you overruled, and how you checked.

# %% [markdown]
# ### 🔬 Interrogate the Output
#
# Before you use the flags, take them apart.
#
# 1. Did the tool use my stated design, or only my sentences? A flag that ignores
#    the design is a claim about English, not about evidence.
# 2. Which flag would embarrass me if a methods reviewer heard my short version
#    next to my poster?
# 3. Which word did it leave alone that I have been quietly hoping nobody would
#    press on?
#
# Write the third answer down. That word is Wednesday's question.

# %% [markdown]
# ### 📒 AI Research Ledger
#
# The row for this lecture, written before you leave.
#
# | Field | Your entry |
# |---|---|
# | Task delegated | Upgrade check across my 30-second and 2-minute drafts |
# | Tool used | |
# | Prompt | |
# | Output summary | |
# | Decision | Flags accepted; flags overruled |
# | Verification method | Checked each flag against my claim–evidence table; counted words by hand |
# | Remaining concern | |
# | Responsible researcher | You |
#
# **Claim Ticket (spoken).** "The sentence I keep at every length is ______, and
# the word I caught myself upgrading is ______."

# %% [markdown]
# ---
#
# ### ⏸ Optional depth from here
#
# **Today's lecture path is complete.** Anything between this line and the next lecture heading is optional depth: run it if you want to push the ideas further. Nothing below this line is required, and any 🏠-marked prompt above it is optional too.

# %% [markdown]
# > 💡 **AI Prompt:** **🏠 Optional depth.** "Here is my ninety-second pitch:
# > [paste]. Here is my boundary sentence: [paste]. Tell me, in one sentence,
# > whether a listener who heard only this pitch would be able to state my
# > boundary. Do not rewrite the pitch and do not suggest wording."
#
# **After running, verify:** read the pitch aloud to one person and ask them to
# state your boundary back to you. A listener beats a model on this question, and
# the model's answer is only a prompt to go and check. Record the run in your
# ledger.

# %% [markdown]
# # Lecture 2

# %% [markdown]
# 🗺️ **Today's frame (Wednesday, 10 / 20 / 12 / 8):** open with the 📣 **lab meeting**: one reporter, one decision from their own project, the room's questions · then the 🧩 challenge, a spoken 📝 **Practice** retrieval drill, and 🔮 **Predict First** · attack the problem with 🛠️ **Run the Study**, 🔁 modifying the prompt and 🔬 interrogating what comes back · verify with 🔍 **Read the Evidence** · defend ⚖️ **Make a Design Choice** to your peers, AI closed at the 🧑‍⚖️ checkpoint · close with 🎯 **Take It to Your Project**, 🛡️ **Defend Your Decision**, and your 📒 ledger row. All seven moves happen in class; 🏠-marked items and everything below the ⏸ line are optional depth.

# %% [markdown]
# ### 📣 Lab Meeting: Today's Reporter
#
# *This lecture opens with a ten-minute lab meeting. One of you is today's reporter: you bring a decision from your **own** project, the room questions it, and none of it is graded on how it goes. Fill in **📣 My Report Plan** below before class: lines 1 to 4 if the slot is yours, line 5 if it is not.*
#
# **The lab meeting (minutes 0–10).** Seven minutes for the reporter: the decision you reached since the last lab meeting, the evidence behind it, and the part you are least sure of. Three minutes for the room's questions. Your instructor keeps time and takes over the lesson at minute 10.
#
# **Where this lecture goes.** *(Your instructor leads from minute 10.)* By minute 50, everyone has typed the questions their board
# invites, and has delivered one honest "my design cannot settle that" with the
# smaller claim behind it.
#
# **Run of show (Wednesday: 10 / 20 / 12 / 8).**
#
# | Min | Section | What you do |
# |---|---|---|
# | 0–10 | 📣 Lab meeting | Today's reporter brings one decision from their own project and what backs it (7 min); the room questions it (3 min). |
# | 10–30 | Retrieval and challenge + applied AI laboratory | **Your instructor says:** one thing a shorter pitch may honestly drop, and one thing it may not. Two answers are taken and the matter is left unsettled. This drill is spoken and has no cell. **Then** the 🧩 puzzle is read aloud and the writing starts. **Everyone produces:** one written line naming the question their board most invites that their design cannot settle. **Hard stop 7.** **If nobody writes:** your instructor says one line first, then restarts the clock. **The rule of the hour:** a question counts only if it is grounded in what the pitch said or in a ledger row. Everyone opens their poster text now, so the 🤖 paste at 25 is instant. **Run in cell order:** 🔮 Predict First to 11, the 🛠️ cell on the ten collected questions to 14 (it returns four attacks, four bound requests, two ambiguous), 🔍 Exercise 2 to 19, the 📝 four-second answers to 22, the ⚖️ concession line to 25. **Then 🎯 and 🛡️ are skipped,** the 🤖 prompt and the 🔁 rerun with the design line run, and the block stops at 30. **If behind:** your instructor cuts 🔍 items 2 and 3 first, then 📝 prompts B and C. **If a run has not returned by 29:** close the tool, and everyone writes which of their own questions they expected the design line to remove. |
# | 30–42 | Peer defense, then synthesis and accuracy lock | **Three pairs, one stance a round.** Round one is the hurried visitor already moving to the next board. **Each round:** ninety-second pitch, two minutes of questions, switch at 34. Round two is the friendly visitor who wants to agree with you. **Every presenter says "my design cannot settle that" once,** with the smaller claim behind it. **If the count is odd:** your instructor takes the open seat as questioner instead of presenting. **At 38** everyone marks their 🔮 list against what was actually asked, each pair reports one concession it heard, and your instructor says which ones the evidence licensed and confirms the corrected version aloud while everyone repairs their own ⚖️ line. |
# | 42–50 | Project transfer | **Scroll back up** for the 🎯 sentence to 44, then the 🛡️ four one-liners, written, with each person saying one of them aloud, to 46. **Tools closed** for the 🧑‍⚖️ checkpoint to 49, item 3 included: the Expo answer said once, out loud, to nobody. **Close** with the 📒 ledger row and a spoken Claim Ticket. **If behind:** your instructor cuts the 🛡️ spoken round to three voices rather than shortening the checkpoint. |
#
# **Three questions that keep the room thinking.** Your instructor asks these; they wait in **🔎 Questions to Keep You Thinking**, just past the puzzle, so nobody reads what to listen for before committing an answer.
#
# **One AI trap to watch for.** A generated question list feels like the room. It
# is a guess built from your board's text alone. The danger is the question it
# leaves out, because absence reads as safety. Have everyone check what the tool
# did not generate, and retype at least one of its labels by hand.
#
# **Checkpoints.** By minute 7, every written guess at the unanswerable question is
# committed. By minute 30, everyone has three typed questions and a note of which
# ones the design line moved. By minute 38, every presenter has said "my design
# cannot settle that" once and offered the smaller claim behind it. By minute 42,
# any untrue concession is named and corrected on everyone's own record. By minute
# 50, everyone has the concession they refuse to make and the question they will
# open with.
#
# **Make it yours.** Your report is yours to stage: bring the decision you are
# least sure of, and say plainly what you want the room to test. Your instructor
# has room to stage the lesson too. A third visitor stance can be written and
# handed to one pair, so one round is questioned by someone nobody expected. Or
# round one can run with the questioner allowed to ask only what the ninety
# seconds actually said. In **📣 My Report Plan** below, name the decision you are bringing and the question you want the room to answer.
#
# **Submitting.** You work this notebook in class. Submit it once a week, by 11:59 PM on the Sunday that ends the studio week, on the course platform. It is graded on completion: worked through and handed in, never on whether your answers came out right.

# %% [markdown]
# ### 📣 My Report Plan
#
# *If this lecture's lab-meeting slot is yours, fill lines 1–4 in before class. If it is not, fill in line 5, so you arrive with a real question. Either way the whole notebook is submitted at the end of the week on the course platform, and it is graded on completion.*
#
# Your report is seven minutes on **your own project**, not on this lecture's topic. You are the only person in the room who has been inside it, so there is no answer here you can get wrong.
#
# **1. The decision I am bringing** *(one my project has actually reached since the last lab meeting):*
#
#
# **2. The evidence behind it** *(the ledger row, the number, the source, or the check that licenses it):*
#
#
# **3. Where it is still uncertain** *(the part I would most like a second pair of eyes on):*
#
#
# **4. The question I want the room to answer for me:**
#
#
# **5. If I am not reporting today, the question I will ask the reporter:**

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(minutes 10–30, opening the applied laboratory)*
# *(Your instructor opens this right after the lab meeting. Commit an answer
# before we go further. No AI yet.)*
# A visitor asks the one question your design cannot answer.
#
# You have about four seconds before you start talking, and in those four seconds
# two things are competing. One is the true answer, which is that your study cannot
# settle it. The other is the agreeable answer, which costs nothing to say, makes
# the conversation pleasant, and gives away everything you spent the semester
# bounding.
#
# Commit in writing, now, before the rotation: **what is the question your board
# most invites that your design cannot settle?** You will find out in forty minutes
# whether you guessed right.

# %% [markdown]
# ### 🔎 Questions to Keep You Thinking
#
# *Your instructor asks these as the lecture runs. Every item below opens with an **Ask after:** line naming the moment where that question belongs, so read each one only when its **Ask after:** point arrives rather than reading this cell straight through.*
#
# **Three questions that keep the room thinking.**
#
# 1. *"Is that a bound request or an attack?"*
#
#    **Ask after:** the 🛠️ table is on screen and every 🔮 list is written, about minute 14.
#
#    Listen for: a bound request asks how far the claim reaches, and is answered by
#    stating the boundary you already wrote. An attack says something is wrong, and
#    is answered by naming the check you already ran. Watch out for: defending
#    against a bound request, which turns a curious visitor into an opponent you
#    created. If silence: read one ambiguous row aloud and ask what the visitor
#    would have to add for you to know which one you are facing.
#
# 2. *"The visitor is friendly and you want to agree. What does the agreeable yes cost?"*
#
#    **Ask after:** every ⚖️ concession line is written, about minute 25.
#
#    Listen for: it gives away a claim the evidence never licensed, and it travels
#    without you. Watch out for: "it was only a hallway conversation." The person
#    repeating you tomorrow never saw your board. If silence: ask who the friendly
#    visitor repeats you to, and what that person says next.
#
# 3. *"Does saying 'my design cannot settle that' make you look weak?"*
#
#    **Ask after:** the first round of the rotation ends, at minute 34.
#
#    Listen for: the opposite, because only someone who knows exactly what their
#    design does can say it. Watch out for: the sentence used as an exit, with no
#    smaller true claim behind it. Stopping is honest; stopping and offering
#    nothing is not. If silence: ask what was offered instead, and whether the
#    design licenses that.

# %% [markdown]
# ## 3. The Questions You Can Predict
#
# *(minutes 7–42)*
#
# Most of the questions you will get on Tuesday are derivable today, from your
# design, without anyone asking them.
#
# **The predictable question set.** The three questions a given board always
# attracts, derived from what the design cannot do. Example: an observational
# comparison always attracts "but could something else explain that?"; a
# convenience sample always attracts "would this hold anywhere else?"; a
# self-reported outcome always attracts "do people actually do what they say?"
#
# **Bound request against attack.** A **bound request** wants to know where your
# evidence stops. An **attack** claims your evidence is wrong. They sound similar
# and need opposite answers: a bound request is answered by stating the boundary
# you already wrote; an attack is answered by naming the check you already ran.
# Reading the type correctly is most of the skill.
#
# **The smaller true claim.** What you offer when the honest answer is that your
# design cannot settle the question. Example: "My design cannot tell you whether
# the programme caused this. What it does establish is that among the people I
# observed, the gap is this size and it is not explained by the two measures I was
# able to adjust for."
#
# **Audience-directed questions.** The questions *you* ask the visitor. They turn a
# monologue into a conversation and, more usefully, they tell you what the person
# actually heard. Example: "Before I go on, what did you take the main finding to
# be?"
#
# > **A question that often comes up here:** *"Doesn't saying 'my design cannot
# > settle that' make me look like I did not do enough?"* It reads as the opposite
# > to anyone who knows the field, because the sentence is only available to
# > someone who knows exactly what their design does. What reads as weak is a
# > confident answer that a follow-up question dismantles.

# %% [markdown]
# ### 🔮 Predict First
#
# Before the rotation, commit in writing:
#
# 1. Write the three questions you expect. Beside each, mark **bound request** or
#    **attack**.
# 2. Write the one question you expect nobody to ask, and that you would find
#    hardest.
#
# At the end of the session you will compare your list against what the room
# actually asked. The gap between the two is the most useful thing you take to
# Tuesday.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# 1. Q1 … [bound request / attack] · Q2 … [ / ] · Q3 … [ / ]
# 2. The question I most fear:

# %% [markdown]
# ### 🛠️ Run It Live: typing the questions a real board attracted
#
# Below is a set of questions collected at a poster session, together with the
# board's design. The next cell types each one and reports what the mix says about
# which part of the board is doing the least work.
#
# Replace the list with the questions your panel actually asks you today, and
# rerun. The rerun is the raw material for your question strategy.

# %%
# Questions asked at a board reporting an observational trust gap.
questions = [
    "Could responsive government be causing both of these?",
    "How far does this reach beyond the people you surveyed?",
    "What is that interval on the headline, exactly?",
    "Did you check whether the result holds if you drop the youngest respondents?",
    "Isn't self-reported trust a pretty weak measure?",
    "Would this replicate in another country?",
    "Which comparison produced the one-point number?",
    "Are you claiming patrols work?",
    "So what should a city do with this?",
    "Why trust in police, and not something else?",
]

# A question is a BOUND REQUEST when it asks how far the claim reaches;
# an ATTACK when it asserts something is wrong or missing.
BOUND_CUES  = ("how far", "beyond", "reach", "replicate", "another",
               "exactly", "which comparison", "what is that")
ATTACK_CUES = ("isn't", "weak", "could ", "causing", "did you check",
               "claiming", "wrong", "but ")

typed = []
for q in questions:
    low = q.lower()
    bound = any(c in low for c in BOUND_CUES)
    attack = any(c in low for c in ATTACK_CUES)
    kind = ("bound request" if bound and not attack else
            "attack" if attack and not bound else "ambiguous")
    typed.append({"question": q[:52] + ("…" if len(q) > 52 else ""), "type": kind})

qdf = pd.DataFrame(typed)
print(qdf.to_string(index=False))
print()
print(qdf["type"].value_counts().to_string())
print()
print("Ambiguous rows are the ones you must read live, from the visitor's face,")
print("and they are the ones worth rehearsing.")

# %% [markdown]
# ### 🔍 Read the Evidence
#
# **Exercise 2.** Answer in two or three sentences each.
#
# 1. Take one row typed as **ambiguous**. Write the version of it that would be a
#    bound request and the version that would be an attack, and say what in the
#    visitor's wording would tell you which you are facing.
# 2. Several questions cluster on the same part of the board. Which part, and what
#    does that clustering tell the author to fix before the Expo?
# 3. Pick the one question in the list that the design genuinely cannot settle.
#    Write the honest answer, including the smaller true claim.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# 1.
# 2.
# 3.

# %% [markdown]
# ### 📝 Practice: the four-second answer
#
# For each prompt, write the one-sentence answer you would give with no preparation
# time. Then write the version you would give having prepared it.
#
# - **A.** "So this proves the programme works, right?"
# - **B.** "How would this look in a different country?"
# - **C.** "Isn't your outcome measure pretty weak?"
#
# The gap between your two versions is exactly what preparation buys, and it is
# almost always the difference between a concession that is true and one that is
# merely polite.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# - A. Unprepared: … Prepared: …
# - B. Unprepared: … Prepared: …
# - C. Unprepared: … Prepared: …

# %% [markdown]
# ### ⚖️ Make a Design Choice
#
# Commit, in writing, to the concession you will not make.
#
# Name the specific sentence you can feel yourself wanting to say when a friendly
# visitor leans in, and write beside it the smaller true claim you will offer
# instead. Then say both aloud, in that order, so the true one is the one your
# mouth knows.
#
# > "The concession I must not make is ______. Instead I say ______."

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# The concession I must not make is … Instead I say …

# %% [markdown]
# ### 🎯 Take It to Your Project
#
# One sentence:
#
# > "The question my board most invites is ______, my honest answer stops at
# > ______, and the audience-directed question I will open with is ______."

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# The question my board most invites is … my honest answer stops at … and the
# audience-directed question I will open with is …

# %% [markdown]
# ### 🛡️ Defend Your Decision
#
# Four one-liners, spoken:
#
# 1. My three predicted questions, typed as bound requests or attacks.
# 2. The one my design cannot settle, and the smaller claim I offer instead.
# 3. The question I will ask the visitor, and what I learn from their answer.
# 4. The concession I refused today, in the words I refused it in.

# %% [markdown]
# ### 🤖 AI Prompt — the questions your board invites
#
# Paste this into your AI assistant. This is the lecture's one live prompt, and the
# constraint at the end is the part that makes it useful.
#
# > 💡 **AI Prompt:** "Here is the complete text visible on my research poster,
# > block by block: [paste every block's text]. You have not been told my claim or
# > my design beyond what is on the board. Generate the six questions this board
# > most invites from a reader who sees only this text. For each, say whether it
# > is asking how far the claim reaches (a bound request) or asserting that
# > something is wrong or missing (an attack). Do not answer any of them."
#
# **After running, verify:**
#
# - [ ] Sort all six against your claim–evidence table. Discard every question your
#       board does not actually invite; a generated question is a guess about
#       readers, not a reading.
# - [ ] Check the typing yourself. The tool will mistype at least one, and the
#       mistyped one is usually the ambiguous one that matters most.
# - [ ] Check what it did not generate. If your hardest question is missing, ask
#       why your board hides it, and whether that is honest.
# - [ ] Record a row in your AI Research Ledger: the prompt, what came back, which
#       questions you kept, which you discarded, and on what grounds.

# %% [markdown]
# ### 🔁 Modify the Prompt
#
# Now run it again with one change.
#
# Add a single line to the prompt: **"The design behind this board is [one
# sentence]."**
#
# Rerun and compare. The questions that appear only in the second run are the ones
# a reader who understands your design would ask, and the questions that disappear
# were artefacts of the board being vague.
#
# Write down which questions moved. That movement is a measure of how much your
# board tells a reader about your design, and at the Expo nobody will be adding
# that line for you.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# Questions present only WITHOUT the design line:
#
# Questions present only WITH the design line:
#
# What the movement tells me about my board:

# %% [markdown]
# ### 🧑‍⚖️ Human-Only Checkpoint
#
# Close every tool. No AI for this block.
#
# Answer in writing:
#
# 1. Write your boundary sentence from memory. Compare it to what is printed on
#    your board. If they differ, the printed one is the one strangers will hold you
#    to, and you have some memorising to do.
# 2. Name one decision in this milestone you would refuse to delegate to any tool,
#    and say why in one clause.
# 3. It is Expo afternoon. A visitor you respect has just asked the question you
#    cannot settle, and they are waiting. Write the exact words you will say, out
#    loud, including the smaller true claim. Say them once now, to nobody. That is
#    the rehearsal that counts.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# 1.
# 2.
# 3.

# %% [markdown]
# ### 📒 AI Research Ledger
#
# The row for this lecture, written before you leave.
#
# | Field | Your entry |
# |---|---|
# | Task delegated | Generating the questions my board invites, with and without the design line |
# | Tool used | |
# | Prompt | |
# | Output summary | |
# | Decision | Questions kept; questions discarded, and on what grounds |
# | Verification method | Sorted every generated question against my claim–evidence table and retyped them myself |
# | Remaining concern | |
# | Responsible researcher | You |
#
# **Claim Ticket (spoken).** "The question my board most invites is ______, and my
# honest answer stops at ______."

# %% [markdown]
# ## 4. Wrap-Up
#
# *(minutes 42–47)*
#
# Your poster has not changed this week, and it cannot. What changed is that the
# spoken version of your research now has the same discipline the printed one has.
#
# What you should be carrying out of these two lectures:
#
# - Three timed versions, counted rather than estimated, with the same boundary
#   sentence in all three.
# - An audience-analysis paragraph that the pitches are actually addressed to.
# - A question strategy built from what a real room asked you, not from what you
#   imagined a room would ask.
# - One prepared "my design cannot settle that" with a smaller true claim behind
#   it, rehearsed until it is the easy answer rather than the brave one.
#
# **Next.** The go-public package (M14) is due at the Friday studio: the plan, the
# three counted pitches, the integration outline, the question strategy, and your
# invitation post. That studio rehearses at the printed board. Next Monday is the
# dress rehearsal, and the **Expo** follows the day after, required and graded.
#
# **Your chapters this week.** Both readings are revisits: **Research Pitches**
# and **Difficult Questions and Uncertainty**. You handed in their "It is your
# turn" sections on their own reading dates, and that work is what this week builds
# on.

# %% [markdown]
# ## 5. Sources & Provenance
#
# *(minutes 47–50)*
#
# **Data.** No new dataset is introduced in the conference block. The worked
# example in Lecture 1 restates a comparison drawn from `lapop_brazil.csv`, which
# ships with the course dataset bundle (`notebooks/data/data.zip`)
# and comes from the `rdss` R package accompanying Blair, Coppock and Humphreys
# (2023), *Research Design in the Social Sciences* (Princeton University Press),
# MIT License. That file is a 10,000-row teaching resample and its README states
# that it does not support substantive claims about Brazil. It appears here as a
# worked demonstration of compression, not as a finding.
#
# **Course book.** EDR|AI, *Evidence-Driven Research in the Age of AI* — this week
# revisits **Research Pitches** and **Difficult Questions and Uncertainty**.
#
# **Recommended.** Blair, Coppock and Humphreys (2023), ch. 23, "Communicating",
# [book.declaredesign.org](https://book.declaredesign.org/).
#
# **Protocols used this week.** `project/conference/presentation_plan_protocol.md`,
# `project/conference/hard_questions_protocol.md`, and
# `project/conference/uncertainty_limitations_protocol.md`.
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>

# %% [markdown]
# ---
#
# ### ⏸ Optional depth from here
#
# **Today's lecture path and the notebook's close are complete.** Everything below this line is optional depth: run it if you want to push the ideas further. Nothing here is required, and any 🏠-marked prompt above is optional too.

# %% [markdown]
# > 💡 **AI Prompt:** **🏠 Optional depth.** "Here is a question I was asked about
# > my research: [paste it]. Here is my design in one line: [paste]. Here is the
# > answer I gave: [paste]. Name anything in my answer that my design does not
# > license. Do not write a better answer."
#
# **After running, verify:** check each flag against your claim–evidence table,
# and notice which flags are about the answer rather than about the question. An
# overreaching answer to a fair question is still an overreaching claim. Record
# the run in your ledger.
