# %% [markdown]
# # Launchpad: How Do We Know?
#
# <hr>
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/nb00_launchpad_student.ipynb)
#
# ---

# %% [markdown]
# ## 🧭 Approach & Claim Boundary
#
# **Approach emphasis:** all (framing) — this notebook opens the map of the four
# quantitative approaches you will spend the semester learning to tell apart:
# **description**, **statistical inference**, **predictive modeling**, and
# **causal reasoning**.
#
# | | |
# |---|---|
# | **A claim this topic PERMITS** | "I can state what evidence WOULD be needed to support this claim." |
# | **A claim this topic does NOT permit** | Any empirical claim without a stated evidence base — including claims an AI tool produced for you. |
#
# **Where this sits in the course:** meeting 1 of 44. Today launches milestone
# M00 (your Curiosity Map) and installs the habit every later meeting relies on:
# **Ask → Verify → Document**.
#
# *Provenance: fresh (course design brief §3) | RDSS ch. 2 concept (research designs as declarable objects) | course framing | newly-constructed-from-source-concept*

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Run, edit, and save a Colab notebook — your laboratory for the semester.
# 2. State the course's central question — *how do we come to know something well
#    enough to defend it?* — and the four kinds of answers evidence can give.
# 3. Catch a fabricated citation produced by an AI tool, and explain how you caught it.
# 4. Apply the **Ask → Verify → Document** discipline and start your AI-use ledger.
# 5. Begin milestone M00: turn one genuine curiosity into the seed of a semester-long project.
#
# ---

# %%
# Setup — run this cell first.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 3)
plt.rcParams["figure.figsize"] = (9, 5)

SEED = 464  # course number — keeps every simulation reproducible
rng = np.random.default_rng(SEED)

# Data loads: GitHub raw URL first (works in Colab), local repo path as fallback.
DATA_URL = ("https://raw.githubusercontent.com/davi-moreira/"
            "2026F_evidence_driven_research_purdue_HONR464/main/notebooks/data/")

def load_course_data(filename):
    """Load a course dataset from GitHub, falling back to the local repo copy."""
    try:
        return pd.read_csv(DATA_URL + filename)
    except Exception:
        from pathlib import Path
        local = Path("notebooks/data") / filename
        if not local.exists():
            local = Path("../data") / filename
        return pd.read_csv(local)

print("✓ Setup complete — seed", SEED)

# %% [markdown]
# ## 1. Meet Your Professor
#
# **Guiding question:** *who is teaching you this course — and why does he care so
# much about evidence?*
#
# <center><img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/notebooks/figures/davi_moreira_photo.jpg" width="30%"/></center>
#
# **Professor Davi Moreira** — [dcordeir@purdue.edu](mailto:dcordeir@purdue.edu) ·
# [davi-moreira.github.io](https://davi-moreira.github.io/)
#
# - Clinical Assistant Professor in the Management Department at Purdue University.
# - His academic work spans **Political Communication, Data Science, Text as
#   Data, Artificial Intelligence, and Comparative Politics** — fields where
#   confident claims are cheap and verified ones are rare, which is exactly how
#   this course came to exist.
# - Before Purdue, he worked as a **Monitoring & Evaluation Specialist consultant
#   for the World Bank** in Brazil, Mozambique, Angola, and the Democratic
#   Republic of the Congo — [measuring whether development projects actually did
#   what they promised](https://blogs.worldbank.org/opendata/improving-how-we-measure-progress-community-biodiversity-conservation-projects-mozambique).
#   Evidence-driven research is not an academic hobby for him; it has been his
#   job on three continents.
#
# ### Two passions, offered as claims to verify
#
# <center><img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/notebooks/figures/palmeiras_logo.png" width="12%"/></center>
#
# <center><img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/notebooks/figures/palmeiras_stadium.jpg" width="45%"/></center>
#
# **Palmeiras** — the São Paulo football club your professor supports, and the
# protagonist of what he will tell you, with a completely straight face, was
# **"the most exciting game in history."**
#
# <center><img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/notebooks/figures/carnaval_olinda.jpg" width="40%"/></center>
#
# **The Olinda carnival** — in Pernambuco, Brazil, where he is from: giant
# puppets, brass bands, and streets so steep the party fights gravity. One year
# the star of the whole carnival was a giant John Travolta puppet — a claim odd
# enough that *The New York Times*
# [wrote it up](https://www.nytimes.com/2024/02/13/world/americas/brazil-carnival-john-travolta.html)
# (with [video](https://www.nytimes.com/video/world/americas/100000009311331/the-star-of-this-carnival-is-a-giant-john-travolta-puppet.html)).
#
# *(Photos: Professor Moreira's own, from his QM 67000 Business Analytics slides.)*
#
# > **A question that often comes up here:** *"What do a soccer club and a
# > carnival puppet have to do with evidence-driven research?"* Everything,
# > actually. "The most exciting game in history" is a **claim** — made by a fan,
# > about something he loves, which is precisely when human beings are worst at
# > weighing evidence. The Travolta-puppet story sounds fabricated and is
# > **true**; plenty of stories sound true and are fabricated. By the end of this
# > notebook you will have a three-step habit for telling which is which — and
# > you are warmly invited to apply it to your professor's claims all semester.
# > He would expect nothing less.
#
# ---
#
# ## 2. Why This Matters
#
# > *"I don't care how confident you sound. I care what your evidence is, where it
# > came from, and what it can and cannot show. Bring me that, and we can talk."*
# > — every good **thesis advisor**, eventually, to every honors researcher
#
# You already know a lot of things. You know them from parents, feeds, professors,
# group chats, headlines, and hunches — and most of the time that mixture works
# fine. But this semester you are going to make a claim in public, with your name
# on it, at the Purdue Fall Undergraduate Research Expo in November. Strangers
# will walk up to your poster and ask, kindly and not so kindly, *"how do you
# know that?"* The whole course exists so that your answer to that question will
# be one you can stand behind.
#
# Here is the promise, in one line: **you will begin with a curiosity and end
# with a claim you can defend** — a claim whose evidence you gathered, whose
# verification you performed, and whose limits you can state without flinching.
#
# > **A question that often comes up here:** *"I'm not a numbers person — is this
# > course going to bury me in statistics?"* No. This course assumes no
# > quantitative or computing background, and it is not a statistics survey. Every
# > piece of code you meet arrives already built; your job is to run it, read what
# > it says, and reason about what it does and does not establish. The thinking is
# > the hard part, and the thinking is in plain English.
#
# ---

# %% [markdown]
# ## 3. Your Laboratory: Google Colab
#
# This document is a **notebook** — a mix of text and runnable code. It is where
# class happens: activities, predictions, exercises, and your own project work
# all live in notebooks like this one.
#
# Three moves are all you need today:
#
# 1. **Save your own copy** (File → Save a copy in Drive) — do this now, or your
#    edits will vanish.
# 2. **Run a cell**: click it, then press `Shift+Enter` (or the ▶ button).
# 3. **Edit and re-run**: change something, run again, see what happens. You
#    cannot break anything that matters — that is what copies are for.
#
# The section that follows checks that your laboratory actually works.

# %% [markdown]
# ### 🛠️ Run the Study — your readiness check
#
# Run the three cells below in order. Each prints a ✓ if your setup works. If any
# cell fails, flag it now — the fix takes two minutes in class and twenty over
# email.
#
# > 💡 **Gemini Prompt:** "I'm running a Python notebook in Google Colab for a
# > course. If a cell gives me an error, I'll paste it here — explain what went
# > wrong in plain English and give me the smallest fix, without rewriting the
# > whole cell."
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] Apply the suggested fix yourself and re-run — the ✓ printing is the
# >   only proof that the fix worked.
# > - [ ] If Gemini's explanation mentions a menu or setting, confirm it actually
# >   exists in YOUR Colab before believing the diagnosis.
# > - [ ] Log this use in your AI ledger: tool, task, verification.

# %%
# Readiness check 1 — can you run code at all?
message = "I can run a code cell."
print("✓", message)

# %%
# Readiness check 2 — can you load a real course dataset from the web?
voters = load_course_data("la_voter_file.csv")
assert voters.shape == (1000, 4), "unexpected shape — flag this!"
print("✓ Loaded la_voter_file.csv —", voters.shape[0], "rows,", voters.shape[1], "columns")
voters.head()

# %%
# Readiness check 3 — can you edit a cell?
# Replace YOUR NAME below with your actual name, then run.
my_name = "YOUR NAME"
print("✓ Notebook claimed by:", my_name)

# %% [markdown]
# The dataset you just loaded is a real extract of 1,000 Los Angeles voter
# records, shipped with the research-design textbook this course draws on. You
# will meet it again when we ask who gets *into* data — and who gets left out.
#
# *Dataset from the `rdss` package (Blair, Coppock & Humphreys, MIT License),
# companion to* Research Design in the Social Sciences *(2023).*
#
# With the laboratory running, we can get to the actual subject of the course:
# how knowing works.
#
# ---

# %% [markdown]
# ## 4. How Do We Know? The Four Kinds of Answers
#
# Every research question that evidence can answer is asking for one of four
# kinds of answers. You will learn to tell them apart the way a musician tells
# keys apart — instantly, and with consequences. Here is your first look:
#
# | Approach | The question it asks | Example |
# |---|---|---|
# | **Description** | What is observed here? | *How many hours do first-years in this survey sleep?* |
# | **Statistical inference** | What holds beyond this sample, with how much uncertainty? | *How many hours do Purdue first-years sleep?* |
# | **Predictive modeling** | Can we forecast cases we haven't seen? | *Which admitted class will struggle in year one?* |
# | **Causal reasoning** | What would change if we intervened? | *Would a later start time increase sleep?* |
#
# Those four example questions sound nearly identical. They are not. They demand
# different evidence, license different claims, and fail in different ways —
# and mixing them up is the single most common way smart people fool themselves
# and their readers.
#
# > **A question that often comes up here:** *"Do I have to pick one approach and
# > stay in it all semester?"* You will declare a primary approach for your
# > project, because your question demands one — but the point is bigger than
# > your project. The classification skill is a permanent lens: after this course
# > you will hear the difference between "people who exercise sleep better" and
# > "exercise improves sleep" for the rest of your life.
#
# ---

# %% [markdown]
# ### 🔮 Pause & Predict
#
# The cell below simulates a tiny, silly study: 40 people, half of whom drank
# coffee before a memory quiz. **Before you run it**, write your prediction in
# the cell that follows the code — will the coffee group score higher, lower, or
# about the same? And here is the real question: *whatever the difference turns
# out to be, what will it prove about coffee?*
#
# Commit to an answer in writing first. This move — predict, then look — is one
# you will make in every notebook this semester, because it is the cheapest
# protection ever invented against fooling yourself.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My prediction (higher / lower / same):**
#
# **What a difference would prove about coffee:**
#
# ---

# %% [markdown]
# > 💡 **Gemini Prompt:** "Here is a short piece of Python from my course:
# > [paste the next cell]. Walk me through what each line does, and explain what
# > the word 'permutation' is doing for the fairness of this tiny experiment."
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] Check Gemini's line-by-line story against the cell's actual printed
# >   output — do the two group means it predicted appear?
# > - [ ] If it claims the code does something you cannot see in the output,
# >   ask it to point to the exact line — and be ready for it to back down.
# > - [ ] Log this use in your AI ledger: tool, task, verification.

# %%
# The tiny coffee "study" — run AFTER writing your prediction above.
n = 40
coffee = rng.permutation(np.repeat([1, 0], n // 2))     # who got coffee (random)
memory_score = rng.normal(70, 6, n) + 8 * coffee         # in this toy world, coffee adds 8 points

study = pd.DataFrame({"coffee": coffee, "score": memory_score.round(1)})
group_means = study.groupby("coffee")["score"].mean().round(2)
print("Mean score, no coffee :", group_means[0])
print("Mean score, coffee    :", group_means[1])
print("Difference            :", round(group_means[1] - group_means[0], 2))

# %% [markdown]
# ### 🔍 Reading the Evidence
#
# Look at the difference you just computed, then answer in the cell below: which
# of the four approaches was this little study using, and what is the *strongest*
# claim its evidence permits? Notice what your answer has to include — the
# simulation *randomly assigned* coffee, which is exactly the kind of design fact
# that determines what you may say. (If that word "assigned" felt important, good
# instincts: October will reward them.)

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Which approach was this study using:**
#
# **The strongest claim its evidence permits:**
#
# ---

# %% [markdown]
# ## 5. The Rule That Runs the Course: Ask → Verify → Document
#
# You will use AI tools constantly this semester — to search, draft, critique,
# and explain. The course encourages it. The course also has one iron rule about it:
#
# > **AI MAY PROPOSE. THE RESEARCHER MUST VERIFY. THE EVIDENCE MUST SUPPORT.**
#
# AI assistants fabricate. Not occasionally — routinely, and most confidently
# exactly where you know least. They invent studies, misstate findings, and cite
# journals that have never existed. A researcher who repeats an AI's claim
# without verifying it has not made an error; they have made someone else's
# error, in their own name, with their credibility attached.
#
# So every AI use in this course follows three steps: **Ask** (use the tool,
# ambitiously), **Verify** (retrieve and confirm every fact and source yourself),
# **Document** (log the tool, the task, and how you verified — your AI-use
# ledger, which travels with every deliverable this semester).
#
# Time to practice catching a fabrication red-handed.

# %% [markdown]
# ### 🛠️ Hands-On: the fabricated-citation hunt
#
# Below are **five citations on the science of how we know things. Three are
# real. Two are fabricated** — invented for this exercise, in exactly the style
# AI tools invent sources. Your job: find the two fakes, and document *how* you
# caught each one.
#
# 1. Blair, G., Coppock, A., & Humphreys, M. (2023). *Research Design in the
#    Social Sciences: Declaration, Diagnosis, and Redesign.* Princeton
#    University Press.
# 2. Martinez, R., & Chen, L. (2019). "Curiosity-driven inquiry and undergraduate
#    research outcomes: A meta-analysis." *Journal of Evidence-Based Pedagogy*,
#    14(3), 211–240.
# 3. Open Science Collaboration (2015). "Estimating the reproducibility of
#    psychological science." *Science*, 349(6251), aac4716.
# 4. Thompson, K. E. (2021). *The Verification Habit: How Scientists Check What
#    They Know.* Oxford University Press.
# 5. Bergstrom, C. T., & West, J. D. (2020). *Calling Bullshit: The Art of
#    Skepticism in a Data-Driven World.* Random House.
#
# > 💡 **Gemini Prompt:** "I need to verify whether
# > these five citations refer to real publications. For each one, tell me what
# > you know about it and how confident you are that it exists: [paste the five
# > citations]"
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] Do NOT trust the AI's verdict — it can vouch for fakes and doubt real
# >   sources. Check each citation yourself: search the exact title in quotes on
# >   Google Scholar, the publisher's site, or the journal's archive.
# > - [ ] A real source is one you can actually retrieve — a page you can open,
# >   not a title an AI describes.
# > - [ ] Log this use in your AI ledger: tool, task, verification.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The two fabricated citations are numbers:**
#
# **How I caught fake #1:**
#
# **How I caught fake #2:**
#
# ---

# %% [markdown]
# ### 📝 Practice
#
# Three claims you might meet in a normal week. For each, answer in the cell
# below: **what kind of evidence would be needed to support it** — and which of
# the four approaches would produce that evidence?
#
# - **A.** "Most Purdue undergraduates get less than seven hours of sleep."
# - **B.** "This app can tell which of its users are about to cancel their
#   subscription."
# - **C.** "Taking notes by hand improves exam performance."

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **A — evidence needed / approach:**
#
# **B — evidence needed / approach:**
#
# **C — evidence needed / approach:**
#
# ---

# %% [markdown]
# ## 6. The Semester at a Glance — and Your Project
#
# The course is one long arc with four landmarks:
#
# - **Now → early October:** turn a curiosity into an answerable question,
#   classify its approach, and design the study that could answer it — declared
#   publicly, piece by piece.
# - **Mid → late October:** stress-test your design by simulation, run a pilot
#   analysis, and find out what your evidence really says.
# - **November:** build a poster and present it at the **Purdue Fall
#   Undergraduate Research Expo (Tuesday, November 17 — required)**.
# - **December:** verify, reproduce, and defend — ending with an oral **Evidence
#   Defense** and a final research dossier.
#
# Every meeting moves your own project forward — and the whole journey fits on
# one map, drawn by the authors of the course's textbook. You do not need to
# understand it today; you will OWN it by December:
#
# <center><img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/notebooks/figures/rdss_fig_2_1.png" width="75%"/></center>
#
# *The course's master map: a research design has a Model of the world, an
# Inquiry, a Data strategy, and an Answer strategy (M·I·D·A) — with a theoretical
# side, an empirical side, and a simulation layer for stress-testing it all.
# (Figure from the replication materials of Blair, Coppock & Humphreys (2023),*
# Research Design in the Social Sciences *— MIT-licensed archive; the book is
# free at book.declaredesign.org.)*
#
# Which brings us to milestone M00.

# %% [markdown]
# ### ⚖️ Make a Design Choice
#
# Your first design decision of the semester, small but real: **which of your
# curiosities deserves the semester?** In the cell below, list **three genuine
# curiosities** — things you actually wonder about, from any field you care
# about. Then mark the one you would currently choose to carry, and defend that
# choice in a short paragraph: why this one, and what would make it a *bad*
# choice that you should watch out for?
#
# (You are not locked in. You are practicing the move: choose, and say why.)

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Curiosity 1:**
#
# **Curiosity 2:**
#
# **Curiosity 3:**
#
# **My current pick and why (one paragraph, including one risk):**
#
# ---

# %% [markdown]
# ### 🎯 Project Transfer — milestone M00 launches now
#
# M00, your **Curiosity Map**, is due **Wednesday, August 26, 11:59 PM** on
# Brightspace. It is deliberately small:
#
# 1. The three curiosities you just wrote, each expanded to 2–3 sentences (what
#    you wonder, and why it hooks you).
# 2. A screenshot of this notebook's readiness checks passing (the three ✓ cells).
# 3. Your first AI-ledger entry, if you used an AI tool today (tool, task, how
#    you verified).
#
# On Wednesday you will pitch one curiosity to the class in 30 seconds. Full
# instructions and the rubric are on Brightspace.

# %% [markdown]
# ### 🎟️ Claim Ticket
#
# Before you leave: **Claim Ticket #1**. In the cell below, write down one claim
# you encountered this week — from a feed, a friend, a class, anywhere — and
# answer: *what evidence would be needed for you to actually believe it?* One
# sentence for the claim, two for the evidence. You will write one of these at
# the end of every meeting; by December, the stack of them will be a record of
# how your standards changed.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The claim:**
#
# **The evidence it would need:**
#
# ---

# %% [markdown]
# ## 7. Wrap-Up
#
# Today you claimed your laboratory, met the four kinds of answers evidence can
# give, caught an AI fabricating scholarship, and chose the curiosities that
# might carry your semester. One idea above all is worth keeping:
#
# > **"A claim you cannot trace to evidence is not knowledge — it is a rumor
# > wearing your voice."**
#
# On Wednesday, nb01 picks up your strongest curiosity and starts the real work
# of research: finding the **gap** — the thing your field genuinely does not
# know yet — and walking the path from curiosity to topic to problem to a
# question evidence can answer. Bring your Curiosity Map; it is the raw material.
#
# ---

# %% [markdown]
# ## 8. Sources & Provenance
#
# **Provenance of this notebook:**
# - *fresh (course design brief §3) | course framing | Ask → Verify → Document policy | newly-constructed-from-source-concept*
# - *RDSS ch. 2 (What is a research design?) | concept | research designs as declarable objects | adapted (conceptual framing only)*
# - *la_voter_file.csv | rdss package data | readiness-check dataset | adapted (loaded as-is)*
#
# **Dataset attribution:** Dataset from the `rdss` package (Blair, Coppock &
# Humphreys, MIT License), companion to *Research Design in the Social Sciences*
# (2023).
#
# **Readings:**
# - Blair, G., Coppock, A., & Humphreys, M. (2023). *Research Design in the
#   Social Sciences: Declaration, Diagnosis, and Redesign.* Princeton University
#   Press. Free online: [book.declaredesign.org](https://book.declaredesign.org/) —
#   skim the Preface and ch. 2 before Wednesday.
# - Open Science Collaboration (2015). "Estimating the reproducibility of
#   psychological science." *Science*, 349(6251), aac4716. *(met in the citation
#   hunt — a real and consequential study)*
# - Bergstrom, C. T., & West, J. D. (2020). *Calling Bullshit.* Random House.
#   *(optional companion, public cases at callingbullshit.org)*
#
# *(Two additional citations in §4 were fabricated for the verification exercise
# and are identified as such there — they are not sources.)*
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>
