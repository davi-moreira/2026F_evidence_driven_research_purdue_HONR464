# %% [markdown]
# # Real Sources, Citation Integrity, and the Claim Map
#
# <hr>
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/nb03_sources_claims_student.ipynb)
#
# ---

# %% [markdown]
# ## 🧭 Approach & Claim Boundary
#
# **Approach emphasis:** description + inference — appraising and mapping what a
# literature *claims* and on what evidence. This is the course's evidence-integrity
# spine made operational: no claim you cannot trace to a source you retrieved.
#
# | | |
# |---|---|
# | **A claim this topic PERMITS** | "Source S exists — I retrieved it myself — and it claims X on the basis of evidence E; across my verified sources, claims cluster as A vs B, and none address C, which is my gap." |
# | **A claim this topic does NOT permit** | Citing any source you have not personally retrieved (however plausible an AI's summary sounds) — or "the literature proves…" (a map of claims is not proof, and unread sources count for nothing). |
#
# **Where this sits in the course:** meetings 7–8 of 44. It builds the **M02
# Literature & Claim Map** and rests on the classified question from nb02 and the
# bounded gap from nb01 — now you go find whether that gap is really there.
#
# *Provenance: RDSS ch. 4 'Getting started' (situating a design in a literature) + fresh AI-era source-finding workflow and claim-map method | getting started | retrieval-verification loop + networkx-lite claim graph | newly-constructed-from-source-concept*

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Name where scholarly claims live, and rank sources by the evidence behind them.
# 2. Run the **retrieval-verification loop**: treat any AI-proposed source as a
#    *lead*, retrieve it yourself, and confirm it exists and says what was claimed.
# 3. Catch a **fabricated citation** and articulate the tell that gave it away.
# 4. Extract a source's central claim and **type the evidence** behind it
#    (description / inference / prediction / causal).
# 5. Build a **claim map** — claims as nodes, agreement and contradiction as edges —
#    and place your gap where the field has not yet looked.
# 6. Assemble your verified source ledger into the M02 claim map for your project.
#
# ---

# %%
# Setup — run this cell first.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 3)
plt.rcParams["figure.figsize"] = (9, 5)

SEED = 464  # course number — keeps every layout reproducible
rng = np.random.default_rng(SEED)

# Data loads: GitHub raw URL first (works in Colab), local repo path as fallback.
DATA_URL = ("https://raw.githubusercontent.com/davi-moreira/"
            "2026F_evidence_driven_research_purdue_HONR464/main/notebooks/data/")

def load_course_data(filename):
    """Load a course dataset from GitHub, falling back to the local repo copy."""
    try:
        return pd.read_csv(DATA_URL + filename)
    except Exception:
        from pathlib import Path
        local = Path("notebooks/data") / filename
        if not local.exists():
            local = Path("../data") / filename
        return pd.read_csv(local)

print("✓ Setup complete — seed", SEED)

# %% [markdown]
# ## 1. Why This Matters
#
# > *"An author once cited a paper of mine to support a claim my paper flatly
# > contradicts. They had never opened it — an AI summary told them what it said,
# > and they believed the summary. That single unretrieved citation is why I now
# > check every reference in a manuscript against the actual source."*
# > — a **journal reviewer**, on the fastest way to lose their trust
#
# Your gap only counts if it is real — and "real" means *checked against the
# literature that actually exists*, not the literature an AI assistant describes.
# This is where the course's iron rule earns its keep. AI tools are extraordinary
# at *finding leads* and catastrophic at *telling the truth about them*: they
# invent authors, fabricate journals, attach real names to papers that were never
# written, and do it most confidently exactly where you know least. A citation you
# cannot open is not a weak source. It is not a source at all.
#
# So every claim in your project passes through one loop:
#
# **Ask** (use any tool to surface leads) → **Retrieve** (open the actual source
# yourself) → **Verify** (confirm it exists and says what was claimed) →
# **Document** (log it in your ledger, with where you found it).
#
# > **A question that often comes up here:** *"If I have to verify everything
# > myself, what is the AI even for?"* For breadth and speed you could not manage
# > alone — it reads the shape of a field in seconds and hands you names to chase.
# > That is genuinely valuable. What it cannot do is *vouch* for anything. Treat
# > its output as a map drawn by someone who has never visited the territory:
# > priceless for pointing you somewhere, worthless as proof you arrived.
#
# ---

# %% [markdown]
# ## 2. Where Claims Live — and the Source Hierarchy
#
# Not all sources carry the same evidentiary weight. When two sources disagree, the
# question is never "which sounds better" but "which stands on stronger evidence."
# A rough hierarchy, strongest evidentiary backing first:
#
# - **Peer-reviewed empirical studies** — a claim tied to data others reviewed
#   before publication (journal articles, many working papers on their way there).
# - **Systematic reviews & meta-analyses** — many studies pooled; strong *when the
#   pooled studies were sound*.
# - **Reports & preprints** — often excellent, but not yet peer-checked; read the
#   methods yourself.
# - **Popular writing** (books, journalism, explainers) — great for *leads and
#   framing*, but chase the primary source it rests on before you cite the claim.
#
# The move that separates a researcher from a repeater is **snowballing**: once you
# have one solid source, walk its reference list backward (what it built on) and its
# citations forward (who built on it). Two good sources, snowballed, become ten.
#
# > **A question that often comes up here:** *"A blog post states a striking
# > statistic with no citation. Can I use it?"* Not as evidence — yet. You can use
# > it as a *lead*: search the exact statistic, find the study it came from, open
# > that study, and cite *that* (if it says what the blog claimed). If the trail
# > dead-ends, the statistic dead-ends with it. No trail, no claim.
#
# ---

# %% [markdown]
# ### 🔮 Pause & Predict
#
# In a moment you will inspect **five citations** on one topic — how information
# environments shape what people believe. **Exactly two are fabricated**: invented
# for this exercise, in the precise style AI tools invent sources. Three are real,
# famous, retrievable works.
#
# **Before you investigate**, commit a guess in the cell below: which two numbers do
# you think are the fakes, and what about them makes you suspicious *on sight*?

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My guess — the two fakes are numbers:** ____ and ____
#
# **What makes me suspicious on sight:**
#
# ---

# %% [markdown]
# ### 🛠️ Hands-On: the fabricated-citation hunt
#
# Below are five citations. **Three are real. Two were fabricated for this
# exercise** — planted, on purpose, to be maximally plausible. Your job: retrieve
# each one and decide which two do not exist. Document *how* you caught each fake.
#
# 1. Tversky, A., & Kahneman, D. (1974). "Judgment under uncertainty: Heuristics and
#    biases." *Science*, 185(4157), 1124–1131.
# 2. Reynolds, D. M., & Okafor, S. A. (2019). "Echo chambers and the erosion of
#    shared facts: A five-year panel study of online news audiences." *Journal of
#    Networked Communication Studies*, 11(2), 203–229.
# 3. Putnam, R. D. (2000). *Bowling Alone: The Collapse and Revival of American
#    Community.* Simon & Schuster.
# 4. Halvorsen, K. (2016). *Manufactured Consensus: How Platforms Engineer Belief.*
#    Beacon Press.
# 5. Pariser, E. (2011). *The Filter Bubble: What the Internet Is Hiding from You.*
#    Penguin Press.
#
# > 💡 **AI Prompt (copy into your AI assistant):** "For each of these five
# > citations, tell me what you know about it and how confident you are that it is a
# > real, published work: [paste the five citations]."
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] Do NOT trust the AI's verdict — it can vouch for a fake and doubt a real
# >   one. Check each yourself: search the exact title in quotes on Google Scholar,
# >   the publisher's site, or the journal's own archive.
# > - [ ] A real source is one you can *open* — a page you reached, not a
# >   description an AI produced. If nothing you can retrieve carries that exact
# >   title, treat it as fabricated.
# > - [ ] Log this use in your AI ledger: tool, task, how you verified.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The two fabricated citations are numbers:** ____ and ____
#
# **How I caught fake #1 (the tell + what I searched):**
#
# **How I caught fake #2 (the tell + what I searched):**
#
# ---

# %% [markdown]
# ### 🔍 Reading the Evidence
#
# In the cell below, answer three things. First: what *general* tell separates the
# two fakes from the three real ones — a rule you could apply to a citation you have
# never seen? Second: write, in the permitted-claim template, one thing you may now
# say about a source you verified: *"Source S exists — I retrieved it at ___ — and
# it claims ___ on the basis of ___."* Third: an AI summary hands you a
# perfect-sounding study you cannot find anywhere. Name the three possible
# explanations and what you do next.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The general tell (a rule I could reuse):**
#
# **One verified source, in the permitted-claim template:**
#
# **The perfect-sounding-but-unfindable study — three explanations + my next step:**
#
# ---

# %% [markdown]
# The tell you just named — *retrievability* — is the whole game. Now let's
# make finding real sources faster, and notice how the two tools you will use fail
# in opposite ways.
#
# ---

# %% [markdown]
# ### 📝 Practice
#
# Take your own M01 research question. In the cell below, turn it into **two search
# strings**: one you would type into a **library database or Google Scholar**, and
# one you would give an **AI assistant**. Then predict how each will fail — because
# they fail differently, and knowing how is how you catch it.
#
# *(Hint: databases match your literal words — they fail by missing work that uses
# different terms. AI tools paraphrase and synthesize — they fail by inventing
# sources that fit your words too perfectly.)*

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My M01 question:**
#
# **Database / Scholar search string (keywords, operators):**
#
# **AI-assistant prompt:**
#
# **How the database search will fail / How the AI search will fail:**
#
# ---

# %% [markdown]
# ### 🎯 Project Transfer — start your source ledger
#
# The ledger you start now becomes the backbone of M02. In the cell below, run one
# AI-assisted search and one database search for your question, then log **at least
# two sources you verified** — retrieved and confirmed to say what you think.
#
# | # | Full citation | Where I retrieved it | Its central claim | Evidence type |
# |---|---|---|---|---|
# | 1 | | | | |
# | 2 | | | | |
#
# *(Evidence type = description / inference / prediction / causal — your nb02 skill,
# now pointed at other people's studies.)*

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Ledger entry 1 — citation / where retrieved / central claim / evidence type:**
#
# **Ledger entry 2 — citation / where retrieved / central claim / evidence type:**
#
# **One lead an AI gave me that I could NOT retrieve (and set aside):**
#
# ---

# %% [markdown]
# ### 🎟️ Claim Ticket
#
# **Claim Ticket #7** — in the cell below, record **one verified source** for your
# question: its full citation, and exactly where you retrieved it. One source you
# could hand a reviewer and say "open it yourself." That is your ticket out today.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Verified source — full citation + where I retrieved it:**
#
# ---

# %% [markdown]
# ---
#
# *(Meeting M8 picks up here.)*
#
# ## 3. From Ledger to Claim Map: Drawing What a Field Argues
#
# > *"Show me the argument of your literature, not a pile of summaries. Which
# > sources agree, which fight, and where — exactly — is the hole you say you're
# > filling? If you can't draw it, you haven't read it yet."*
# > — a **thesis advisor**, sending a first draft back
#
# A reading list is not a literature review. A pile of sources tells your reader
# nothing about the *shape* of what is known. A **claim map** does: it turns each
# verified source into a claim, draws the relationships between claims (who agrees,
# who contradicts, who qualifies), and marks the one place the map is empty — your
# gap. Three moves build it:
#
# 1. **Extract the central claim.** One sentence per source: what does it actually
#    assert? (Not its topic — its claim.)
# 2. **Type the evidence.** Which of the four approaches backs the claim —
#    description, inference, prediction, or causal? A causal claim resting on
#    descriptive evidence is a crack in the map worth marking.
# 3. **Draw the edges, place the gap.** Connect claims that **agree** or
#    **contradict** or **qualify** one another, then put your gap where no source
#    reaches — and check it is a hole, not just somewhere you have not read.
#
# One honesty rule governs the whole picture: a map of claims is **not proof**. It
# shows what the field *asserts*, not what is *true*, and an unread source is not on
# the map at all.
#
# ---

# %% [markdown]
# ### 🛠️ Hands-On: build a claim map
#
# The cell below builds a **worked** claim map on one literature — does social-media
# use lower social trust? — from two small tables. Run it, read the picture, then
# notice the design: you build your *own* map later by swapping your ledger into the
# two tables. The graph draws itself.

# %%
# A worked claim map. To build your OWN, replace the two tables with your ledger.
import networkx as nx
from matplotlib.lines import Line2D

claims = pd.DataFrame({
    "id":       ["C1", "C2", "C3", "C4", "GAP"],
    "kind":     ["source", "source", "source", "source", "gap"],
    "evidence": ["inference", "inference", "description", "inference", "—"],
    "label":    ["C1: heavy use links\nto lower trust",
                 "C2: the link is\nsmall and mixed",
                 "C3: trust fell\nbefore social media",
                 "C4: strong local ties\nbuffer the link",
                 "GAP: not shown for\nfirst-gen undergrads"],
})
edges = pd.DataFrame({
    "src":      ["C2", "C3", "C4", "C4"],
    "dst":      ["C1", "C1", "C1", "GAP"],
    "relation": ["contradicts", "contradicts", "qualifies", "opens"],
})

print("Claims, each typed by the kind of evidence behind it:")
readable = claims.assign(label=claims["label"].str.replace("\n", " ", regex=False))
print(readable[["id", "evidence", "label"]].to_string(index=False))

G = nx.DiGraph()
for _, r in claims.iterrows():
    G.add_node(r["id"], kind=r["kind"])
for _, e in edges.iterrows():
    G.add_edge(e["src"], e["dst"], relation=e["relation"])

pos = nx.spring_layout(G, seed=SEED, k=1.6)
ecolor = {"agrees": "#2a9d8f", "contradicts": "#e76f51",
          "qualifies": "#8a8a8a", "opens": "#6a4c93"}
node_colors = ["#f4a259" if G.nodes[n]["kind"] == "gap" else "#8ec7d2"
               for n in G.nodes]
edge_colors = [ecolor[G.edges[e]["relation"]] for e in G.edges]
labels = dict(zip(claims["id"], claims["label"]))

fig, ax = plt.subplots(figsize=(9, 6))
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=4200, ax=ax)
nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=2.2,
                       arrowsize=18, node_size=4200, ax=ax)
nx.draw_networkx_labels(G, pos, labels, font_size=8, ax=ax)
ax.set_title("A claim map: what the sources assert, how they relate, where the gap sits")
ax.axis("off")
handles = [Line2D([0], [0], color=c, lw=3, label=r) for r, c in ecolor.items()]
handles.append(Line2D([0], [0], marker="o", color="w", label="gap (unfilled)",
                      markerfacecolor="#f4a259", markersize=12))
ax.legend(handles=handles, loc="lower left", fontsize=8, frameon=False)
plt.tight_layout()
plt.show()

# %%
# Self-check — a claim map needs exactly one placed gap and its relations intact.
assert G.number_of_nodes() == 5 and G.number_of_edges() == 4, "map shape changed unexpectedly"
assert (claims["kind"] == "gap").sum() == 1, "a claim map needs exactly one gap node placed"
assert set(edges["relation"]) <= set(ecolor), "an edge relation has no color — add it to the legend"
print("✓ Self-check passed: 5 claims, 4 relations, exactly one gap placed.")

# %% [markdown]
# ### 🔍 Reading the Evidence
#
# Read the worked map, then answer in the cell below. First: state the one claim the
# map **permits** in the template *"Across these sources, claims cluster as ___ vs
# ___, and none address ___ — the gap."* Second: C1 and C2 point opposite ways —
# does that mean one is wrong? Third: name the sentence about this map that would
# **overreach** — the "the literature proves…" move — and say why it is false.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The claim this map permits (cluster A vs B; the unfilled gap):**
#
# **C1 vs C2 disagree — is one of them wrong? Why or why not:**
#
# **The overreaching sentence, and why it is false:**
#
# ---

# %% [markdown]
# ### 📝 Practice
#
# On the map, C1 ("heavy use links to lower trust") and C3 ("trust fell before
# social media") pull in opposite directions. In the cell below, list **three design
# differences** that could explain the contradiction **without either study being
# wrong** — different populations, measures, time windows, or methods. Contradiction
# is data, not a verdict; your job is to explain it charitably.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Design difference 1:**
#
# **Design difference 2:**
#
# **Design difference 3:**
#
# ---

# %% [markdown]
# ### ⚖️ Make a Design Choice — place your gap
#
# Now the decision that makes your map yours. In the cell below, state **where your
# gap sits** on your own literature — the one thing your verified sources do not
# address — and defend the placement against the question that kills weak gaps:
# *could one of your own sources already cover it, if you read it more carefully?*
# Choose a placement, and argue it is a genuine hole and not just unread ground.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My gap, placed (what no verified source of mine addresses):**
#
# **My defense (why it is a real hole, not a source I under-read):**
#
# ---

# %% [markdown]
# ### 🎯 Project Transfer — your claim map IS M02
#
# Assemble the deliverable now. Copy the two-table pattern from the worked cell,
# replace `claims` with your verified ledger (one row per source, typed by evidence)
# and `edges` with the agreements and contradictions you see, place your `GAP` node,
# and run it. That figure — plus your ledger — is **M02, the Literature & Claim Map**,
# presented in Friday's gallery walk and submitted tonight (11:59 PM). Incorporate at
# least one challenge you receive at the gallery before you submit.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My claim map's clusters (agree/contradict, in words):**
#
# **The one gallery-walk challenge I incorporated:**
#
# ---

# %% [markdown]
# ### 🎟️ Claim Ticket
#
# **Claim Ticket #8** — in the cell below, name the **strongest claim in your map
# that argues AGAINST your project's premise**. Not the friendliest source — the one
# that most makes you nervous. Facing it now is how your gap survives contact with a
# reviewer later.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The strongest claim against my premise (citation + what it asserts):**
#
# ---

# %% [markdown]
# ## 4. Wrap-Up
#
# Across two meetings you learned to trust sources the only way that survives a
# reviewer: you retrieved them. You caught two fabricated citations by the one tell
# that never lies — you could not open them — turned your question into search
# strings whose opposite failure modes catch each other, and drew the argument of a
# literature as a map of claims with your gap placed honestly where no source
# reaches.
#
# > **"A citation you did not retrieve is not a source — it is a rumor with a page
# > number. And a map of claims is not proof; it is an honest picture of what a
# > field asserts, and of the one place it stays silent."**
#
# Submit M02 tonight — your ledger and your claim map together. On Monday, nb04 turns
# from *what others claim* to *the world your own question lives in*: potential
# outcomes and DAGs, the first half of the MIDA design engine. Bring your gap; it is
# about to become a declared model.
#
# ---

# %% [markdown]
# ## 5. Sources & Provenance
#
# **Provenance of this notebook:**
# - *RDSS ch. 4 'Getting started' | situating a design in a literature | source hierarchy + snowballing framing | adapted (concept-level, honors non-quant audience)*
# - *fresh | AI-era source-finding workflow (retrieval-verification loop) | citation-integrity instantiation of the AI policy | newly-constructed-from-source-concept*
# - *fresh | claim-map method | table-driven networkx-lite claim graph | newly-constructed-from-source-concept*
#
# **Readings:**
# - Blair, G., Coppock, A., & Humphreys, M. (2023). *Research Design in the Social
#   Sciences*, ch. 4 'Getting started'. Free online:
#   [book.declaredesign.org](https://book.declaredesign.org/).
# - Optional: Bergstrom & West, public case studies at
#   [callingbullshit.org](https://callingbullshit.org/case_studies.html).
#
# **On the citation hunt (§1 hands-on):** three citations there are real and
# retrievable — Tversky & Kahneman (1974, *Science*); Putnam (2000, *Bowling
# Alone*); Pariser (2011, *The Filter Bubble*). *Two others (Reynolds & Okafor 2019;
# Halvorsen 2016) were fabricated for the exercise and are identified as such — they
# are not sources.*
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>
