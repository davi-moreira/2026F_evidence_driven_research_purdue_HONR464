# %% [markdown]
# # Research in the Age of AI: Your Arm, Your RA, Not Your Brain
#
# **Topic 01 · 2 lectures**
#
# <hr>
#
# <center>
# <div>
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" width="300"/>
# </div>
# </center>
#
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/nb01_ai_arm_not_brain_student.ipynb)
#
# ---

# %% [markdown]
# ## 🧭 Inquiry & Claim Boundary
#
# *Every notebook in this course opens with this panel, so here is how to read
# it. **Inquiry emphasis** names the kind of question the week trains you to
# ask. **Design pathway** places the week on the course's map of research
# designs. The claim table then draws the week's line: what your evidence
# permits you to claim, and what it does not.*
#
# **Inquiry emphasis:** This first notebook does not
# teach one kind of question. It installs the habit that keeps every later question
# honest: use AI tools hard, then verify everything they hand you before you put your
# name on it. The map for sorting questions, the **inquiry compass**, opens next week.
#
# **Design pathway:** cross-cutting. This week is framing, not one design pathway. It
# sets the working rule you carry into all five design pathways later in the
# course: observational descriptive, observational causal, experimental
# descriptive, experimental causal, and prediction.
#
# | | |
# |---|---|
# | **A claim this topic PERMITS** | "An AI tool generated this, the source exists, and I read, confirmed, and criticized the underlying argument or technique before using it." That is the course's opening standard. |
# | **A claim this topic does NOT permit** | "The AI said so," offered as evidence. A generated citation you have not retrieved and checked is not yet a source. |
#
# **Where this sits in the course:** Week 1, the first notebook of the course and of
# Phase 1. It launches milestone **M0**, your research-and-AI baseline, which you
# work on at this week's Friday studio. It installs the **Ask → Verify → Document**
# habit every later notebook relies on.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. State the course promise in one line, and explain what **AI as your arm and
#    research assistant, not your brain** asks of you on day one.
# 2. Run a Colab notebook and confirm your laboratory works, so the semester's tools
#    are ready.
# 3. Show, with a seeded simulation, why how confident a source *sounds* tells you
#    nothing about whether it is real, and verify a source by retrieving it yourself.
# 4. Name the ways an AI partner goes wrong (**hallucination**, **automation bias**,
#    **false confidence**) and run one claim through the full **Ask → Verify →
#    Document** cycle.
# 5. Sort research tasks into safe-to-delegate, delegate-then-verify, and
#    never-delegate, and defend the boundary.
# 6. Apply the Ledger and the never-delegate boundary to your own project's M0
#    research-and-AI baseline.
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Before anything else, get your laboratory running. Run the two code cells
# below, then read the AI Research Partner briefing: it explains how you will
# work with your AI all semester. Every notebook in this course starts the same
# way, so this takes two minutes from Week 2 on.

# %%
# Setup — run this cell first.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx  # for the loop diagrams; if missing locally: pip install networkx (pre-installed in Colab)

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 3)
plt.rcParams["figure.figsize"] = (9, 5)

SEED = 464  # course number — keeps every simulation reproducible
rng = np.random.default_rng(SEED)

# Data loads: GitHub raw URL first (works in Colab), local repo path as fallback.
DATA_URL = ("https://raw.githubusercontent.com/davi-moreira/"
            "2026F_evidence_driven_research_purdue_HONR464/main/notebooks/data/")

def load_course_data(filename):
    """Load a course dataset from GitHub, falling back to the local repo copy."""
    try:
        return pd.read_csv(DATA_URL + filename)
    except Exception:
        from pathlib import Path
        local = Path("notebooks/data") / filename
        if not local.exists():
            local = Path("../data") / filename
        return pd.read_csv(local)

print("✓ Setup complete — seed", SEED)

# %% [markdown]
# **Reading the output.** The setup cell prints one line: `✓ Setup complete —
# seed 464`. That seed pins every simulation in the course, so your numbers and
# your neighbor's numbers always match.
#
# **What the next cell does:** four quick checks that your laboratory works: you
# can run a cell, load the course data, and sign your notebook. Expect ✓ lines;
# a ✗ is a setup problem to fix now, not in Week 5.

# %%
# Readiness check — confirm your laboratory works before the semester leans on it.
# 1) Can you run code? 2) Can you load a real course dataset? 3) Can you edit a cell?
voters = load_course_data("la_voter_file.csv")
assert voters.shape == (1000, 4), "unexpected shape — flag this!"
print("✓ You can run a code cell.")
print("✓ Loaded la_voter_file.csv —", voters.shape[0], "rows,", voters.shape[1], "columns")

my_name = "YOUR NAME"   # replace with your actual name, then re-run
print("✓ Notebook claimed by:", my_name)

# %% [markdown]
# **Reading the output.** You should see `✓ You can run a code cell.`, a line
# confirming `la_voter_file.csv` loaded with 1000 rows and 4 columns, and your
# name on the claim line. If any line failed, flag it today: every later notebook
# leans on this laboratory.

# %% [markdown]
# # Lecture 1

# %% [markdown]
# ## 👋 Meet Your Professor
#
# <center>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/images/professor/davi_moreira_photo.JPG" width="180">
# </center>
#
# <center>
#
# [dcordeir@purdue.edu](mailto:dcordeir@purdue.edu) · [davi-moreira.github.io](https://davi-moreira.github.io/)
#
# </center>
#
# - Clinical Assistant Professor in the Quantitative Methods Department and
#   Director of the Daniels Undergraduate Business Honors Program at Purdue
#   University.
# - My academic work addresses Political Communication, Data Science, Text as
#   Data, Artificial Intelligence, and Comparative Politics.
# - [Monitoring & Evaluation Specialist consultant for the World Bank
#   (Brazil, Mozambique, Angola, and the Democratic Republic of the
#   Congo)](https://blogs.worldbank.org/opendata/improving-how-we-measure-progress-community-biodiversity-conservation-projects-mozambique).

# %% [markdown]
# ### My Passions
#
# Research runs on curiosity, so here is what I am curious and passionate about
# when I am not teaching.
#
# **Palmeiras.** The greatest Brazilian football club, and the source of my most
# rigorous training in uncertainty.
#
# <center>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/images/professor/palmeiras_logo.png" width="110">
# </center>
#
# <center>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/images/professor/palmeiras_stadium.jpg" width="380">
# </center>
#
# <center>
#
# [The Most Exciting Game in History (video)](https://www.youtube.com/watch?v=FCebgeX_3hI&t=89s)
#
# </center>
#
# **Carnaval de Olinda.** My hometown party: a street carnival in Pernambuco,
# Brazil, famous for its giant puppets.
#
# <center>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/images/professor/carnaval_olinda.jpg" width="320">
# </center>
#
# <center>
#
# [NYT: How John Travolta Became the Star of Carnival](https://www.nytimes.com/2024/02/13/world/americas/brazil-carnival-john-travolta.html) · [the video](https://www.nytimes.com/video/world/americas/100000009311331/the-star-of-this-carnival-is-a-giant-john-travolta-puppet.html)
#
# </center>

# %% [markdown]
# ### Now It Is Your Turn
#
# Five minutes. Introduce yourself to the colleague on your left or right: name,
# field, and one thing you are genuinely curious about. Then ask them to rate, on
# a scale from 1 (not at all) to 5 (completely), how much they trust an AI answer
# they have not checked. Keep both numbers in mind; this course is about earning
# the right to move that number.

# %% [markdown]
# ## How Every Week Runs
#
# Every week of this course has the same three-beat rhythm: two flipped lectures
# (Monday and Wednesday) and a Friday project studio. Knowing the shape ahead of
# time means you walk into every room already knowing your job.
#
# **Monday and Wednesday are flipped lectures.** Both are run by the day's
# **Student Research Lead** (a classmate, solo or in a pair; your instructor
# leads only in Week 1), built on a fixed four-section, 50-minute architecture
# whose center of gravity is a roughly 22-minute controlled AI investigation.
# Your instructor does not lecture from the front: they monitor conceptual
# accuracy while the lead runs the room, then formalize the concept at the end.
# Monday and Wednesday use the same skeleton but a different rhythm. Monday
# discovers a concept; Wednesday applies and defends it.

# %% [markdown]
# **Monday: concept discovery (9 / 22 / 12 / 7).**
#
# 1. **Student-led research puzzle (9 min).** The lead opens with a concrete
#    puzzle or contradiction, draws out the room's prior beliefs, and everyone
#    commits an answer in writing before any AI.
# 2. **Guided AI research-partner investigation (22 min), the core.** You work
#    the notebook with your AI as a directed research partner: specify the
#    decision, get an initial answer, surface its assumptions, ask for a
#    competing explanation, demand evidence or a test, then verify against the
#    data. The lead steers; your instructor watches for errors.
# 3. **Human verification + instructor formalization (12 min).** You verify the
#    AI-assisted result independently (a calculation, a simulation, a
#    counterexample, a DAG, a holdout check), then your instructor formalizes
#    the concept, corrects misconceptions, and states the research-decision rule.
# 4. **Decision and defense (7 min).** You record a decision, its justification,
#    a verification statement, the project implication, and an AI Research
#    Ledger entry; the meeting closes on a spoken Claim Ticket.
#
# **Wednesday: applied lab + adversarial defense (7 / 23 / 12 / 8).**
#
# 1. **Student-led retrieval and challenge (7 min).** The lead presents a common
#    error, an ambiguous claim, a flawed AI output, or a result needing
#    interpretation, and the room decides what is wrong before touching your AI.
# 2. **Intensive applied AI laboratory (23 min), the core.** You use the
#    concept: repair or generate code, build a simulation, diagnose a design,
#    audit a claim, hunt for data leakage, stress-test a model, always under the
#    required iterative control (initial prompt → diagnose → revise → new output
#    → independent test → decision), never copy-and-accept.
# 3. **Peer defense and adversarial questioning (12 min).** You compare
#    solutions and defend what you delegated, why, what the AI proposed, what
#    you rejected, how you verified it, and what is still uncertain.
# 4. **Transfer to the final project (8 min).** You apply the concept to your
#    own research project and update the cumulative Research Project Dossier and
#    ledger.

# %% [markdown]
# **Friday is the project studio**, with no new topic content. It is the
# fixed weekly beat where the concepts from Monday and Wednesday get turned into
# that week's milestone. Unlike Monday and Wednesday, Friday is not led by a
# Student Research Lead: your instructor frames it and runs rotating consults
# while you work. Same 50-minute discipline, four sections (10 / 5 / 30 / 5):
#
# 1. **Weekly topic quiz (10 min).** You answer a short set of multiple-choice
#    questions, solo and on paper, about the topic covered during the week. It
#    is quick, it counts toward your grade, and it tells you immediately what
#    stuck.
# 2. **Research stand-up (5 min).** You report, in a sentence or two: what
#    changed since last time, the current blocker, the research decision you are
#    facing, what you delegated to AI this week, and what still needs
#    verification.
# 3. **Milestone kickoff + AI-supported sprint (30 min), the core.** Your
#    instructor presents the milestone in the course Brightspace page, then you
#    work on it with your AI assistant. This is the block where the milestone
#    actually gets built.
# 4. **Revision, ledger, submission (5 min).** You address the highest-priority
#    finding, update the Research Project Dossier and the AI Research Ledger,
#    state your next decision, and submit the milestone.

# %% [markdown]
# ### The Milestone Chain
#
# You carry one individual research question across the whole semester. Every
# milestone is a graded, submittable artifact that follows a develop in class,
# present, submit, revise cadence, so no deliverable is ever built alone or at
# the last minute. Each one updates your cumulative **Research Project Dossier**
# and appends an **AI Research Ledger** entry. Milestone briefs and rubrics are
# posted on Brightspace, one page per milestone; due dates live on the course
# Schedule page.
#
# | ID | Milestone | Week |
# |---|---|---|
# | M0 | Research and AI baseline | 1 |
# | M1 | Research opportunity landscape | 2 |
# | M2 | Verified evidence and contribution map | 3 |
# | M3 | Research charter and MIDA declaration | 4 |
# | M4 | Observational descriptive design audit | 5 |
# | M5 | Causal identification strategy or causal-language boundary *(async)* | 6 |
# | M6 | Experimental measurement or data-acquisition protocol (+ conference abstract gate) | 7 |
# | M7 | Declared analysis protocol | 8 |
# | M8 | Minimum viable analysis | 9 |
# | M9 | Poster draft 1 and research audit | 10 |
# | M10 | **Final poster lock** *(terminal)* | 11 |
# | M11 | Presentation package | 12 |
# | M12 | Conference reflection and poster-criticism portfolio | 13 |
# | M13 | Replication and red-team report *(async)* | 14 |
# | M14 | Research-note draft and reproducibility capsule | 15 |
# | M15 | **Final research chapter and AI-management portfolio** *(terminal)* | 16 |

# %% [markdown]
# ## The Course at a Glance
#
# This is a research seminar, not a statistics survey. Over one semester you
# carry a single research project of your own, from a curiosity you actually
# care about to a claim you defend in public. No quantitative or computing
# background is assumed; all code is provided, and every method is taught at the
# conceptual level first.
#
# The course's one promise, and the rule behind every activity: **AI is your arm
# and your research assistant, not your brain.** You will use AI tools
# constantly, at high intensity, and you will verify everything they hand you
# before your name goes on it.
#
# By the end you will have produced a conference poster presented in public, a
# replication and red-team report on a peer's work, a written research note
# grown into a final chapter, an AI-management portfolio, and an oral evidence
# defense.

# %% [markdown]
# ## Grading and Assessment
#
# | Component | Weight |
# |---|---|
# | Lecture Notebook Completion | 10% |
# | Quizzes (Friday, multiple choice, on the week's topic) | 20% |
# | Student Research Lead performance | 20% |
# | Final Project Milestones | 20% |
# | Final Project | 20% |
# | Research artifact (paper/chapter/note) | 10% |
#
# Two habits drive most of these points: come having worked the notebook, and
# keep your AI Research Ledger honest and current. Full grading details are in
# the syllabus on the course website and Brightspace.

# %% [markdown]
# ## Materials and Logistics
#
# **The course book (required, free).** **EDR|AI**, *Evidence-Driven Research in
# the Age of AI*, on the course website. It is the required reading each week,
# it links every Colab lab, and it also exists in Brazilian Portuguese and
# Spanish. It is a work in progress that grows during the semester.
#
# **The theory text (recommended, free).** Blair, Coppock & Humphreys, *Research
# Design in the Social Sciences* (RDSS), free at book.declaredesign.org. EDR|AI
# translates it for you; read RDSS when you want depth.
#
# **Computing.** Everything runs in the browser through Google Colab. Nothing to
# install, nothing to purchase.
#
# **AI tools.** AI is your primary research assistant. Purdue GenAI
# Studio supplies reviewer roles you will consult at designated milestones.
# Microsoft Copilot and other tools are permitted with disclosure. Every AI use
# follows Ask → Verify → Document.
#
# **Where things live.** Milestone briefs, rubrics, and announcements are on
# Brightspace. The calendar with every date is the Schedule page of the course
# website. The Material page catalogs every notebook, dataset, and reading.

# %% [markdown]
# ## Questions
#
# What did the last twenty minutes leave unclear? Ask now: about the project,
# the leading, the quizzes, the AI rules, anything. Whatever we do not settle in
# the room, bring to office hours or send by email. The one question with a
# guaranteed answer today: yes, you can do this course, and the person next to
# you can too.

# %% [markdown]
# ### 🎤 SRL Lead Brief
#
# *Every Monday and Wednesday lecture in this course opens with this section. It
# belongs to the day's **Student Research Lead**: the classmate, solo or in a
# pair, who runs the room.*
#
# This week is the exception. Your instructor leads both Week 1 lectures,
# modeling the format you will run yourselves from next week on. Watch three
# things closely: how the opening puzzle gets posed, how everyone commits an
# answer in writing before any AI tool is opened, and how the investigation is
# steered with questions rather than answered from the front. That is the job you
# will inherit.
#
# From next week on: lead slots are **randomly assigned at the start of the
# semester**, your lead's brief sits exactly here in that lecture's notebook, and
# everyone is welcome to read it ahead of time. When your turn comes, start
# preparing about a week ahead and send your preparation script or notebook two
# days ahead. The frame is fixed; the staging is yours. Bring your own examples,
# your own voice, and one move the brief never thought of. The full guide lives
# in the course book's Student Research Lead appendix.

# %% [markdown]
# ### 🤝 AI Research Partner
#
# All semester you work with **AI as a research partner**, not an answer machine.
# A **research partner** is a tool you task with real work and then check, the way
# you would check a fast but unproven research assistant. And AI today is more
# than a chatbot: **agentic tools** can carry out multi-step work for you, running
# an analysis plan, trying variations, assembling a draft. It is fine to ask your
# AI to *do* things, not just answer things. The deal never changes: you review,
# you curate, and you make the final decision.
#
# AI is also a good partner for **brainstorming**: candidate questions, rival
# explanations, designs you had not considered. Generate widely with it; commit
# narrowly yourself. A good use looks like this: you commit your own answer first,
# then ask your AI to locate candidate sources you will retrieve, list items you
# will check against your data, or explain a cell so you can confirm it against
# the printed output. A bad use is letting it decide your question, wave a claim
# past your evidence, or hand you a source you never opened.
#
# **Never delegate these:** which problem and question you pursue, which claims your
# evidence justifies, the ethics of your study, and how you state your uncertainty.
# Those are yours to declare and defend. The full list of never-delegate decisions
# lives in the book:
# [Chapter 4 — Research Responsibility and Intellectual Ownership](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part1-research-with-ai/04-research-responsibility-and-intellectual-ownership.html).
#
# **Commit first, then ask.** Every AI block below asks you to write your own answer
# before you open your AI tool, so the reply has something of yours to disagree with.
#
# > **A question that often comes up here:** *"If AI is faster and often right,
# > why write my answer first?"* Because the habit protects your judgment. If you read
# > the tool's answer first, it anchors you, and you lose the one thing you bring that
# > it cannot: knowing what your project is really about. Writing first keeps you the
# > researcher and keeps AI the assistant.
#
# ---

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(We open the lecture with this. Think it through and commit an answer before we go
# further. No AI yet.)*
#
# An AI tool can now write working code and fluent prose in seconds. Paste in a
# question and it hands back an analysis, a paragraph, and a tidy list of sources.
#
# Here is the puzzle. If the machine can produce the code and the writing, **what is
# left for a researcher to actually do?** Commit an answer in one or two sentences
# before we go further. Then push on it: name one job in that list that you would
# still stake your name on personally, and one that you would refuse to let any tool
# finish for you. If your two jobs are the same job, look again. Sorting those jobs
# is the whole point of Lecture 1.

# %% [markdown]
# ## 1. What Is Left for the Researcher?
#
# **Guiding question:** *when an AI can generate the code and the prose, which part of
# research becomes more important, not less?*
#
# > *"I don't care how confident you sound, or how polished the writing is. I care
# > what your evidence is, where it came from, and what it can and cannot show. Bring
# > me that, and we can talk."*
# > — a **thesis advisor**, eventually, to every honors researcher
#
# Welcome to the course. Your professor, **Davi Moreira**, has spent years measuring
# whether things that sound true actually are, from academic research to development
# projects on three continents. That gap, between sounding right and being right, is
# exactly why this course exists.
#
# Three ideas frame the whole semester. Meet them once, plainly.
#
# - **Evidence-driven research** is turning a curiosity into a claim you can defend
#   with traceable, verified evidence. Example: not "napping helps grades," but "in
#   the 200 first-years I surveyed, nappers averaged 0.2 grade points higher, and here
#   is the survey, the numbers, and the limits."
# - **AI as your arm and research assistant, not your brain** is the course's iron
#   rule. The tool can reach, fetch, draft, and compute for you, like an arm or an
#   assistant. It does not get to decide what is true or what you claim. Example: let
#   it draft a summary paragraph, then you check every number in it yourself.
# - **Assistance versus intellectual substitution** is the line you patrol. **Assistance**
#   speeds up work you could check and own. **Intellectual substitution** is letting the
#   tool make a judgment that was yours to make. Example of the bad kind: pasting an
#   AI's conclusion into your poster without deciding, yourself, that the evidence
#   supports it.
#
# So the answer to the puzzle. When the machine writes the code and the prose, the
# human job that grows is **judgment**: deciding what to ask, what counts as evidence,
# what the evidence licenses, and where to stop. That judgment is the course.
#
# > **A question that often comes up here:** *"I'm not a numbers person. Will this
# > course bury me in statistics?"* No. It assumes no quantitative or computing
# > background. Every piece of code arrives already built. Your job is to run it, read
# > what it says, and reason about what it does and does not establish. The thinking is
# > the hard part, and the thinking is in plain English.
#
# ---

# %% [markdown]
# The rule turns into a three-step habit you will use in every notebook:
# **Ask → Verify → Document**. **Ask** means use the tool, ambitiously. **Verify**
# means retrieve and confirm every fact, source, and number yourself. **Document**
# means log the tool, the task, and how you checked, in a record that travels with your
# work. One more term before the diagram:
#
# - A **claim** is a statement about the world that could be true or false. Example:
#   "this app can tell which users are about to cancel." A claim is not yet knowledge.
#   It becomes knowledge only when evidence you can point to supports it.
#
# The loop below is the shape of the whole course. Skip the Verify and Document steps,
# and you are not doing research. You are repeating a machine's guess in your own
# voice.
#
# **What the next cell does:** draws that habit as a three-box loop. Expect one
# figure and a ✓ line; there are no numbers to read yet.

# %%
# The habit that runs the course, drawn as a loop: Ask -> Verify -> Document.
# (networkx is imported once in the setup cell.)
G = nx.DiGraph()
pos = {"Ask": (0.0, 0.0), "Verify": (2.0, 0.0), "Document": (4.0, 0.0)}
G.add_edges_from([("Ask", "Verify"), ("Verify", "Document")])

fig, ax = plt.subplots(figsize=(9, 3.2))
nx.draw_networkx_nodes(G, pos, node_color="#DCE6F1", edgecolors="#4C72B0",
                       linewidths=1.5, node_size=6000, ax=ax)
nx.draw_networkx_labels(G, pos, font_size=12, ax=ax)
nx.draw_networkx_edges(G, pos, arrowstyle="-|>", arrowsize=22, edge_color="#555555",
                       width=1.8, node_size=6000, ax=ax)
labels = {("Ask", "Verify"): "use the tool", ("Verify", "Document"): "confirm it yourself"}
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels, font_size=9, ax=ax)
# The return arrow: Document feeds the next Ask.
ax.annotate("", xy=(0.0, 0.35), xytext=(4.0, 0.35),
            arrowprops=dict(arrowstyle="-|>", color="#4C72B0",
                            connectionstyle="arc3,rad=-0.25", lw=1.6))
ax.text(2.0, 0.62, "log it, then ask the next question", ha="center",
        fontsize=9, color="#4C72B0")
ax.set_ylim(-0.4, 0.8)
ax.set_title("The habit that runs the course: Ask → Verify → Document")
ax.axis("off")
plt.tight_layout()
plt.show()
print("✓ Ask → Verify → Document loop drawn.")

# %% [markdown]
# **Reading the output.** *In plain terms, the diagram says: use the tool, then confirm what it gave you
# yourself, then write down how you checked. The curved arrow on top is the point.
# Documenting one answer sets up the next honest question.*
#
# The next section puts the Verify step under pressure, because Verify is where an AI
# partner is most likely to hand you something that looks perfect and is not.
#
# ---

# %% [markdown]
# ## 2. Why Sounding Right Is Not Evidence
#
# **Guiding question:** *can you tell a real source from an invented one by how
# confident and polished it sounds?*
#
# AI tools **hallucinate**, and you need the word. A **hallucination** is confident,
# polished output that is simply made up: a study that was never run, a statistic with
# no basis, a journal article that does not exist. Example: ask for scholarly sources
# and you may get a mix of real papers and convincing inventions, with nothing marking
# which is which. The tone is identical for both.
#
# That is why one skill matters more than any prompt trick: **verification** by
# **retrievability**. A source is **retrievable** when you can actually open it: find
# the real paper, and confirm the authors, year, and venue match. Example: you paste
# the exact title into Google Scholar or the Purdue Libraries catalog, and the real
# article opens. If nothing opens, treat the source as invented until it does.
#
# The simulation ahead makes the danger visible before you meet it live.

# %% [markdown]
# ### 🔮 Pause & Predict
#
# You are about to simulate an AI returning **12 candidate sources**. Each one has a
# **polish** score, how authoritative it sounds, and a hidden label for whether it is
# actually **retrievable**. Before you run it, commit: if you sorted the 12 by how
# confident they sound and trusted the top half, would that reliably filter out the
# fabricated ones? Predict yes or no, and write one sentence of reasoning. Do not peek
# at the output first.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Would sorting by confidence filter out the fakes? (yes / no):**
#
# **One sentence of reasoning:**
#
# ---

# %% [markdown]
# **🏠 Homework depth — run this on your own before the next lecture.**
# **Before you ask:** predict, in one sentence, what the correlation between polish and
# retrievability will be (near zero, strongly positive, strongly negative). Write it
# down first so the tool has something of yours to disagree with.
#
# > 💡 **AI Prompt:** "Here is a Python cell that simulates an AI returning 12
# > candidate sources, each with a 'polish' score and a hidden 'retrievable' label,
# > then reports the correlation between the two: [paste the next cell]. Without
# > rerunning my code, give me one independent way to recompute that correlation by
# > hand from the printed `polish` and `retrievable` values. Do NOT tell me the number
# > my cell printed; I will read that from my own output and compare."
# >
# > **After running, verify (counters *plausible-but-wrong-method*: a fluent
# > walkthrough can describe a computation the cell never performed):**
# > - [ ] Confirm the correlation your AI quotes matches the `corr` value your cell
# >   actually printed, not a rounder number it guessed.
# > - [ ] Run its "independent way to recompute" yourself. If it will not run, or gives a
# >   different value than your printout, trust your printout.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# ### 🛠️ Run the Study: the retrieval test
#
# Run the cell below. It simulates 12 candidate sources, sets each one's polish and its
# real-or-not label **independently**, and then checks whether sorting by polish would
# catch the fakes. Read the printout before the next markdown cell.

# %%
# Simulate the retrieval test. An AI returns 12 candidate sources for one query.
# 'polish' = how authoritative each SOUNDS (0-1). 'retrievable' = whether it actually
# opens when you search for it. The two are drawn INDEPENDENTLY, which is the point:
# sounding good and being real are unrelated.
n_sources = 12
polish = rng.uniform(0.55, 0.99, size=n_sources)     # everything sounds authoritative
retrievable = rng.random(n_sources) < 0.60           # ~60% actually exist
corr = np.corrcoef(polish, retrievable.astype(float))[0, 1]

n_fake = int((~retrievable).sum())
order = np.argsort(-polish)                           # most confident-sounding first
top_half = order[: n_sources // 2]                    # the 6 you'd 'trust' on tone alone
fake_in_top_half = int((~retrievable[top_half]).sum())

print(f"Sources returned              : {n_sources}")
print(f"Actually retrievable          : {int(retrievable.sum())}")
print(f"Fabricated (do not open)      : {n_fake}")
print(f"Correlation(polish, real)     : {corr:+.2f}")
print(f"Fabricated among the 6 most confident-sounding: {fake_in_top_half}")

# Plot: polish on the x-axis, real-or-not on the y-axis. Shape AND color both encode
# the label, so the picture never depends on color alone.
fig, ax = plt.subplots()
real = retrievable
ax.scatter(polish[real], np.ones(real.sum()), s=130, marker="o",
           color="#4C72B0", label="retrievable (you can open it)")
ax.scatter(polish[~real], np.zeros((~real).sum()), s=170, marker="X",
           color="#DD8452", label="fabricated (nothing opens)")
ax.set_yticks([0, 1])
ax.set_yticklabels(["fabricated", "retrievable"])
ax.set_xlim(0.5, 1.02)
ax.set_ylim(-0.5, 1.5)
ax.set_xlabel("How authoritative the source SOUNDS (polish)")
ax.set_title("Polish does not sort real from fabricated: both spread across the range")
ax.legend(loc="center left")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reading the output.** The printout is the whole lesson: 12 sources came
# back, only 5 actually exist, and the correlation between how polished a source
# sounds and whether it is real is a weak **+0.21**. Three fabricated sources sit
# in the confident-sounding half of the plot. Polish is not evidence.
#
# **What the next cell does:** a self-check that restates that result as one ✓
# line, quoting the correlation and the fabricated count from the data.

# %%
# Self-check: polish and existence are roughly unrelated, so tone cannot filter fakes.
assert n_sources == 12
assert n_fake >= 1, "the demo needs at least one fabricated source to catch"
assert abs(corr) < 0.6, "polish and existence were drawn independently — corr should be modest"
print(f"✓ Self-check passed: with r = {corr:+.2f} between polish and existence, sorting "
      f"the 12 by how good they sound leaves {fake_in_top_half} fabricated source(s) "
      f"sitting in the 'confident' half.\n  Tone is not a filter. Retrieval is.")

# %% [markdown]
# ### 🔍 Reading the Evidence: what the simulation does and does not show
#
# The blue circles and the orange X marks spread across the same polish range. The
# fabricated sources sound just as authoritative as the real ones, and the printed
# correlation between polish and existence is small. In the cell below, write three
# things. First: what this simulation establishes about using an AI's confidence to
# judge its sources. Second: the one thing it does NOT establish (it is a model with a
# built-in 60% chance that each source is real, not a measurement of any real tool). Third: the single move
# that *would* separate real from fabricated, stated in your own words.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **What the simulation establishes:**
#
# **What it does NOT establish:**
#
# **The one move that separates real from fabricated:**
#
# ---

# %% [markdown]
# ### 🛠️ Hands-On: catch a live citation
#
# Now the real thing. Pick one topic you are genuinely curious about, from any field.
# Ask your AI for scholarly sources, then **verify every one by retrieving it yourself**.
# Search each exact title, in quotes, on [Google Scholar](https://scholar.google.com/)
# or in the Purdue Libraries catalog, and record one verdict per source:
#
# - **Retrieved**: you opened the actual paper or book, and authors, year, and venue
#   match.
# - **Distorted**: something real exists, but a detail is wrong (year, journal, mangled
#   title, wrong authors).
# - **Not found**: nothing turns up. Treat it as invented until you can retrieve it.
#
# Whatever mix you get is a finding. If everything checks out, you learned that
# verification can be fast. If one fails, you just caught a hallucination on day one, on
# a topic you care about.
#
# **🔴 Live in class: we run this one together.**
# **Before you ask:** in one sentence, predict how many of the four sources you expect
# to be fully retrievable. Commit the number before you look.
#
# > 💡 **AI Prompt:** "I'm starting a research project on [YOUR TOPIC]. Give me 4
# > scholarly sources: peer-reviewed articles or academic books. For each, give the
# > authors, year, exact title, and where it was published, plus one sentence on what it
# > found. Only include work you are confident exists; mark anything you are unsure
# > about. Then tell me which one of the four I should verify first, and what search
# > would prove it does not exist."
# >
# > **After running, verify (counters *confident fabrication*: an invented citation
# > arrives with the same confident tone as a real one):**
# > - [ ] Do NOT trust the list as delivered. Search each exact title, in quotes, and
# >   open the actual source. A real source is a page you can open, not a title the tool
# >   describes.
# > - [ ] Compare the count you retrieve against the number you predicted above. If the
# >   tool marked all four as certain and one will not open, you caught the failure.
# > - [ ] Record a verdict for all four below, then log this use in your AI Research
# >   Ledger: task, tool, decision, verification.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My topic:**
#
# **Source 1 (verdict + how I checked):**
#
# **Source 2 (verdict + how I checked):**
#
# **Source 3 (verdict + how I checked):**
#
# **Source 4 (verdict + how I checked):**
#
# **What this tells me about using AI to find sources:**
#
# ---

# %% [markdown]
# ---
#
# ### ⏸ In class through here
#
# **You have reached the end of Lecture 1's in-class block.** Everything below deepens
# the same ideas. Finish it on your own before the next lecture: the design choice about
# which curiosity to carry, the practice drill on defensible claims, and the
# homework-depth your AI prompt you met above. Come back having caught at least one
# citation you had to retrieve to trust.
#
# ---

# %% [markdown]
# ### ⚖️ Make a Design Choice: which curiosity will you carry?
#
# *(Human-first: settle your own choice and its defense before you ask any AI.)*
#
# Your first design decision of the semester, small but real. Your project starts from
# a genuine curiosity, and your M0 baseline asks for three. In the cell below, list
# **three genuine curiosities** from any field you care about. Then mark the one you
# would currently carry, and defend it in a short paragraph: why this one, and what
# would make it a *bad* choice you should watch for (too broad to finish, no reachable
# data, already settled).
#
# You are not locked in. You are practicing the move: choose, and say why.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Curiosity 1:**
#
# **Curiosity 2:**
#
# **Curiosity 3:**
#
# **My current pick and why (one paragraph, including one risk):**
#
# ---

# %% [markdown]
# ### 📝 Practice: defensible now, or needs a source first?
#
# *(Human-first: sort all three yourself before any AI. Telling the two apart by eye is
# the graded skill.)*
#
# For each claim below, answer in the cell that follows: could you defend it **right
# now** with evidence you can point to, or would you first have to **retrieve a source**
# you do not yet hold? Name the source you would need.
#
# - **A.** "An AI tool wrote this summary of my dataset, so the numbers in it are
#   correct."
# - **B.** "Most Purdue undergraduates get less than seven hours of sleep."
# - **C.** "The paper I just cited, which your AI gave me, says exactly what I claim it
#   says."

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **A (defensible now / needs a source, which one):**
#
# **B (defensible now / needs a source, which one):**
#
# **C (defensible now / needs a source, which one):**
#
# ---

# %% [markdown]
# You have sorted what a researcher still owns and seen why polish is not proof.
# Lecture 2 turns to the harder failure: not a made-up source, but a confident, fluent
# answer that is simply wrong, and the discipline that catches it before it reaches your
# poster.
#
# ---

# %% [markdown]
# ---
#
# # Lecture 2

# %% [markdown]
# ### 🎤 SRL Lead Brief
#
# *Your instructor leads this lecture too; it is the second and last
# instructor-led model of the format. From next week on, this opening section
# belongs to the day's Student Research Lead, and one of these lectures will be
# yours. As you watch, take one note you will reuse: the move you want to steal
# for your own lead.*

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(We open the lecture with this. Think it through and commit an answer before we go
# further. No AI yet.)*
#
# A machine gives a confident, detailed, well-written wrong answer. A smart, careful
# person reads it and uses it anyway.
#
# Here is the puzzle. **Why do smart people trust a wrong machine?** Commit an answer in
# one or two sentences before we go further. Then name the moment it would happen to
# *you*: a point in your own project where a fluent AI answer would be so convincing
# that you would stop checking. What exactly would have to be true for you to catch it
# anyway? Naming that catch is the work of Lecture 2.

# %% [markdown]
# ## 3. Why Smart People Trust a Wrong Machine
#
# **Guiding question:** *what makes a fluent, confident answer so hard to doubt, and
# what discipline keeps you doubting anyway?*
#
# > *"The most dangerous output isn't the one that's obviously wrong. It's the one
# > that's confident, detailed, well-organized, and wrong. That one gets used."*
# > — a **skeptical peer**, reviewing a draft that leaned too hard on a tool
#
# Three named habits explain the trap. Learn the names, because you cannot guard against
# a danger you cannot name.
#
# - **Automation bias** is the tendency to over-trust an automated system and stop
#   checking, precisely because it is automated. Example: drivers who follow a GPS
#   straight into a closed road because "the machine said turn."
# - **False confidence** is when fluent, detailed output makes you feel sure of
#   something you never actually verified. Example: a polished paragraph makes a wrong
#   statistic feel solid, so you quote it.
# - **Illusion of understanding** is mistaking a smooth explanation for real
#   comprehension. Example: you nod along to an AI's line-by-line walkthrough of a cell,
#   then find you could not defend it to a skeptic.
#
# None of this is new to AI. Long before these tools, Tversky and Kahneman (1974)
# showed people lean on confident mental shortcuts that misfire in predictable ways. And
# Open Science Collaboration (2015) re-ran 100 published psychology studies and found
# that many did not hold up, a reminder that even peer-reviewed, confident-sounding
# results need checking. A fluent AI answer simply makes the old trap faster and
# smoother.
#
# > **A question that often comes up here:** *"If these tools invent things and mislead,
# > why use them at all?"* Because they are genuinely powerful, and you will use them
# > for the rest of your career no matter what any course says. A search that once took
# > an afternoon now takes minutes. The skill worth building is not avoidance. It is
# > using the tool ambitiously and then verifying like a professional, every time.
#
# ---

# %% [markdown]
# The discipline that beats the trap is a loop with a human at both ends. You met its
# shorthand, Ask → Verify → Document. Here is the full version the course trains,
# **SDIIVDD**: **Specify, Delegate, Interrogate, Inspect, Verify, Document, Defend**.
#
# You **specify** the task and write down your own expected answer first. You
# **delegate** the well-specified work to the tool. You **interrogate** the draft for
# assumptions and errors. You **inspect** what it actually produced, not its summary of
# itself. You **verify** with a real check before trusting anything. You **document** the
# use in your Ledger. You **defend** the result in your own words, with the tool out of
# the room.
#
# The two ends are human on purpose. That connects to one more term. **Never-delegate
# decisions** are the calls that stay yours no matter how good the tool gets: the
# question, the design and population, the measures, the ethics, the claim boundary, the
# uncertainty, and the public defense. Example: you may ask your AI to list candidate
# measures for your concept, but deciding which one truly captures it is your call.
#
# **What the next cell does:** draws the full SDIIVDD chain as one figure. Expect
# seven boxes and a ✓ line naming the everyday shorthand.

# %%
# The full loop, drawn as a chain: Specify -> Delegate -> Interrogate -> Inspect ->
# Verify -> Document -> Defend. Specify and Defend are the human bookends.
steps = ["Specify", "Delegate", "Interrogate", "Inspect", "Verify", "Document", "Defend"]
G2 = nx.DiGraph()
G2.add_edges_from([(steps[i], steps[i + 1]) for i in range(len(steps) - 1)])
pos2 = {s: (i, 0) for i, s in enumerate(steps)}

# Human-owned bookends get a darker outline AND are named in the caption (not color
# alone). Verify, where trust is earned, is filled a distinct shade.
fill = ["#B7C9E2", "#DCE6F1", "#DCE6F1", "#DCE6F1", "#55A868", "#DCE6F1", "#B7C9E2"]
edgecol = ["#1F3B6E", "#4C72B0", "#4C72B0", "#4C72B0", "#2F6B45", "#4C72B0", "#1F3B6E"]

fig, ax = plt.subplots(figsize=(12, 3))
nx.draw_networkx_nodes(G2, pos2, node_color=fill, edgecolors=edgecol,
                       linewidths=2.0, node_size=3400, ax=ax)
nx.draw_networkx_labels(G2, pos2, font_size=8.5, ax=ax)
nx.draw_networkx_edges(G2, pos2, arrowstyle="-|>", arrowsize=16, edge_color="#555555",
                       width=1.5, node_size=3400, ax=ax)
ax.set_title("SDIIVDD: the AI-collaboration loop, human at both ends (Specify, Defend)")
ax.set_xlim(-0.6, 6.6)
ax.set_ylim(-0.6, 0.6)
ax.axis("off")
plt.tight_layout()
plt.show()
print("✓ SDIIVDD loop drawn. Shorthand: Ask (Specify + Delegate) → Verify (Interrogate")
print("  + Inspect + Verify) → Document, and Defend closes it. You own the first and last step.")

# %% [markdown]
# **Reading the output.** *In plain terms, the chain says: you set the task, hand out the work, argue with the
# draft, look at what it really did, confirm it with a real check, log it, and defend it
# yourself. The two darker end circles are the steps you never hand to a tool.*
#
# The next section stress-tests the Verify step on the failure that matters most in
# practice: a confident answer with a wrong number in it.
#
# ---

# %% [markdown]
# ## 4. Verify the Number, Not the Paragraph
#
# **Guiding question:** *when an AI hands you a fluent finding, what exactly do you
# check before you repeat it?*
#
# Here is the rule that governs the whole notebook: **code running without errors is not
# the same as code being correct.** A cell can execute cleanly, and a summary can read
# beautifully, and the number inside can still be wrong. So you verify the **number**,
# not the paragraph about the number.
#
# Below is a small randomized study. A confident one-line summary, the kind an AI
# partner might hand you, reports a large effect. Your job is to check it against what
# the data actually show.

# %% [markdown]
# ### 🔮 Pause & Predict
#
# The next cell runs a small study where a study-skills workshop was **randomly
# assigned**, then compares the two groups' quiz scores. Imagine the summary you get
# back reads: *"the workshop delivered a clear boost of about 9 points."* Before you run
# the cell, commit: do you expect the actual gap in the data to be near 9, or smaller?
# Write one sentence of reasoning. Do not run the cell until you have committed. You are
# predicting a reveal.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Near 9, or smaller? and why:**
#
# ---

# %% [markdown]
# ### 🛠️ Run the Study: check the claimed number
#
# Run the cell below. It builds a small randomized study with a real built-in effect,
# computes the actual gap between the groups, and puts that verified gap next to the
# confident "9 points" claim. Read the printout before the next markdown cell.
#
# **🔴 Live in class: we run this one together.**
# **Before you ask:** write down, in one sentence, the exact number you would need to
# recompute to check the claim (the gap in group means). Commit it before you delegate.
#
# > 💡 **AI Prompt:** "Here is a Python cell that runs a small randomized study and
# > compares two groups' mean quiz scores: [paste the next cell]. Point to which single
# > printed number is the actual effect of the workshop in this toy world, and say
# > plainly whether the confident '9 points' summary is or is not that number. Then give
# > me one independent way to compute that same gap myself, by hand from the two printed
# > group means, without rerunning your explanation."
# >
# > **After running, verify (counters *confident fabrication*: a fluent summary can state
# > a number the data never produced):**
# > - [ ] Read the *Verified gap* your cell printed. Confirm your AI points to that same
# >   number as the effect, not to the claimed 9.
# > - [ ] Run its "independent way to compute the gap" yourself. If it does not match the
# >   printed verified gap, trust your printout, not the paragraph.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# **What the next cell does:** builds a tiny randomized study: 200 people, half
# assigned to a study-skills workshop by coin flip, and a written summary that
# claims a **+9 point** effect. It prints both group means, the gap verified from
# the data, and the claimed gap, then draws the two score distributions. Watch
# whether the printout backs the paragraph.

# %%
# A small randomized study: does a study-skills workshop raise a quiz score?
# Re-seed a fresh generator so this result is reproducible on its own (seed 464).
rng_study = np.random.default_rng(SEED)

n = 120
TRUE_EFFECT = 3.0                                        # the real effect in this toy world
workshop = rng_study.permutation(np.repeat([1, 0], n // 2))  # random assignment, 60 vs 60
score = rng_study.normal(72, 8, n) + TRUE_EFFECT * workshop
study = pd.DataFrame({"workshop": workshop, "score": score.round(1)})

means = study.groupby("workshop")["score"].mean()
observed_gap = means[1] - means[0]
CLAIMED_GAP = 9.0                                        # the confident one-line summary

print(f"Mean score, no workshop : {means[0]:.2f}")
print(f"Mean score, workshop    : {means[1]:.2f}")
print(f"Verified gap (from data): {observed_gap:+.2f} points")
print(f"Claimed gap (summary)   : {CLAIMED_GAP:+.2f} points")
print(f"The summary overstated the gap by {CLAIMED_GAP - observed_gap:.2f} points.")

# Plot the claimed number next to the verified one. Hue AND the value label both carry
# the meaning, so the picture never depends on color alone. The verified bar is blue;
# the unverified claim gets its own orange so it never reads as the trusted value.
fig, ax = plt.subplots(figsize=(7, 5))
bars = ax.bar(["Verified gap\n(from the data)", "Claimed gap\n(confident summary)"],
              [observed_gap, CLAIMED_GAP],
              color=["#4C72B0", "#DD8452"], edgecolor="white")
for b, v in zip(bars, [observed_gap, CLAIMED_GAP]):
    ax.text(b.get_x() + b.get_width() / 2, v + 0.15, f"{v:+.1f}", ha="center", fontsize=11)
ax.set_ylim(0, 10)
ax.set_ylabel("Effect on quiz score (points)")
ax.set_title("Verify the number: the confident summary is not what the data show")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reading the output.** The verified gap is **+1.68 points** (75.01 vs 76.69)
# against the summary's claimed **+9.00**. The printout, not the paragraph, is
# the evidence; the overstatement is 7.32 points.
#
# **What the next cell does:** a self-check that restates that comparison as one
# ✓ line.

# %%
# Self-check: random assignment licenses a causal gap here, but it is far below 9.
assert observed_gap > 0, "the built-in effect is positive; the observed gap should be too"
assert observed_gap < CLAIMED_GAP - 2, "the claim should clearly overstate the data"
print(f"✓ Self-check passed: the verified gap is {observed_gap:+.2f} points, well below the "
      f"confident '{CLAIMED_GAP:+.0f} points'.\n  Random assignment lets this gap estimate "
      f"the workshop's effect in the toy world, but the claimed number was never in the data.")

# %% [markdown]
# ### 🔍 Reading the Evidence: what the data license and what they refute
#
# Two facts sit side by side. Because the workshop was **randomly assigned**, the gap the
# cell computed is a fair estimate of its effect in this toy world. And that verified gap
# is far below the confident "9 points" in the summary. So the summary is refuted on the
# number, even though the study design is sound. In the cell below, write three things.
# First: the honest one-sentence finding the data support, using the verified gap your
# cell printed. Second: the sentence you must NOT repeat (the claimed 9). Third: name the
# failure mode this catches, and the exact check that caught it.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My honest finding (using the verified gap):**
#
# **The sentence I must NOT repeat:**
#
# **The failure mode, and the check that caught it:**
#
# ---

# %% [markdown]
# ---
#
# ### ⏸ In class through here
#
# **You have reached the end of Lecture 2's in-class block.** Everything below deepens
# the same ideas and feeds your M0 baseline. Finish it before Friday's studio: red-team
# the finding you wrote, adapt the attack to your own project, interrogate what comes
# back, make the AI-free never-delegate call, sort the five delegation cases, and draft
# your baseline. The 🧑‍⚖️ Human-Only Checkpoint is the core of M0, so give it real time.
#
# ---

# %% [markdown]
# **🏠 Homework depth: run this on your own after class.**
# **Before you ask:** you wrote an honest finding two cells up. Do not let your AI rewrite
# it for you. Commit it, then make your AI try to break it.
#
# > 💡 **AI Prompt:** "Here is a finding I wrote from a small randomized study:
# > '[paste your honest finding].' The verified gap in the data was the number my cell
# > printed, and a separate summary had claimed about 9 points. Act as a hostile peer
# > reviewer. Name every place my sentence over-reaches or hides uncertainty. Do not
# > rewrite it for me. List the specific weaknesses so I fix them myself."
# >
# > **After running, verify (counters *sycophantic agreement*: an AI that praises the
# > sentence you wrote has reviewed your ego, not your evidence):**
# > - [ ] If every objection is mild, or it calls your sentence "well-balanced," push
# >   back: "assume it is wrong, name the single worst flaw." Weak praise is a red flag.
# > - [ ] Check each objection against your printout. Reject any objection that treats
# >   the claimed 9 as the real effect; your verified gap is the smaller printed number.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# ### 🔁 Modify the Prompt
#
# Above, you had your AI attack a finding about the teaching study. Now do the same for
# *your* project. First, in one or two sentences, write an honest claim your project might
# make. Do not let AI draft it. Then adapt the attack prompt so your AI red-teams *your*
# sentence, naming your topic and the evidence you would actually have.
#
# > **Base prompt (the attack, from above):** "Here is a claim I wrote: '[your
# > sentence].' Act as a hostile peer reviewer and name every place it over-reaches or
# > hides uncertainty. Do not rewrite it for me."
#
# **🏠 Homework depth: run this on your own.**
# **Before you ask:** predict the single strongest objection your AI will raise, and write
# it down. Then rewrite the prompt for your project, run it, and compare.
#
# > 💡 **AI Prompt:** "Here is a claim from my honors project: '[your claim].' My
# > evidence is [what you would actually have]. Act as a hostile reviewer in my field.
# > Name every place the claim reaches past that evidence, and the one source or number I
# > most need to verify before I say it. Do not rewrite it for me; list the weaknesses."
# >
# > **After running, verify (counters *silent scope change*: a partner that quietly
# > broadens your claim has answered an easier question than you asked):**
# > - [ ] Read the reworded claim back against your original. Did the tool, or your fix,
# >   quietly widen "in my sample" into "in general"? If so, narrow it back.
# > - [ ] Pick the one source or number it flagged and actually retrieve or recompute it.
# >   An objection you cannot check yourself does not get to change your claim.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **An honest claim my project might make (AI did not draft this):**
#
# **My adapted attack prompt (my topic, my evidence):**
#
# **The strongest objection I predict your AI will raise:**
#
# **What your AI actually raised, and how I fixed my claim:**
#
# ---

# %% [markdown]
# ### 🔬 Interrogate the Output
#
# your AI just handed you a list of objections. Do not accept the attack as automatically
# right either. Interrogate it against the evidence, using four checks. Answer each in the
# cell below.
#
# - **Claims:** does each objection point to a real flaw? For the teaching study, the
#   verified gap was the smaller printed number, so an objection that you under-stated
#   uncertainty is fair, but one insisting the true effect really is 9 is simply wrong.
# - **Assumptions:** what does the attack assume about your data or design that you never
#   stated? An invented assumption is not your problem to fix.
# - **Missing information:** which real weakness did the attack *miss*? A reviewer that
#   skips your biggest limitation left the most important objection on the table.
# - **Overstatements:** does any objection sound more certain than the evidence supports?
#   Flag the exact words.
#
# Remember the governing rule: **a cell running without errors is not the same as the
# cell being correct.** Verify the number, not the green check.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Claims (does each objection match the evidence?):**
#
# **Assumptions (did the attack invent one?):**
#
# **Missing information (the real weakness it skipped):**
#
# **Overstatements (exact words):**
#
# ---

# %% [markdown]
# ### 🧑‍⚖️ Human-Only Checkpoint
#
# Close your AI for this one. No AI, no search. This is a never-delegate decision, and it
# is the core of your M0 baseline: what you assume about AI, and what you refuse to hand
# it. In the cell below, write, in your own words:
#
# 1. **Two things you currently assume AI is good at** for research, and for each, the
#    exact check that would confirm or break that assumption.
# 2. **Two decisions in your own project you will NOT let AI make**, drawn from the
#    never-delegate list, and one sentence on why each is yours to own.
# 3. **One honest worry** about your own automation bias: where are you most likely to
#    stop checking because an answer sounded good?
#
# If you cannot yet name where you over-trust the tool, that is itself a finding. It
# tells you which habit to watch first.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Two things I assume AI is good at (each with its check):**
#
# **Two decisions I will NOT delegate (and why each is mine):**
#
# **Where my own automation bias is most likely to bite:**
#
# ---

# %% [markdown]
# ### 📝 Practice: safe to delegate, verify first, or never delegate?
#
# *(Human-first: sort all five yourself before any AI. The sorting is the graded skill.)*
#
# For each task below, mark it **safe to delegate** (low stakes, easy to check),
# **delegate then verify** (fine to hand out, but you must check the result), or **never
# delegate** (a human-only judgment). Justify each in a phrase, in the cell that follows.
#
# - **A.** Draft three plain-language rewrites of a survey question you wrote.
# - **B.** Decide which of your two research questions is worth the semester.
# - **C.** Summarize what a paper argues, when you have the paper open in front of you.
# - **D.** Judge whether your data collection is fair to the people in it.
# - **E.** Reformat a messy table into a clean one.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **A (category + why):**
#
# **B (category + why):**
#
# **C (category + why):**
#
# **D (category + why):**
#
# **E (category + why):**
#
# ---

# %% [markdown]
# ### 🎯 Project Transfer: launch your M0 research-and-AI baseline
#
# *(Human-first: draft every piece yourself. AI may help you locate or format, but the
# baseline you defend at the studio has to be reasoned by you.)*
#
# This is where the week becomes your **M0 research-and-AI baseline**, the course's first
# milestone. In the cell below, assemble its spine for *your* start:
#
# 1. **Three curiosities**, each in two or three sentences: what you wonder, and why it
#    hooks you. Bring forward the pick you defended in Lecture 1.
# 2. **Your AI baseline**, from the Human-Only Checkpoint: two things you assume AI is
#    good at (each with its check), and two decisions you will not delegate.
# 3. **Tool readiness**: confirm your Colab ran the readiness cell, and that you can log
#    into the course tools. Note a screenshot of the passing checks for your submission.
# 4. **Your first Ledger row**: the citation catch from Lecture 1 counts. Fill one full
#    row in the ledger below.
#
# At Friday's studio you pitch one curiosity in 30 seconds and submit M0. Write these so a
# reader who has never met your project could see what you are curious about and where you
# already know to keep AI on a short leash.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **1. Three curiosities (2-3 sentences each, with my current pick marked):**
#
# **2. My AI baseline (two strengths with checks; two never-delegate decisions):**
#
# **3. Tool readiness (readiness cell passed? tools logged in?):**
#
# **4. My first Ledger row (see the ledger below):**
#
# ---

# %% [markdown]
# ### 📒 AI Research Ledger
#
# Log every AI use from this notebook in the ledger. One worked row is filled in as a
# model: it records the Lecture 1 citation catch, where **you asked, then verified by
# retrieving, then documented**. The ledger's fields are the course's discipline made
# concrete: task delegated, tool, prompt, output summary, decision, verification method,
# remaining concern, and the responsible researcher (you). It is a graded habit, not
# paperwork. It is how you show your work was checked.
#
# | Task delegated | Tool used | Prompt | Output summary | Decision | Verification method | Remaining concern | Responsible researcher |
# |---|---|---|---|---|---|---|---|
# | Find 4 scholarly sources on my topic and flag which to verify first | your AI | "Give me 4 scholarly sources on [topic]; authors, year, title, venue; only include work you are confident exists" | Four citations, all stated with equal confidence; one title returned nothing when searched | Kept the three I opened and confirmed; cut the one that would not resolve | Retrieved each exact title on Google Scholar and opened the real papers | The cut source might exist under a title I have not found yet | *(your name)* |
# |  |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |  |
#
# ---

# %% [markdown]
# ### 🛡️ Exit Defense
#
# Defense #00 — write, in your own words:
#
# 1. **The claim I can defend:** one bounded sentence, drawn from today's work or your own
#    project, that you would put your name on.
# 2. **Its boundary:** what this evidence does NOT establish. If it came from a
#    simulation, say the result is about the toy world, not the real one.
# 3. **My uncertainty and limitations:** one sentence naming what you do not yet know.
# 4. **AI check:** what you delegated to your AI, whether you **accepted, changed, or
#    rejected** what it returned, and the specific check that decided it (a source you
#    retrieved, a number you recomputed).

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **1. The claim I can defend:**
#
# **2. Its boundary:**
#
# **3. My uncertainty and limitations:**
#
# **4. AI check (what I delegated, how I verified):**
#
# ---

# %% [markdown]
# ## 5. Wrap-Up
#
# Across two lectures you set the terms for the whole course. You saw that when an AI can
# write the code and the prose, the human job that grows is judgment: what to ask, what
# counts as evidence, and where to stop. You proved to yourself that polish is not proof,
# because a fabricated source sounds exactly like a real one, so you verify by retrieving.
# You named the failures that fool careful people, automation bias and false confidence
# and the illusion of understanding, and you caught a confident summary that overstated a
# number the data never held. The loop that beats all of it is short: Ask, then Verify,
# then Document.
#
# > **"A claim you cannot trace to evidence you retrieved and checked is not knowledge.
# > It is a machine's guess wearing your voice. AI is your arm and your research
# > assistant, never your brain."**
#
# Next week, nb02 picks up your strongest curiosity and starts the real work: turning it
# into a research problem and a question evidence can answer, and meeting the **inquiry
# compass** that sorts questions by kind and reach. This notebook companions the course
# book's opening, Blair, Coppock and Humphreys, chapters 1 and 2. Bring your M0 baseline
# to Friday's studio. It is the raw material for everything that follows.
#
# ---

# %% [markdown]
# ## 6. Sources & Provenance
#
# **Provenance of this notebook:**
# - *fresh (course design brief + course_config ai_policy) | the course promise, Ask → Verify → Document, SDIIVDD, the never-delegate list, the AI Research Ledger | newly-constructed-from-source-concept*
# - *RDSS ch. 1 (Preface) + ch. 2 (What is a research design?) | concept | research as a declarable, defensible object | adapted (conceptual framing only)*
# - *la_voter_file.csv | rdss package data | loaded once as a day-one readiness check | adapted (loaded as-is)*
# - *fresh | the seeded citation-catch and toy claim-check simulations + the two loop diagrams | newly-constructed-from-source-concept (seed 464)*
#
# **Dataset attribution:** Dataset from the `rdss` package (Blair, Coppock &
# Humphreys, MIT License), companion to *Research Design in the Social Sciences*
# (2023).
#
# **Readings:**
# - Blair, G., Coppock, A., & Humphreys, M. (2023). *Research Design in the Social
#   Sciences: Declaration, Diagnosis, and Redesign.* Princeton University Press. Free
#   online: [book.declaredesign.org](https://book.declaredesign.org/). Skim the Preface
#   and ch. 2 before the next lecture.
# - Tversky, A., & Kahneman, D. (1974). "Judgment under Uncertainty: Heuristics and
#   Biases." *Science*, 185(4157). *(a real, landmark study of the confident mental
#   shortcuts that misfire; retrieving it is good verification practice)*
# - Open Science Collaboration (2015). "Estimating the reproducibility of psychological
#   science." *Science*, 349(6251), aac4716. *(a real re-run of 100 studies, on why
#   confident published results still need checking)*
# - *(Optional)* Bergstrom, C. T., & West, J. D. (2020). *Calling Bullshit.* Random
#   House. *(public cases at [callingbullshit.org](https://callingbullshit.org/))*
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>
