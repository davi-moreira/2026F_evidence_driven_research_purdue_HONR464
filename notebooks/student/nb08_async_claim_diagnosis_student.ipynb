# %% [markdown]
# # Diagnose a Misleading Claim (Async Module)
#
# <hr>
#
# <center>
# <div>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/notebooks/figures/honr_464_logo.png" width="200"/>
# </div>
# </center>
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/nb08_async_claim_diagnosis_student.ipynb)
#
# ---

# %% [markdown]
# ## 🧭 Inquiry & Claim Boundary
#
# **Inquiry emphasis:** all positions (claim diagnosis in the wild) — this Friday
# there is no live class. You are the analyst today. A claim has crossed your feed;
# your job is to take it apart carefully, with evidence and without cruelty, and say
# exactly what it is allowed to mean. Everything you have built so far — the inquiry
# compass (kind × reach), the sampling and assignment logic, the arithmetic behind a
# percentage — becomes a diagnostic toolkit here.
#
# | | |
# |---|---|
# | **A claim this topic PERMITS** | "The claim as stated needs [design]; the study ran [design]; therefore what stands is the weaker claim X." |
# | **A claim this topic does NOT permit** | Reflexive debunking ("this study is trash") with no statement of what evidence WOULD settle the question. |
#
# **Where this sits in the course:** meeting 17 of 44 — the asynchronous Friday
# that closes MIDA's Data strategy week and previews the Answer strategy (Monday's
# nb09). The diagnosis protocol you practice here is exactly what milestone M08 will
# later turn on your OWN design. This module also carries a block that assembles your
# M05 Data Strategy draft into one document.
#
# *Provenance: fresh claim-diagnosis protocol (claim / evidence / warrant + the compass-crossing diagnosis: kind × reach and the unlicensed crossing) + RDSS ch. 9 'Choosing an answer strategy' (opening, previewed for Monday); optional Calling Bullshit public case index | async module | constructed case study + recompute + charitable reconstruction | newly-constructed-from-source-concept*

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Break any claim into its **anatomy** — the claim itself, the evidence offered,
#    and the warrant that supposedly connects them.
# 2. Place a claim in the wild on the **inquiry compass** (its kind and reach) and
#    name **which crossing it smuggles** — the claim it NEEDED versus the claim it MADE.
# 3. **Recompute** a published number from a study's own table, and catch a real
#    arithmetic-or-framing slip when the recomputation disagrees.
# 4. Write a **structured diagnosis** — what stands, what falls, and what evidence
#    would settle the question — using charitable reconstruction rather than
#    reflexive debunking.
# 5. Preview the **estimand / estimator / estimate** triad that Monday formalizes.
# 6. Assemble the four pieces of your own **M05 Data Strategy** into one document.
#
# ---

# %%
# Setup — run this cell first.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 3)
plt.rcParams["figure.figsize"] = (9, 5)

SEED = 464  # course number — keeps every simulation reproducible
rng = np.random.default_rng(SEED)

# Data loads: GitHub raw URL first (works in Colab), local repo path as fallback.
DATA_URL = ("https://raw.githubusercontent.com/davi-moreira/"
            "2026F_evidence_driven_research_purdue_HONR464/main/notebooks/data/")

def load_course_data(filename):
    """Load a course dataset from GitHub, falling back to the local repo copy."""
    try:
        return pd.read_csv(DATA_URL + filename)
    except Exception:
        from pathlib import Path
        local = Path("notebooks/data") / filename
        if not local.exists():
            local = Path("../data") / filename
        return pd.read_csv(local)

print("✓ Setup complete — seed", SEED)

# %% [markdown]
# ## 1. Why This Matters — and How to Work This Async Module
#
# > *"By the time a correction runs, the headline has already been shared ten
# > thousand times. My whole job is the ten minutes BEFORE we publish: does the
# > number in the headline actually come out of the table underneath it? You would
# > be amazed how often it does not."*
# > — a **newsroom fact-checker** who reads the methods section first
#
# This Friday's class meets **asynchronously** — Professor Moreira is traveling, and
# this module stands in for the live session. Budget about **50 minutes** and work
# straight through: read the case, classify it, recompute its central number, write
# your diagnosis, preview Monday's ideas, and assemble your M05. Cells marked
# **YOUR ANSWER HERE** are where you write; run the code cells as you reach them.
#
# The skill today is **diagnosis without cruelty**. Anyone can shout "fake news" at
# a claim they dislike. What a researcher does is harder and more useful: take the
# claim apart, keep the piece that survives, name the piece that does not, and say
# precisely what evidence would settle the rest. That posture — **charitable
# reconstruction** — is the difference between debunking and understanding.
#
# > **A question that often comes up here:** *"If a study is flawed, why not just
# > throw the whole thing out?"* Because "flawed" is not a verdict, it is a
# > location — it tells you WHERE the claim outran its evidence, not that nothing
# > was learned. Almost every flawed study still supports some weaker, honest claim.
# > Finding that surviving claim is the whole point; discarding the study wholesale
# > throws away the part that was true along with the part that was oversold.
#
# ---

# %% [markdown]
# ## 2. The Case: A Campus-Wellness Story
#
# **Guiding question:** *Does every number in this confident story actually come out of the table printed beneath it?*
#
# Below is a news item from *The Boiler Wellness Beacon*. Read it the way you would
# read anything that crossed your feed — and notice how confident it sounds.
#
# > ⚠️ **This story is fictional — written for this module.** The outlet, the
# > survey, and every number in it are constructed. Nothing here is attributed to
# > any real publication or real study, on purpose: that disclosure is the
# > evidence-integrity rule in action — a *disclosed* fiction is an honest teaching
# > tool, a *fake attribution* would be a fabricated citation. Diagnose the numbers,
# > not the (nonexistent) authors.
#
# ---
#
# ### 🍳 Skip Breakfast, Skip Success? New Campus Data Says the Stakes Are High
# *The Boiler Wellness Beacon — Wellness Desk*
#
# **Undergraduates who skip breakfast are twice as likely to fail a course** — that
# is the striking finding from a campus wellness survey of 1,000 first-years this
# term. "The pattern was impossible to ignore," the write-up reports. Skippers
# failed courses at double the rate of breakfast-eaters, and, more alarmingly,
# **breakfast-skippers accounted for roughly two-thirds of all course failures on
# campus** — making a skipped morning meal *the single biggest driver of academic
# trouble* the survey uncovered. The takeaway, the Beacon urges: eat breakfast, and
# protect your GPA.
#
# ---
#
# Here is the entire data table the story was built on — the same numbers the
# Beacon's Wellness Desk had in front of them:
#
# | Group | Number surveyed | Failed a course | Passed all courses |
# |---|---|---|---|
# | Breakfast-skippers | 200 | 24 | 176 |
# | Breakfast-eaters | 800 | 48 | 752 |
# | **Total** | **1,000** | **72** | **928** |
#
# Every number the story cites is supposed to come out of this table. In a few
# cells you will check whether it does.

# %% [markdown]
# ### 🔮 Pause & Predict
#
# The story makes three quantitative claims: (a) skippers are **twice as likely** to
# fail; (b) skippers are **two-thirds of all failures**; (c) skipped breakfast is the
# **biggest driver** of academic trouble. **Before you recompute anything**, read the
# table and commit a prediction in the cell below: which of the three claims do you
# expect to survive an honest recomputation, and which do you expect to fall apart —
# and why?

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Which claim(s) will survive the numbers:**
#
# **Which claim(s) will fall apart, and why I suspect it:**
#
# ---

# %% [markdown]
# ## 3. The Anatomy of a Claim — and Where It Sits on the Compass
#
# **Guiding question:** *What is this claim actually made of — and which compass position is it reaching to occupy?*
#
# Before touching the arithmetic, take the claim apart structurally. Every claim has
# three parts, and naming them shows you where to aim:
#
# - **The claim** — what is asserted (skipping breakfast drives course failure).
# - **The evidence** — what is offered in support (a one-term survey of 1,000
#   first-years; a table of failure counts).
# - **The warrant** — the unstated bridge that says the evidence supports the claim
#   ("if skippers fail more in this survey, then skipping *causes* failure").
#
# Most overclaims break at the **warrant** — the evidence is real, but the bridge it
# is asked to carry is far too heavy. So the decisive question becomes: *place the
# claim on the inquiry compass — what kind of answer is it (descriptive or causal),
# and how far does it reach (the data at hand, a population, unseen cases)? — and
# which design would that position require?* That is the compass classification you
# have practiced all semester:
#
# - A **description** claim ("in this survey, skippers failed at a higher rate")
#   needs only honest counting of the data at hand.
# - A **generalization** claim ("first-years in general…") needs a defensible sample
#   and stated uncertainty — that is the sample→population crossing, licensed by a
#   sampling design.
# - A **causal** claim ("skipping breakfast *causes* failure") needs an
#   identification argument — ideally random assignment, at minimum serious control
#   of confounders — that is the descriptive→causal crossing, licensed by assignment
#   or a defended design.
#
# Here is the sharp version of the whole diagnosis: **every overclaim is a compass
# crossing made without paying for it.** A claim that speaks about a population its
# sample never earned is *the silent upgrade*; a forecast paraded as understanding
# *leaks* past the only thing it tested; a pattern narrated as a cause is
# *after-therefore-because*. Name the crossing and you have named the flaw.
#
# The Beacon's language — "driver," "protect your GPA," "eat breakfast" — is
# **causal**. Its evidence is a single-term observational survey — **descriptive,
# the data at hand**. That gap is a descriptive→causal crossing smuggled with no
# identification license: the heart of the diagnosis.

# %% [markdown]
# ### 📝 Practice
#
# Warm up your classifier on three other headlines. For each, name the **compass
# position the headline is claiming** (description / generalization / prediction /
# causal reasoning), **which crossing it smuggles** (silent upgrade / leakage /
# after-therefore-because), and the **strongest claim the stated evidence could
# actually permit**. Answer in the cell that follows.
#
# - **A.** "Campus survey: undergraduates who use the rec center report lower stress."
#   *(Evidence: a one-time voluntary survey.)*
# - **B.** "New model flags which first-years will struggle, with 85% accuracy."
#   *(Evidence: a model tested on last year's records.)*
# - **C.** "Living on campus raises first-year GPA, study finds."
#   *(Evidence: on-campus residents had higher GPAs than off-campus residents, same
#   term.)*

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **A — position claimed / crossing smuggled / strongest permitted claim:**
#
# **B — position claimed / crossing smuggled / strongest permitted claim:**
#
# **C — position claimed / crossing smuggled / strongest permitted claim:**
#
# ---

# %% [markdown]
# ### YOUR ANSWER HERE — place the Beacon's claim on the compass:
#
# Now the case itself. In the cell below, do two things. First: place the Beacon's
# claim on the compass — name the **position it is claiming** and the **position its
# evidence can actually support** — and name **which crossing it smuggles**. Second:
# write, in one sentence each, **the claim the story NEEDED to make** to be honest,
# and **the claim it actually MADE**.
#
# **Position the Beacon claims / position its evidence supports / crossing smuggled:**
#
# **The claim it NEEDED to make (honest version):**
#
# **The claim it MADE (as written):**
#
# ---

# %% [markdown]
# ## 4. Recompute the Central Number
#
# **Guiding question:** *When you rebuild the headline's numbers from scratch, which survive an honest recomputation and which fall apart?*
#
# A structural diagnosis tells you the claim reached too high. Now check whether the
# numbers even hold up on their own terms — because the Beacon made two *arithmetic*
# claims ("twice as likely," "two-thirds of failures") that either do or do not come
# out of that table. This is the **verify** habit made literal: never repeat a number
# you have not reproduced yourself.
#
# The next cell rebuilds the Beacon's own table and recomputes each claimed figure
# from scratch.

# %% [markdown]
# ### 🛠️ Hands-On: recompute the headline from its own table
#
# Run the cell below. It reconstructs the study's table, computes the two group
# failure rates, the relative risk ("twice as likely"), the *absolute* difference,
# and — the decisive one — the skippers' true share of all course failures. Read each
# printed line against what the story claimed.
#
# > 💡 **Gemini Prompt:** "There's no class today, so be my study partner on this
# > one. I'm recomputing the numbers behind a news claim straight from its own data
# > table: [paste the next cell]. Walk me through what each computed line means — the
# > two failure rates, the relative risk, the absolute gap, and the skippers' share
# > of all failures — as if we were working through it together."
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] Gemini is your study partner, not the verdict — the numbers your cell
# >   printed are. Check every figure it describes against the actual output (the two
# >   rates, and the 33% share of failures).
# > - [ ] If Gemini and your printout disagree on the two-thirds-versus-one-third
# >   point, trust the recomputation and note exactly where Gemini went wrong.
# > - [ ] Log this use in your AI ledger: tool, task, verification.

# %%
# The Beacon's own table, rebuilt exactly as printed.
case = pd.DataFrame({
    "group": ["Breakfast-skippers", "Breakfast-eaters"],
    "n": [200, 800],
    "failed": [24, 48],
})
case["passed"] = case["n"] - case["failed"]
case["failure_rate"] = case["failed"] / case["n"]
print("The study's own numbers:")
print(case.to_string(index=False))
print()

rate_skip = 24 / 200        # skippers' failure rate
rate_eat  = 48 / 800        # eaters' failure rate
print(f"Skipper failure rate : {rate_skip:.0%}   (24 of 200)")
print(f"Eater   failure rate : {rate_eat:.0%}    (48 of 800)")
print()

# Claim (a): "twice as likely to fail"
relative_risk = rate_skip / rate_eat
print(f"CLAIM (a) 'twice as likely'  → relative risk = {relative_risk:.1f}×   → TRUE, 12% vs 6%")

# ...but what the relative framing hides:
absolute_gap = rate_skip - rate_eat
print(f"   BUT the ABSOLUTE gap is only {absolute_gap:.0%} "
      f"(6 percentage points); {1 - rate_skip:.0%} of skippers did NOT fail.")
print()

# Claim (b): "two-thirds of all course failures came from skippers"
total_failures = case["failed"].sum()
true_share = 24 / total_failures
print(f"CLAIM (b) 'two-thirds of failures' → skippers' TRUE share = "
      f"24 / {total_failures} = {true_share:.0%}   → FALSE, that is a MINORITY")

# How the story likely got 'two-thirds': it compared the RATES, ignoring group size.
wrong_share = rate_skip / (rate_skip + rate_eat)
print(f"   The story's error: rate / (rate+rate) = {wrong_share:.0%} — a ratio of")
print(f"   RATES, not a share of PEOPLE. Eaters outnumber skippers 4-to-1, so their")
print(f"   6% is far more failures (48) than the skippers' 12% (24).")

# %%
# Self-check: pin down every recomputed figure so the diagnosis rests on facts.
assert relative_risk == 2.0, "the doubling claim should check out exactly"
assert abs(absolute_gap - 0.06) < 1e-9, "absolute gap should be 6 percentage points"
assert round(true_share, 3) == 0.333, "skippers are one-third of failures, not two-thirds"
assert total_failures == 72, "the table's failures must total 72"
print("✓ Self-check passed: the '2× likelier' claim is TRUE but small in absolute")
print("  terms; the 'two-thirds of failures' claim is FALSE — skippers are 33%, a")
print("  minority. One claim survives, one does not, and now you can prove both.")

# %% [markdown]
# ### The same numbers, two pictures
#
# The recomputation is done; now *see* why the story felt so alarming. The next cell
# draws the identical failure numbers two ways — the scary relative framing the
# headline leaned on, and the honest absolute framing that shows most skippers failed
# nothing.
#
# > 💡 **Gemini Prompt:** "Working solo today, so be my study partner here. This cell
# > plots the same breakfast-and-failure numbers two ways, a 'relative' framing and
# > an 'absolute' framing: [paste the next cell]. Explain how one honest dataset can
# > leave two opposite impressions depending on which framing a chart chooses."
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] Look at your two rendered panels and confirm Gemini's account matches them —
# >   does the right panel really show that most skippers (about 88%) did not fail?
# > - [ ] Gemini can suggest which framing is fairer, but you decide: check its
# >   reasoning against the bars you actually see, not the other way around.
# > - [ ] Log this use in your AI ledger: tool, task, verification.

# %%
# One picture makes the framing trick visible: the same data, two stories.
fig, axes = plt.subplots(1, 2, figsize=(11, 4.2))

# Left: the scary "relative" framing — bars of the two failure rates.
axes[0].bar(["Skippers", "Eaters"], [rate_skip, rate_eat],
            color=["#C44E52", "#4C72B0"])
axes[0].set_ylabel("Failure rate")
axes[0].set_ylim(0, 1)
axes[0].set_title("The headline's framing:\n'skippers fail at DOUBLE the rate'")
for i, r in enumerate([rate_skip, rate_eat]):
    axes[0].text(i, r + 0.02, f"{r:.0%}", ha="center", fontweight="bold")

# Right: the honest "absolute" framing — what happened to each 100 skippers.
axes[1].bar(["Failed", "Did NOT fail"], [rate_skip, 1 - rate_skip],
            color=["#C44E52", "#B0B0B0"])
axes[1].set_ylabel("Share of skippers")
axes[1].set_ylim(0, 1)
axes[1].set_title("The same skippers, whole picture:\n88% did not fail a course")
for i, r in enumerate([rate_skip, 1 - rate_skip]):
    axes[1].text(i, r + 0.02, f"{r:.0%}", ha="center", fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 Reading the Evidence
#
# You now have the numbers. In the cell below, write three things. First: state the
# one claim from the story that **survives** the recomputation, worded exactly as
# tightly as the data permit. Second: state the one quantitative claim that **falls**,
# and name the specific mistake that produced it (be precise: what did the writer
# divide by what?). Third: even setting the arithmetic aside, name the deeper reason
# the "biggest driver" language is not something this study could ever support — the
# design word for what is missing.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The claim that survives (worded to the data's edge):**
#
# **The claim that falls, and the exact arithmetic mistake behind it:**
#
# **The design reason 'biggest driver' was never supportable (name the missing thing):**
#
# ---

# %% [markdown]
# ## 5. The Structured Diagnosis — What Stands, What Falls, What Would Settle It
#
# A diagnosis is not a verdict of "good" or "bad." It is a three-part memo that a fair
# reader could act on:
#
# 1. **What stands** — the claim the evidence genuinely supports, stated at its true
#    (usually more modest) altitude.
# 2. **What falls** — the specific overreach, named precisely, with the reason it does
#    not follow.
# 3. **What evidence would settle it** — the design that could actually answer the
#    question the headline was reaching for.
#
# That third part is what separates a researcher from a heckler. Debunking stops at
# "this is wrong." Diagnosis continues: *here is what would make it right, or prove it
# wrong for good.* For the breakfast claim, settling it would take a design that
# breaks the confounding — randomly assigning some first-years to a free-breakfast
# program and comparing course outcomes, or at minimum an observational study that
# measures and adjusts for sleep, work hours, and prior performance.
#
# > **A question that often comes up here:** *"Isn't 'charitable reconstruction' just
# > letting a bad claim off the hook?"* The opposite. Steel-manning a claim — stating
# > the strongest honest version before you critique it — makes your critique
# > *harder* to dismiss, because no one can say you attacked a caricature. It also
# > protects you: the version of you that always finds the surviving true claim is the
# > version reviewers trust when you say something genuinely does not hold.

# %% [markdown]
# ### ⚖️ Make a Design Choice
#
# Two follow-up studies are proposed to settle whether breakfast actually affects
# course outcomes. In the cell below, choose the one you would fund and defend it in a
# short paragraph — say what your choice buys that the other does not, and what it
# still cannot rule out.
#
# - **Option A —** A randomized program: 300 volunteer first-years are randomly
#   assigned to a free-breakfast plan or not, and course outcomes are compared at
#   term's end.
# - **Option B —** A larger survey: 5,000 first-years are asked in detail about
#   breakfast habits, sleep, work hours, and grades, and the breakfast–failure
#   association is re-estimated adjusting for the rest.
#
# > 💡 **Gemini Prompt:** "I am evaluating a claim that
# > skipping breakfast causes course failure, based on an observational campus
# > survey. List the confounding variables most likely to produce a spurious
# > breakfast–failure association, and for each, explain which direction it would
# > bias the observed relationship."
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] For each confounder the AI names, decide *yourself* whether it plausibly
# >   causes both skipped breakfast AND course failure — that double link is what
# >   makes it a confounder, and only you can judge the mechanism.
# > - [ ] Cross-check one claimed bias direction against your own reasoning before you
# >   write it into your diagnosis; do not paste the AI's list unexamined.
# > - [ ] Log this use in your AI ledger: tool, task, verification.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The option I would fund:**
#
# **What it buys that the other does not:**
#
# **What it still cannot rule out:**
#
# ---

# %% [markdown]
# ### YOUR ANSWER HERE — write the diagnosis memo:
#
# This is the module's central artifact. Write the three-part diagnosis of the
# Beacon's claim in the cell below — a paragraph a fair reader could act on. Lead with
# the surviving claim (charitable reconstruction), then the overreach and why it does
# not follow, then the evidence that would settle it.
#
# **What stands (the surviving, honest claim):**
#
# **What falls (the overreach, named precisely, and why):**
#
# **What evidence would settle the question the headline reached for:**
#
# ---

# %% [markdown]
# ### 🎟️ Claim Ticket
#
# **Claim Ticket #17** — in ONE sentence, write the **weaker-but-true claim** the
# Beacon could honestly have published from its own data. Then, once you have written
# it, **post it to the async discussion board**: share the single most surprising line
# from your diagnosis, and reply to one classmate's post with a **steel-man** — the
# strongest honest version of the claim they diagnosed, before any critique.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Claim Ticket #17 — the weaker-but-true claim (one sentence):**
#
# **My most surprising diagnosis line (for the board):**
#
# ---

# %% [markdown]
# ---
#
# ## 6. Preview of Monday: The Estimand / Estimator / Estimate Triad
#
# Everything you just did by hand — deciding what the study *should* have measured,
# what procedure would measure it, and what number came out — has three formal names
# that Monday's class (nb09) will make precise. Learn the words now, using a cooking
# metaphor that will carry all week:
#
# - **Estimand** — the true quantity you are after, the number the world actually
#   holds. *The dish the genie would serve you if you could ask.* For the breakfast
#   question, it is the real causal effect of breakfast on course failure — which no
#   survey ever handed us.
# - **Estimator** — the *recipe*: the exact procedure you apply to data to produce an
#   answer (a difference in failure rates, a regression, a difference-in-means).
# - **Estimate** — the *dish you actually cooked*: the specific number the recipe
#   returns on your data (12% minus 6% = 6 percentage points).
#
# The Beacon's deepest problem, in these words: it reported an **estimate** (a rate
# difference) as if it were the **estimand** (the causal effect) — serving the dish it
# cooked as though it were the dish the genie promised. Monday you will build the
# recipe yourself, on a world where you actually get to peek at the genie's number and
# measure exactly how far your recipe lands from it.
#
# > **A question that often comes up here:** *"If we can never see the estimand, how do
# > we know any recipe is any good?"* Because you can build a pretend world where you
# > DID plant the true number yourself, run your recipe on it, and check the miss —
# > which is precisely what nb09 does. Testing your recipe on a world whose truth you
# > control is how you earn trust in it before pointing it at a world whose truth you
# > do not.

# %% [markdown]
# ## 7. Project Transfer — Diagnose Your Own Premise
#
# The most valuable target for this diagnosis habit is your OWN project. In the cell
# below, take the central claim your research question assumes is true (or hopes to
# establish) and run the same protocol on it: which compass position does your claim
# need (kind + reach), which claim are you currently positioned to actually make, and
# what is the one piece of evidence that would most move you? Steel-man your own
# premise, then find its softest spot — the version of you that does this now will not
# be ambushed by a reviewer later.
#
# > 💡 **Gemini Prompt:** "No class today, so act as my study partner and a friendly
# > reviewer. Here is my project's central claim: '[paste your claim]', and the
# > evidence I currently have is '[describe it]'. First steel-man the claim, then come
# > at it: which compass position (kind + reach) would it truly need, and where is it
# > softest?"
# >
# > **After running, verify (the responsible-AI habit):**
# > - [ ] Treat Gemini's critique as a study partner's notes, not a grade — keep only
# >   the weaknesses you can confirm are real about *your* evidence.
# > - [ ] Make sure the position it names (description / generalization / prediction /
# >   causal reasoning) actually matches what your design can deliver before you write
# >   it down.
# > - [ ] Log this use in your AI ledger: tool, task, verification.

# %% [markdown]
# ### 🎯 Project Transfer
#
# ### YOUR ANSWER HERE:
#
# **My project's central claim, stated plainly:**
#
# **The position it NEEDS (kind + reach) vs the position I can currently support:**
#
# **The one piece of evidence that would most strengthen (or overturn) it:**
#
# ---

# %% [markdown]
# ## 8. Assemble Your M05 Data Strategy
#
# Now stitch your week together. Across M15 and M16 you drafted four pieces — a
# **sampling** paragraph, an **assignment** reasoning, a **feasibility** triage, and an
# **ethics** paragraph. Your M05 Data Strategy is those four assembled into one clean
# document, due Sunday night with this module. In the cell below, paste your four
# paragraphs in order and add two connective sentences: one opening line naming your
# population and design in a breath, and one closing line naming the single biggest
# threat your data strategy still carries. Read the whole thing once out loud — if any
# seam contradicts another (a population your frame cannot reach, an assignment your
# feasibility rules out), fix it now, while the pieces are fresh.

# %% [markdown]
# ### YOUR ANSWER HERE — my assembled M05:
#
# **Opening line (population + design in one breath):**
#
# **1. Sampling paragraph (from M15):**
#
# **2. Assignment reasoning (from M16):**
#
# **3. Feasibility triage (from M16):**
#
# **4. Ethics paragraph (from M16):**
#
# **Closing line (the biggest remaining threat to this data strategy):**
#
# ---

# %% [markdown]
# ## 9. Submit Checkpoint
#
# Before you close the module, confirm you have completed each piece — this is what is
# due on Brightspace by **Sunday 11:59 PM**:
#
# - [ ] **The diagnosis memo** (§5): what stands, what falls, what would settle it.
# - [ ] **The recompute cells** (§4) run, with the self-check showing ✓.
# - [ ] **Claim Ticket #17** (§5): your weaker-but-true one-sentence claim.
# - [ ] **A discussion-board post** with your most surprising line **and** one
#   steel-man reply to a classmate.
# - [ ] **Your assembled M05 Data Strategy** (§8), full draft.
#
# If you got stuck anywhere, that is expected on an async day — the discussion board is
# monitored Friday afternoon, and office hours can be booked from the link on
# Brightspace. **Optional enrichment:** the Calling Bullshit case-study index at
# [callingbullshit.org/case_studies.html](https://callingbullshit.org/case_studies.html)
# collects real-world claims worth diagnosing with exactly today's protocol; pick one
# that touches your field and try the three-part memo on it.
#
# ---

# %% [markdown]
# ## 10. Wrap-Up
#
# Working alone today, you did a real analyst's job. You took a confident campus
# headline apart into claim, evidence, and warrant; you classified it as a causal
# claim riding on descriptive evidence; you recomputed its numbers and caught a real
# slip — a minority (one-third) dressed up as a majority (two-thirds) by dividing
# rates instead of counting people; and you wrote a diagnosis that kept the surviving
# truth, named the overreach precisely, and pointed to the design that would settle
# it. That is charitable reconstruction, and it is a far more powerful move than
# debunking.
#
# > **"The goal is never to prove a claim wrong. It is to find the exact altitude at
# > which the claim becomes true — and to say, precisely, what evidence would let it
# > climb higher."**
#
# Monday, nb09 turns this diagnostic instinct into a construction skill: you will
# build the **answer strategy** — the estimand, estimator, and estimate — on a world
# whose true number you plant yourself, so you can measure exactly how close your
# recipe lands. The habit you practiced on someone else's claim today is the habit
# milestone M08 will turn on your own design. Bring your assembled M05; submit both by
# Sunday night.
#
# ---

# %% [markdown]
# ## 11. Sources & Provenance
#
# **Provenance of this notebook:**
# - *fresh | claim-diagnosis protocol (claim / evidence / warrant anatomy + compass-crossing classification: kind × reach and the unlicensed crossing + charitable reconstruction) | — | newly-constructed-from-source-concept*
# - *fresh | constructed case study (*The Boiler Wellness Beacon*, fully fictional, disclosed) with an embedded, recomputable table carrying a real relative-vs-absolute framing slip and a wrong-base arithmetic error | — | newly-constructed-for-the-module*
# - *RDSS ch. 9 'Choosing an answer strategy' (opening) | the estimand / estimator / estimate triad | previewed conceptually (the cooking metaphor) ahead of nb09 | adapted (concept-level preview)*
# - *Calling Bullshit case-study index (optional enrichment) | public case studies | linked only, no case reproduced | referenced*
#
# **Readings:**
# - Blair, G., Coppock, A., & Humphreys, M. (2023). *Research Design in the Social
#   Sciences*, ch. 9 'Choosing an answer strategy' (opening sections — preview for
#   Monday). Free online: [book.declaredesign.org](https://book.declaredesign.org/).
# - Bergstrom, C. T., & West, J. D. *Calling Bullshit* case-study index (optional):
#   [callingbullshit.org/case_studies.html](https://callingbullshit.org/case_studies.html).
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>
