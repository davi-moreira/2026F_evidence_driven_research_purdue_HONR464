# %% [markdown]
# # Managing Multiple AI Agents
#
# **Topic 16 · 2 lectures**
#
# <hr>
#
# <center>
# <div>
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" width="300"/>
# </div>
# </center>
#
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/nb16_managing_ai_agents_student.ipynb)
#
# ---

# %% [markdown]
# ## 🧭 Inquiry & Claim Boundary
#
# **Inquiry emphasis:** This is
# the final week, and it is cross-cutting. It adds no new compass position. Instead it
# manages the AI workflow that runs across every position you already learned, then
# closes the course by defending your claims out loud at their boundaries.
#
# **Design pathway:** cross-cutting (multi-agent). You will not build a new design this
# week. You will run several AI roles on your own chapter draft, reconcile them when
# they clash, and take the pen back at the decisions that are yours alone.
#
# | | |
# |---|---|
# | **A claim this topic PERMITS** | "I gave each AI role a scoped task and an independent reviewer, I can name what each one did and did not touch, and where they agreed I checked the agreement was not one error repeated three times." |
# | **A claim this topic does NOT permit** | "The agents handled it," or "all the agents agreed, so it must be right": a workflow whose outputs no human scoped, traced, or owned, or a false consensus mistaken for confirmation. |
#
# **Where this sits in the course:** the last week. It develops **M15**, your final
# research chapter and AI-management portfolio, and it stages the **Evidence Defense**
# you perform this week. It builds on the AI Research Ledger habit you have kept all
# semester, and it is terminal: no revision follows.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. **Decompose** a chapter task into scoped AI roles, decide which run in parallel and
#    which run in sequence, and say which decision each role is allowed to touch.
# 2. Run a **worker-critic** workflow on a draft and read what parallel structure buys
#    you against what a sequential chain buys you.
# 3. Tell **real disagreement** from **correlated error** and **false consensus**, and
#    name the independent check that settles which one you are looking at.
# 4. State a **stopping rule** for your own confidence, apply **human override** at an
#    escalation trigger, and name the decisions that should never be automated.
# 5. Structure a ten-minute **Evidence Defense** around claims, choices, and
#    verification, concede gracefully where your ledger says concede, and avoid the
#    three forbidden moves.
# 6. Apply all of this to your own project's **M15** research chapter and AI-management
#    portfolio.
#
# ---

# %%
# Setup — run this cell first.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx  # for the workflow DAGs; if missing locally: pip install networkx (pre-installed in Colab)

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 3)
plt.rcParams["figure.figsize"] = (9, 5)

SEED = 464  # course number — keeps every simulation reproducible
rng = np.random.default_rng(SEED)

# Data loads: GitHub raw URL first (works in Colab), local repo path as fallback.
# This week's "data" is your own chapter draft, so the loader is here for parity only.
DATA_URL = ("https://raw.githubusercontent.com/davi-moreira/"
            "2026F_evidence_driven_research_purdue_HONR464/main/notebooks/data/")

def load_course_data(filename):
    """Load a course dataset from GitHub, falling back to the local repo copy."""
    try:
        return pd.read_csv(DATA_URL + filename)
    except Exception:
        from pathlib import Path
        local = Path("notebooks/data") / filename
        if not local.exists():
            local = Path("../data") / filename
        return pd.read_csv(local)

print("✓ Setup complete — seed", SEED)

# %% [markdown]
# ### 💡 Where "agents" sits on the six-level scale
#
# The title says "agents," so be exact about what that means here. Your **agents** are
# **human-run reviewer roles**: AI critics you open, task, and read one at a time, with
# your own decision at every hand-off. For example, you run a citation checker, read its
# output, decide what to keep, then hand the cleaned draft to a leakage auditor. Nothing
# here plans or acts on its own.
#
# AI collaboration runs on an honest six-level scale. Knowing which level you are on
# keeps you from overclaiming what you did.
#
# | Level | Name | What it is |
# |---|---|---|
# | 1 | Prompted role | You paste a role instruction into a plain chat with a base model. |
# | 2 | Custom model | A saved model that already carries the role instruction for you. |
# | 3 | RAG assistant | A custom model with a course knowledge base attached for retrieval. |
# | 4 | Sequential multi-role workflow | You run several roles in a planned order, carrying each output to the next. **You** are the orchestrator. |
# | 5 | Autonomous agent | A model that plans and takes actions on its own, with no human in each step. |
# | 6 | Multi-agent orchestration | Several autonomous agents coordinating a task by themselves. |
#
# **This week is level 4.** A **sequential multi-role workflow** means you plan an
# order, run one role, then feed its result to the next, staying in charge the whole
# time. Example: worker roles draft, a critic role attacks the draft, and you decide
# what survives. You sequence the roles by hand; they never call each other.
#
# **Levels 5 and 6 are named here so you can recognize them, not used.** An
# **autonomous agent** (level 5) acts without you in the loop, and **multi-agent
# orchestration** (level 6) lets several such agents coordinate on their own. Neither
# GenAI Studio nor your AI is run at those levels anywhere in this course. You never hand
# a research decision to a process no human scoped, traced, or owned.
#
# ---

# %% [markdown]
# # Lecture 1

# %% [markdown]
# 🗺️ **Today's frame (Monday, 9 / 22 / 12 / 7):** open with the 🧩 puzzle and 🔮 **Predict First** · investigate with 🛠️ **Run the Study** and your AI · verify with 🔍 **Read the Evidence** · drill 📝 **Practice** aloud and take ⚖️ **Make a Design Choice** · close in the room with 🎯 **Take It to Your Project**, 🛡️ **Defend Your Decision**, and your 📒 ledger row. All seven moves happen in class; 🏠-marked items and everything below the ⏸ line are optional depth.

# %% [markdown]
# ### 🎤 SRL Lead Brief
#
# *This lecture opens with its Student Research Lead. If this is your slot, this
# brief is your backbone. If not, read along: this is how the room will run.*
#
# **Your mission.** By minute 50, everyone in the room can name which AI role has to
# wait on which, defend every dependency they drew, and hold a first decomposition of
# their own chapter into scoped, checkable roles.
#
# **Run of show (Monday: 9 / 22 / 12 / 7).**
#
# | Min | Section | What you do |
# |---|---|---|
# | 0–9 | Research puzzle | Pose the puzzle below and make everyone commit an answer in writing before any AI is opened. |
# | 9–31 | Guided AI investigation | Steer the room through Sections 1 and 2: scoped tasks, specialization, and context allocation, then parallel versus sequential and the critical path. Run the workflow-graph cell live. Keep asking one thing: does this role have anything to read yet, or is it still waiting on somebody's output? |
# | 31–43 | Verification + formalization | The room checks the printed depth and width against the order it committed to on paper, then hands the corrected wiring to your instructor for the formal wrap on decomposition, specialization, and the worker-critic structure. |
# | 43–50 | Decision and defense | Everyone records the decision and a ledger entry; close on a spoken Claim Ticket. |
#
# **Three questions that keep the room thinking.**
#
# 1. *"Which two roles can safely read the draft at the same moment?"* Listen for: any
#    two independent lenses, like a clarity reviewer and a citation-checker, because
#    neither one needs the other's output. Watch out for: "all four at once," which
#    forgets that the critics have no draft to read yet.
# 2. *"Which role must wait, and for whose output?"* Listen for: every critic waits on
#    the worker's draft, and that single dependency is what sets the critical path.
# 3. *"When two roles disagree, who decides?"* Listen for: you do, and the next lecture
#    is about how. Watch out for: "take the majority," which is a vote among roles that
#    may have been built the same way.
#
# **One AI trap to watch for.** Ask a chatbot "what is the best multi-agent setup?" and
# it hands back a fluent, generic pipeline that never mentions one section of the actual
# chapter. That is illusion of completeness: the answer looks whole because it is shaped
# like an answer, not because it fits this work. When it appears, read the tidy pipeline
# back against one real section heading, then send everyone to decompose their own
# chapter into tasks small enough to check.
#
# **Checkpoints.** By minute 9, the four roles are on the board with the worker-first
# dependency named out loud. By minute 31, the parallel and the sequential critical
# paths sit side by side, with both depth numbers read off the printout rather than
# guessed. By minute 43, everyone holds a first decomposition of their own chapter.
#
# **Make it yours.** The frame, the puzzle, and the checkpoints are fixed;
# the staging is yours. Swap the four generic roles for four your own project actually
# needs and open with those, or restage the puzzle as a live bet: two volunteers argue
# opposite orders, the room votes before the graph cell runs, then votes again after
# the depth and width print. In your prep script, name one thing you are adding that
# this brief does not contain.
#
# **Prep.** Start about a week ahead. Submit your preparation script or notebook
# two days ahead. The full guide is the course book's Student Research Lead
# appendix.

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(Your research lead opens the lecture with this. Think it through and commit an
# answer before we go further. No AI yet.)*
#
# You have one chapter draft and four AI roles waiting: a **reviewer** (is the writing
# clear?), a **methodologist** (is the design sound?), a **skeptic** (what breaks
# this?), and an **editor** (is it tight?).
#
# Here is the question on the table. **Who works first, who can work at the same time,
# and which output do you trust when two of them disagree?** Commit to an order before
# we go further. Then defend it: name one pair of roles that can safely read the draft
# at the same moment, one role that must wait for another's output, and the one role
# whose job is to disagree with the others. If your order lets an early mistake flow
# downstream unchecked, it is the wrong order. Wiring these four roles is the whole job
# of Lecture 1.

# %% [markdown]
# ## 1. Decompose the Chapter Into Scoped Roles
#
# **Guiding question:** *how do you split one big writing task into jobs small enough
# that a single AI role can own each one and be checked on it?*
#
# > *"Bring me a chapter, not a pile of AI output. I want to know which part each tool
# > touched, what you told it to do, and how you checked it. If you cannot tell me
# > that, you did not write the chapter. The tools did, and neither of us can defend
# > it."*
# > — your **thesis advisor**, on the draft you will defend this week
#
# The move that makes a team of roles work is **task decomposition**: breaking one job
# into smaller subtasks, each with a clear owner. Example: instead of "improve my
# chapter," you split it into check the design, check the citations, tighten the prose.
# Each piece is now checkable on its own.
#
# Three ideas make decomposition pay off, and each is a term your M15 portfolio uses.
#
# - **Scoped task**: a job narrow enough to state in one sentence and check in one
#   pass. Example: "flag every claim in section 2 that reaches past my sample."
#   A scoped task has a clear pass or fail. "Make it better" does not.
# - **Agent specialization**: giving one role one lens instead of asking a generalist
#   for everything. Example: a skeptic briefed only to attack your weakest claim
#   finds sharper holes than a role told to "review the whole thing." A narrow brief
#   earns a sharper answer.
# - **Context allocation**: deciding how much of your material each role actually
#   sees. Example: your citation-checker needs the reference list, not your
#   half-finished discussion section. More context is not always better. Extra
#   material can bury the one thing you wanted checked.
#
# > **A question that often comes up here:** *"If specializing a role makes it sharper,
# > why not split my chapter into twenty tiny roles?"* Because every split costs you a
# > hand-off you have to manage and verify. Past a point, you spend more effort wiring
# > and checking roles than the sharper answers are worth. Decompose until each subtask
# > is checkable, then stop. The goal is a workflow you can supervise, not the most
# > roles possible.

# %% [markdown]
# Two more terms name what turns a pile of roles into a workflow you can trust.
#
# - **Independent review**: a second role checks the first role's work without sharing
#   its assumptions. Example: the role that drafts your summary should not also be the
#   role that decides the summary is accurate. The checker has to be able to disagree.
# - **Worker-critic structure**: pairing a role that produces (the worker) with a
#   role that attacks what it produced (the critic). Example: a worker drafts your
#   limitations paragraph, then a critic hunts for the limitation it left out. The
#   critic's whole job is to find what the worker missed.
#
# The worker-critic pair is the backbone of this week. A worker alone gives you a
# draft that is confident about its own quality, which is exactly the blind spot you
# cannot see from the inside. A critic that never wrote the draft can. But the critic
# only helps if it is genuinely independent, and Lecture 2 shows what happens when it
# is not.
#
# Now wire the roles into an order.

# %% [markdown]
# ## 2. Wire the Workflow: Parallel, Sequential, and the Critical Path
#
# **Guiding question:** *which roles can safely work at the same time, and which must
# wait for another role's output before they can start?*
#
# Two words decide the wiring, and getting them wrong either wastes effort or lets one
# early error poison everything downstream.
#
# - **Parallel**: two roles run at the same time because neither needs the other's
#   output. Example: a reviewer checking clarity and a citation-checker checking
#   sources can both read the same draft at once. They are independent lenses on the
#   same input.
# - **Sequential**: one role must wait for another to finish, because it needs that
#   output as its input. Example: a critic cannot attack a draft that the worker has
#   not written yet. This is a **dependency**, a required order between two subtasks.
#
# The **critical path** is the longest chain of dependencies in your workflow: the
# roles that must happen one after another, with no shortcut. Example: worker drafts,
# then critic attacks, then you integrate. That chain sets how many rounds your
# workflow takes at minimum, because nothing can collapse a step that truly depends on
# the one before it.
#
# You will build a small worker-critic workflow as a **directed graph**, a picture of
# arrows where each arrow means "this feeds that." Then you will read its critical path
# off the code, not off a guess.

# %% [markdown]
# ### 🔮 Predict First
#
# You are about to build a workflow where a worker drafts, then three critic roles (a
# reviewer, a methodologist, and a skeptic) all read that draft, then you integrate
# their notes, then an editor tightens the result. Six nodes in all: five AI roles and
# you.
#
# Before running the next cell, commit to two numbers. First, the **critical-path
# depth**: the longest chain of must-follow-must steps, counted in arrows. Second, the
# **maximum parallel width**: the most roles that can run at the same moment. Write one
# sentence of reasoning for each.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My predicted critical-path depth (arrows in the longest chain):**
#
# **My predicted maximum parallel width (most roles running at once):**
#
# **One sentence of reasoning:**
#
# ---

# %% [markdown]
# ### 🛠️ Run the Study: build the worker-critic workflow
#
# Run the cell below. It builds the workflow as a directed graph, computes the
# critical-path depth and the maximum parallel width, and draws it. Read the two
# numbers before you read the next markdown cell. If you want, move the skeptic to run
# *after* the reviewer (the second graph in the cell) and watch the critical path grow.
#
# **🔴 Live in class: we build this one together.**
# **Before you ask:** in one sentence, name which single role, if it runs too early,
# would let its mistake flow into every role downstream.
#
# > 💡 **AI Prompt:** "Here is a Python cell that builds a worker-critic workflow as
# > a directed graph and prints its critical-path depth and maximum parallel width:
# > [paste the next cell]. Explain, step by step, what `topological_generations` and
# > `dag_longest_path_length` compute here, and why running the three critics in
# > parallel gives a shorter critical path than running them one after another. Then
# > give me one independent way to confirm the critical-path depth without rerunning
# > this code."
# >
# > **After running, verify (counters *confident fabrication*: a fluent walkthrough can
# > describe a depth the graph never had):**
# > - [ ] Confirm the depth your AI quotes equals the `critical-path depth` your cell
# >   actually printed, not a number it guessed.
# > - [ ] Trace the longest path it names by hand along the arrows in the drawing. If
# >   its path skips an arrow or invents one, trust the drawing.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %%
# Build the worker-critic workflow as a directed graph.
# Nodes: five AI roles (worker, three critics, editor) plus YOU, the integrator.
# (networkx is imported once in the setup cell.)
G = nx.DiGraph()
parallel_edges = [
    ("Worker\ndraft", "Reviewer"),
    ("Worker\ndraft", "Methodologist"),
    ("Worker\ndraft", "Skeptic"),
    ("Reviewer", "You\nintegrate"),
    ("Methodologist", "You\nintegrate"),
    ("Skeptic", "You\nintegrate"),
    ("You\nintegrate", "Editor"),
]
G.add_edges_from(parallel_edges)

generations = list(nx.topological_generations(G))
depth = nx.dag_longest_path_length(G)          # longest dependency chain, in arrows
width = max(len(layer) for layer in generations)  # most roles that can run at once

print("Worker-critic workflow (three critics in PARALLEL):")
print(f"  roles + you (nodes)     : {G.number_of_nodes()}")
print(f"  dependencies (arrows)   : {G.number_of_edges()}")
print(f"  critical-path depth     : {depth} arrows  ({len(generations)} rounds)")
print(f"  maximum parallel width  : {width} roles at once")
print(f"  the critical path       : {' -> '.join(p.replace(chr(10), ' ') for p in nx.dag_longest_path(G))}")

# The SEQUENTIAL variant: the skeptic now waits for the reviewer's notes.
H = nx.DiGraph()
H.add_edges_from([
    ("Worker\ndraft", "Reviewer"),
    ("Worker\ndraft", "Methodologist"),
    ("Reviewer", "Skeptic"),               # skeptic now depends on the reviewer
    ("Skeptic", "You\nintegrate"),
    ("Methodologist", "You\nintegrate"),
    ("You\nintegrate", "Editor"),
])
gens_seq = list(nx.topological_generations(H))
print("\nIf the skeptic instead waits for the reviewer (one critic made SEQUENTIAL):")
print(f"  critical-path depth     : {nx.dag_longest_path_length(H)} arrows  ({len(gens_seq)} rounds)")
print(f"  maximum parallel width  : {max(len(l) for l in gens_seq)} roles at once")

# Draw the parallel workflow.
pos = {
    "Worker\ndraft":    (0.0, 1.0),
    "Reviewer":          (1.6, 1.9),
    "Methodologist":     (1.6, 1.0),
    "Skeptic":           (1.6, 0.1),
    "You\nintegrate":   (3.2, 1.0),
    "Editor":            (4.8, 1.0),
}
colors = {
    "Worker\ndraft": "#4C72B0", "Reviewer": "#8AA9D6", "Methodologist": "#8AA9D6",
    "Skeptic": "#8AA9D6", "You\nintegrate": "#55A868", "Editor": "#4C72B0",
}
fig, ax = plt.subplots(figsize=(10, 4.5))
nx.draw_networkx_nodes(G, pos, node_color=[colors[n] for n in G.nodes()],
                       edgecolors="#333333", linewidths=1.5, node_size=4600, ax=ax)
nx.draw_networkx_labels(G, pos, font_size=8.5, ax=ax)
nx.draw_networkx_edges(G, pos, arrowstyle="-|>", arrowsize=16, edge_color="#777777",
                       width=1.5, node_size=4600, ax=ax)
ax.set_title("A worker-critic workflow: three critics in parallel, then you integrate")
ax.axis("off")
plt.tight_layout()
plt.show()

print("\n✓ Workflow built. The green node is YOU: the integrator no role can replace.")

# %%
# Self-check: the parallel workflow has depth 3 and width 3; sequencing a critic costs a round.
assert G.number_of_nodes() == 6, "expected 5 AI roles + you"
assert depth == 3, "parallel critical-path depth should be 3 arrows"
assert width == 3, "three critics should run in parallel (width 3)"
assert nx.dag_longest_path_length(H) == 4, "sequencing the skeptic should deepen the path to 4"
print(f"✓ Self-check passed: parallel depth {depth} (width {width}); the sequential "
      f"variant deepens to {nx.dag_longest_path_length(H)} arrows.\n"
      f"  Parallel buys you speed and three independent lenses at once; sequencing buys "
      f"the skeptic the reviewer's context, at the cost of one more round.")

# %% [markdown]
# ### 🔍 Read the Evidence: what the wiring buys you
#
# The parallel workflow has a critical-path depth of **3 arrows** and runs up to **3
# critic roles at once**. Sequencing one critic deepens the path to **4 arrows** and
# narrows the width to 2. Neither wiring is simply better. In the cell below, write
# three things. First: one situation where the parallel wiring is the right call.
# Second: one situation where you would pay the extra round to run the skeptic
# *after* the reviewer instead. Third: name the one node in this workflow that no AI
# role can take over, and say why.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **When parallel is the right call:**
#
# **When I would pay a round to make the skeptic sequential:**
#
# **The node no AI role can take over, and why:**
#
# ---

# %% [markdown]
# You have decomposed the task and wired the roles. Lecture 2 turns to the hard part:
# what to do when the roles disagree, and the trap that is far more dangerous, when
# they all agree for the wrong reason.
#
# ---

# %% [markdown]
# ### 📝 Practice: assign roles, order, and decision rights
#
# *(In class: answers aloud, a couple of minutes; writing them down is optional.)*
#
# *(Human-first: do all three yourself before any AI. The assignment is the graded
# skill.)*
#
# For one section of your chapter, you will run three AI roles. In the cell below, do
# three things for that section:
#
# 1. **Assign** each of three roles a scoped task (one sentence each). Pull from
#    drafter, reviewer, methodologist, skeptic, citation-checker, editor.
# 2. **Order** them: mark which run in parallel and which wait on another (name the
#    dependency).
# 3. **Decision rights**: for each role, name the one decision it is allowed to
#    *inform* and the one decision it is never allowed to *settle*.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Role 1 (scoped task / runs when / informs vs never settles):**
#
# **Role 2 (scoped task / runs when / informs vs never settles):**
#
# **Role 3 (scoped task / runs when / informs vs never settles):**
#
# ---

# %% [markdown]
# ### ⚖️ Make a Design Choice: wire your own chapter section
#
# *(In class: commit to one option in a single written line and be ready to defend it aloud; the full write-up is optional depth.)*
#
# *(Human-first: settle your own wiring and its defense before you ask any AI.)*
#
# Take one section of your chapter (your methods, your results, or your limitations).
# You have three AI roles available: a **drafter**, a **fact-checker**, and a
# **skeptic**. Choose one wiring and defend it in a short paragraph:
#
# - **A.** All three run in parallel on the current draft.
# - **B.** Drafter first, then fact-checker and skeptic in parallel on the new draft.
# - **C.** Drafter, then fact-checker, then skeptic, strictly one after another.
#
# In the cell below, pick A, B, or C, then defend it: what does your wiring gain, what
# does it cost in rounds, and which early error would it stop from flowing downstream?

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My chosen wiring (A / B / C):**
#
# **What it gains and what it costs in rounds:**
#
# **The early error my wiring stops from flowing downstream:**
#
# ---

# %% [markdown]
# ### 🎯 Take It to Your Project
#
# One sentence: how does today's research decision change the next step of your
# own project? Write it below, then add the same line to your Research Project
# Dossier.
#
# **My line:**

# %% [markdown]
# ### 🛡️ Defend Your Decision
#
# Close the lecture out loud. In the three lines below, state the claim you now
# hold from today, the evidence that justifies it, and the uncertainty it still
# carries.
#
# **Claim:**
#
# **Justification:**
#
# **Uncertainty:**

# %% [markdown]
# ### 📒 AI Research Ledger
#
# Before you leave the room, add today's row to your AI Research Ledger: task
# delegated · tool used · prompt · output summary · decision · verification
# method · remaining concern · responsible researcher. One honest row is enough,
# and if you delegated nothing to AI today, log that decision too.

# %% [markdown]
# ---
#
# ### ⏸ Optional depth from here
#
# **Today's lecture path is complete.** Anything between this line and the next lecture heading is optional depth: run it if you want to push the ideas further. Nothing below this line is required, and any 🏠-marked prompt above it is optional too.

# %% [markdown]
# **🏠 Optional depth.** Run this on your own if you want to go deeper.
# **Before you ask:** in one sentence, name the single check your chapter most needs
# right now. Write it down first, so you can see whether the tool's tidy list of roles
# actually includes it.
#
# > 💡 **AI Prompt:** "I am decomposing my research chapter into scoped AI roles.
# > Here is my chapter's structure: [paste your section headings and one line on each].
# > Propose a table of AI roles for it, one row per role, with columns for the role's
# > scoped task, what draft or input it needs, whether it runs in parallel or waits on
# > another role, and the single decision it must hand back to me. Then, as a hostile
# > reviewer, tell me the one check my chapter most needs that your table left out."
# >
# > **After running, verify (counters *illusion of completeness*: a long, tidy role
# > table that omits the check that matters most):**
# > - [ ] Compare the table against the check you committed to above. If yours is
# >   missing, the tidy output just failed the one test it looked complete on.
# > - [ ] For every role, confirm the "hand back to me" column names a real
# >   never-delegate decision, not a fake one it invented to look cautious.
# > - [ ] Decide *yourself* which roles are worth the hand-off cost. A table with ten
# >   roles you cannot supervise is worse than three you can.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %% [markdown]
# ---
#
# # Lecture 2

# %% [markdown]
# 🗺️ **Today's frame (Wednesday, 7 / 23 / 12 / 8):** open with the 🧩 challenge, a spoken 📝 **Practice** retrieval drill, and 🔮 **Predict First** · attack the problem with 🛠️ **Run the Study**, 🔁 modifying the prompt and 🔬 interrogating what comes back · verify with 🔍 **Read the Evidence** · defend ⚖️ **Make a Design Choice** to your peers, AI closed at the 🧑‍⚖️ checkpoint · close with 🎯 **Take It to Your Project**, 🛡️ **Defend Your Decision**, and your 📒 ledger row. All seven moves happen in class; 🏠-marked items and everything below the ⏸ line are optional depth.

# %% [markdown]
# ### 🎤 SRL Lead Brief
#
# *This lecture opens with its Student Research Lead. If this is your slot, this
# brief is your backbone. If not, read along: this is how the room will run.*
#
# **Your mission.** By minute 50, everyone can say whether their roles' agreement was
# independent confirmation or one error repeated, and holds a written stopping rule
# plus the decisions they refuse to automate.
#
# **Run of show (Wednesday: 7 / 23 / 12 / 8).**
#
# | Min | Section | What you do |
# |---|---|---|
# | 0–7 | Retrieval challenge | Present the puzzle below: three AI reviewers all say the chapter looks solid. The room decides whether that is three confirmations or one error echoed three times, before your AI is opened. |
# | 7–30 | Applied AI laboratory | Work Sections 3 and 4 with the room: separate real disagreement, correlated error, and false consensus, then run the four-reviewer simulation live and read both miss rates out loud (about 6% for the independent team, about 43% for the correlated one). Keep asking one thing: could these roles have been wrong the same way? |
# | 30–42 | Peer defense | Run the adversarial questioning: everyone defends what they delegated, rejected, and verified in their own workflow. The first Evidence Defenses are staged here, so every non-defender arrives with at least one ledger-grounded question. |
# | 42–50 | Project transfer | Everyone records the decision and a ledger entry; close on a spoken Claim Ticket. |
#
# **Three questions that keep the room thinking.**
#
# 1. *"Could three reviewers be wrong the same way?"* Listen for: yes, if they share a
#    base model, a prompt, or a blind spot, which makes their agreement one signal
#    instead of three. Watch out for: "no, three is more than one," which counts voices
#    rather than checking whether they were ever independent.
# 2. *"What would make their agreement worth more?"* Listen for: independence, so vary
#    the tool, vary the framing, give them different context, and add a check that no
#    model can share a blind spot with. Watch out for: "add more reviewers," which the
#    team-size sweep shows does not move the correlated floor.
# 3. *"When would you overrule all three at once?"* Listen for: at a never-delegate
#    decision such as a claim boundary, an ethical call, or the defense itself, backed
#    by a check you ran without AI.
#
# **One AI trap to watch for.** Ask a chatbot "is my chapter ready?" and it comes back
# warm and fluent: yes, this is strong. That is sycophantic agreement wearing the
# costume of review, and it feels exactly like the confirmation everyone was hoping
# for. When it appears, name it out loud, reframe the ask neutrally ("list the three
# weakest claims in this chapter and say why each is weak"), and rerun it in front of
# the room so the difference is visible.
#
# **Checkpoints.** By minute 7, confirmation and correlated error are separated on the
# board as two different things. By minute 30, both miss rates are on the board with
# the roughly sevenfold gap stated out loud. By minute 42, everyone holds a stopping
# rule and a never-automate list drafted for the M15 portfolio.
#
# **Make it yours.** The frame, the puzzle, and the checkpoints are fixed;
# the staging is yours. Bring four real reviews of your own draft, three that agree and
# one that dissents, and let the room sort them cold before any simulation runs. Or
# restage the challenge as a cross-examination: the agreeing roles testify, the room
# questions them, and one volunteer has to argue that the agreement is worth nothing.
# In your prep script, name one thing you are adding that this brief does not contain.
#
# **Prep.** Start about a week ahead. Submit your preparation script or notebook
# two days ahead. The full guide is the course book's Student Research Lead
# appendix.

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(Your research lead opens the lecture with this. Think it through and commit an
# answer before we go further. No AI yet.)*
#
# You send your chapter to three AI reviewers. All three come back with the same
# verdict: **"This looks solid. No major problems."**
#
# Here is the question on the table. Is that **three independent confirmations**, or
# **one mistake echoed three times**? Commit to an answer before we go further. Then
# defend it: name one thing that, if it were true about how you set up the three
# reviewers, would make their agreement nearly worthless. If you can name that thing,
# you have found the trap this lecture exists to catch. If three agreeing tools can
# still all be wrong the same way, then agreement alone is not evidence.

# %% [markdown]
# ### 📝 Practice: retrieval drill
#
# Before any AI opens today: from memory, in about a minute, state (1) Monday's
# research decision rule in one line, (2) one claim it permits, and (3) one claim
# it does not permit. Answers run aloud; nothing written is required.

# %% [markdown]
# ## 3. Conflicting Outputs: Real Disagreement, Correlated Error, False Consensus
#
# **Guiding question:** *when two AI roles disagree, and when they all agree, what are
# you actually looking at?*
#
# > *"Do not tell me your reviewers agreed. Tell me whether they could have agreed for
# > the same wrong reason. Agreement is the easiest thing in the world to manufacture,
# > and the most dangerous to trust."*
# > — a **skeptical peer** at your practice defense
#
# **Reconciling conflicting outputs** is the work of deciding what to believe when your
# roles do not match. The first move is not to pick a winner. It is to diagnose *why*
# they differ, because there are three very different cases and they call for opposite
# responses.
#
# - **Real disagreement**: the roles genuinely read the evidence differently. Example:
#   your reviewer calls a sentence "clear and strong" while your methodologist flags
#   that same sentence as reaching past your data. This is *useful*. It points you
#   straight at the claim you need to check.
# - **Correlated error**: the roles *agree*, but on the same wrong assumption, so the
#   agreement proves nothing. Example: three reviewers built from the same base model,
#   given the same prompt, all miss the same flaw because they share the blind spot.
#   Ask: could they be wrong the *same* way? If yes, their consensus is one signal, not
#   three.
# - **False consensus**: the roles agree only because your prompt framed the task so
#   they had to. Example: you ask "confirm my chapter is ready," and every role obliges.
#   You led all the witnesses. Reframe the ask neutrally and run it again.
#
# > **A question that often comes up here:** *"Conflict feels like the problem. Isn't
# > agreement what I want?"* It is the reverse. Conflict announces itself and tells you
# > where to look. Correlated error and false consensus feel like confirmation while
# > quietly agreeing on something false. The trap to fear most is agreement, not
# > conflict. When roles agree on something that matters, your job is to ask whether
# > they were ever independent before you trust it.

# %% [markdown]
# ## 4. Does Agreement Mean Confirmation? A Seeded Test
#
# **Guiding question:** *if you add more AI reviewers, does your chance of catching a
# real flaw actually improve, or does it stall?*
#
# Here is a clean way to see the trap. Imagine every chapter you send out has exactly
# one hidden flaw. You run a team of reviewers, and the team "misses" whenever *every*
# reviewer says the chapter looks fine while the flaw is really there. When that
# unanimous "looks fine" comes from reviewers who share a blind spot, it is **correlated
# error** in action: the team agreed, and the team was wrong the *same* way, so their
# agreement confirms nothing.
#
# You will compare two teams of the same size. In the **independent** team, each
# reviewer catches the flaw on its own, uncorrelated with the others. In the
# **correlated** team, the reviewers share a blind spot: some of the time, the flaw
# falls in a region they are *all* blind to, so every one of them misses it together.
# Same number of reviewers. The only difference is whether their errors are
# independent.

# %% [markdown]
# ### 🔮 Predict First
#
# Both teams have four reviewers, and each reviewer catches the hidden flaw about half
# the time on its own. The correlated team shares a blind spot on about 40% of
# chapters.
#
# Before running the next cell, commit to two numbers. First: out of every 100
# chapters, how many will the **independent** team miss entirely (all four wrong at
# once)? Second: how many will the **correlated** team miss? Write which you expect to
# be larger, and by roughly how much. Do not peek at the output first. You are
# predicting a reveal.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Independent team: misses per 100 chapters (my prediction):**
#
# **Correlated team: misses per 100 chapters (my prediction):**
#
# **Which is larger, and by roughly how much:**
#
# ---

# %% [markdown]
# ### 🛠️ Run the Study: independent vs correlated reviewers
#
# Run the cell below. It simulates 5,000 chapters, each with one hidden flaw, reviewed
# by a four-role team. It reports how often each team misses a flaw unanimously (all
# four say "fine" while a flaw is really there), and plots the two rates side by side.
# Read the two numbers before you read the next markdown cell.
#
# **🔴 Live in class: we run this one together.**
# **Before you ask:** write one sentence predicting whether the correlated team's miss
# rate is a little higher or a lot higher than the independent team's.
#
# > 💡 **AI Prompt:** "Here is a Python cell that simulates two four-reviewer teams,
# > one with independent errors and one that shares a blind spot, and reports how often
# > each misses a flawed chapter unanimously: [paste the next cell]. Walk me
# > through, line by line, how the correlated team's shared blind spot is built, and why
# > its miss rate does not shrink the way the independent team's does. Then give me one
# > independent way to confirm the two printed rates without rerunning this exact code."
# >
# > **After running, verify (counters *correlated errors across tools or roles*: asking
# > the same model twice feels like confirmation when it is one flaw echoed back):**
# > - [ ] Confirm the miss rates your AI quotes match the `independent` and `correlated`
# >   percentages your cell actually printed, not numbers it guessed.
# > - [ ] Check its explanation of the shared blind spot against the `blind` line in the
# >   code. If it describes a mechanism the code does not contain, trust the code.
# > - [ ] Notice the irony and log it: you just used one AI to check a claim about AI
# >   agreement, so confirm its answer with the printout, not its confidence.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %%
# Two four-reviewer teams on 5,000 flawed chapters. Fresh seed so this is
# reproducible on its own, regardless of what ran before (seed 464).
rng_sim = np.random.default_rng(SEED)

n_chapters = 5000
k = 4        # reviewers per team
detect = 0.5 # each reviewer catches the hidden flaw about half the time, on its own
rho = 0.40   # the correlated team shares a blind spot on ~40% of chapters

# Independent team: each reviewer catches the flaw on its own. A MISS = all four fail.
caught_indep = rng_sim.random((n_chapters, k)) < detect
miss_indep = ~caught_indep.any(axis=1)
rate_indep = miss_indep.mean()

# Correlated team: on a shared-blind-spot chapter, EVERY reviewer misses together;
# otherwise each catches on its own, just like the independent team.
blind = rng_sim.random(n_chapters) < rho
caught_corr = (rng_sim.random((n_chapters, k)) < detect) & (~blind[:, None])
miss_corr = ~caught_corr.any(axis=1)
rate_corr = miss_corr.mean()

print("A team MISS = all four reviewers say 'fine' while a real flaw is present.")
print(f"  Independent team miss rate : {rate_indep:.1%}   ({miss_indep.sum()} of {n_chapters})")
print(f"  Correlated team miss rate  : {rate_corr:.1%}   ({miss_corr.sum()} of {n_chapters})")
print(f"  The correlated team is unanimous-and-wrong about {rate_corr/rate_indep:.1f}x as often.")

fig, ax = plt.subplots(figsize=(7, 5))
# Independent gets the calm blue; correlated gets the warning orange (never the truth hue).
ax.bar(["Independent\nreviewers", "Correlated\nreviewers"],
       [rate_indep, rate_corr], color=["#4C72B0", "#DD8452"], edgecolor="white")
ax.set_ylim(0, 0.55)
ax.set_ylabel("Share of flawed chapters the team MISSES")
ax.set_title("Same four reviewers: a shared blind spot manufactures correlated error")
for i, r in enumerate([rate_indep, rate_corr]):
    ax.text(i, r + 0.012, f"{r:.1%}", ha="center", fontsize=11)
plt.tight_layout()
plt.show()

# %%
# Self-check: the correlated team misses real flaws several times more often.
assert 0.04 < rate_indep < 0.09, "independent miss rate drifted — is the seed 464?"
assert 0.40 < rate_corr < 0.47, "correlated miss rate drifted — is the seed 464?"
assert rate_corr > 5 * rate_indep, "the shared blind spot should dominate"
print(f"✓ Self-check passed: independent misses {rate_indep:.1%} of flawed chapters, "
      f"correlated misses {rate_corr:.1%}.\n  Four reviewers either way, about "
      f"{rate_corr/rate_indep:.0f}x the false-confidence rate. Agreement is only worth "
      f"the independence behind it.")

# %% [markdown]
# The independent team is unanimous-and-wrong on about **6%** of flawed chapters. The
# correlated team, the same four reviewers, is unanimous-and-wrong on about **43%**,
# roughly seven times as often. Nothing changed except whether the reviewers could miss
# the flaw *together*. When they share a blind spot, four "looks fine" verdicts are not
# four confirmations. They are close to one. This is why asking the same model twice,
# or four roles built the same way, can feel like a chorus of agreement while every
# voice is repeating the same mistake.

# %% [markdown]
# ### 🔍 Read the Evidence: what agreement was and was not worth
#
# You now have two miss rates from the same four-role team, and the lesson has a name. An
# **independence check** is a test that a between-role agreement is worth more than a
# head-count: an independent check you run yourself, or a way you make two roles genuinely
# independent (a different tool, a different framing, different context) rather than the
# same role asked twice. Example: two roles both bless a claim, so you re-read the cited
# source yourself before you trust the agreement. The independence check is the fourth
# part of your M15 portfolio, and the simulation you just ran is the reason it exists.
#
# In the cell below, write three things. First: the false claim this simulation warns you
# against, phrased as a sentence a careless researcher would actually write about their
# reviewers. Second: the *mechanism* that made the correlated team so much worse, in your
# own words. Third: one **independence check** you could run on your real chapter, so that
# when your reviewers agree, their agreement is worth more than one voice.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **The false claim this warns against:**
#
# **The mechanism behind the correlated team's higher miss rate:**
#
# **One concrete step to make my real reviewers more independent:**
#
# ---

# %% [markdown]
# ### 🔁 Modify the Prompt
#
# *(In class: one modification, one prediction, one rerun; deeper variations are optional depth.)*
#
# The false-consensus trap often starts in *your* prompt. A leading ask ("confirm my
# chapter is ready") manufactures agreement. First, write a neutral, non-leading review
# prompt for your own chapter yourself. Do not let AI draft it. Then run the same
# chapter past two roles you deliberately set up to be *independent*: give them
# different framings and different context.
#
# > **Base prompt (leading, the one to fix):** "Review my chapter and confirm it is
# > ready to submit."
#
# Rewrite it into two independent asks. One might be neutral ("List the three weakest
# claims in this chapter and why"). The other might be hostile and differently
# scoped ("You are a reviewer who wants to reject this. Attack the design, not the
# prose"). In the cell below: paste your two rewritten prompts, predict where the two
# roles will *disagree*, then run them and note whether the disagreement was real, or
# whether they still agreed the same way.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My neutral review prompt (AI did not draft this):**
#
# **My hostile, differently-scoped prompt:**
#
# **Where I predict the two roles will disagree:**
#
# **What actually happened (real disagreement, or agreement the same way?):**
#
# ---

# %% [markdown]
# ### 🔬 Interrogate the Output
#
# *(In class: raise the sharpest challenge and check it; the full written interrogation is optional depth.)*
#
# The AI just handed you five "hardest questions" for your defense. Do not accept the
# list as complete or correctly ranked. Interrogate it against the defense protocol and
# your own ledger, using four checks. Answer each in the cell below.
#
# - **Claims:** does each question point to a real weakness in *your* evidence, or a
#   generic one any project would face? A generic question is not the one that will sink
#   you.
# - **Assumptions:** what does the cross-examiner assume about your design? Did it invent
#   a method or a claim you never made, then attack that instead?
# - **Missing information:** which real weakness did it *miss*? Compare its list to your
#   three weakest ledger rows. The question it skipped is the one to prepare hardest.
# - **Overstatements:** does any question smuggle in a false premise ("since your result
#   is causal...") that you must correct before answering, not accept?
#
# And the rule that governs the whole notebook: **agreement is not verification, and a
# fluent question list is not a complete one.** Rank the questions yourself, against
# your ledger, before you trust the tool's ranking.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Claims (which questions hit a real weakness in my evidence?):**
#
# **Assumptions (did it attack a method or claim I never made?):**
#
# **Missing information (the weakness it skipped, from my weakest ledger rows):**
#
# **Overstatements (a false premise I must correct before answering):**
#
# ---

# %% [markdown]
# ### 🧑‍⚖️ Human-Only Checkpoint
#
# *(In class: AI closed, one decision, one line of reasoning.)*
#
# Close every AI tool for this one. No roles, no notebook search. This is the
# never-delegate core of M15, and it is the last such checkpoint of the course. In the
# cell below, write, in your own words:
#
# 1. **Your stopping rule** for this chapter: one sentence naming what has to be true
#    about *your* confidence before you submit, phrased around verification you ran,
#    not around the roles agreeing.
# 2. **Three decisions you refuse to automate** on this chapter, and for each, one line
#    on why it carries your name and not a tool's.
# 3. **One escalation you actually made** this semester: a moment you took the pen back
#    from an AI output, what you decided instead, and the non-AI check that backed you.
#    If you cannot name one yet, that is a finding. Go make the escalation your ledger
#    is missing before you defend.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **1. My stopping rule (about my verified confidence, not the roles agreeing):**
#
# **2. Three decisions I refuse to automate (and why each is mine):**
#
# **3. One escalation I made (what I overrode, decided, and how I verified):**
#
# ---

# %% [markdown]
# ### ⚖️ Make a Design Choice
#
# *(In class: commit to one option in a single written line and be ready to defend it aloud; the full write-up is optional depth.)*
#
# From today's lab, name the one design decision most relevant to your own
# project. Take a position on it, with one reason and one risk.
#
# **My choice:**
#
# **Reason:**
#
# **Risk:**

# %% [markdown]
# ### 🎯 Take It to Your Project: your M15 chapter, portfolio, and defense
#
# In class, one sentence: the line your Evidence Defense will lead with — your
# claim and its boundary, as you will say them in the room. Write it below,
# then add the same line to your Research Project Dossier.
#
# **The portfolio you build at Friday's studio (M15):** the decomposition of
# your AI roles with the one node you kept human · the conflict-and-override
# log with its non-AI verification · the stopping rule and never-automate list
# · the independence check that makes agreement worth more than a head-count ·
# the defense in three movements. The M15 brief collects all five; your AI
# assistant helps there, and the chapter stays yours.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My line (the claim + boundary my defense leads with):**
#
# ---

# %% [markdown]
# ### 🛡️ Defend Your Decision
#
# Defense #15 — the last one. The short ritual close, one line each:
#
# 1. **The claim I can defend:** one bounded sentence from your own chapter,
#    name-worthy in the room.
# 2. **Its boundary:** the compass position, and any crossing you did or did not
#    license.
# 3. **My uncertainty and limitations:** what is still uncertain and why, one
#    line.
# 4. **AI check:** across the whole workflow, the one place you **overrode** an
#    AI output, and the non-AI check that decided it.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **1. The claim I can defend:**
#
# **2. Its boundary (compass position + crossing licensed or not):**
#
# **3. My uncertainty and limitations:**
#
# **4. AI check (what I delegated, where I overrode, how I verified):**
#
# ---

# %% [markdown]
# ### 📒 AI Research Ledger
#
# Log every AI use from this notebook in the ledger. One worked row is filled in as a
# model, and it is an **escalation** row, the kind your M15 portfolio is read for: you
# overrode a correlated agreement. This notebook offers five prompts, one live per lecture
# and three optional-depth, so your ledger carries a row for each one you actually ran.
# The ledger is the spine of your final defense: it is how you show every claim was
# verified and every override was owned.
#
# | Task delegated | Tool used | Prompt | Output summary | Decision | Verification method | Remaining concern | Responsible researcher |
# |---|---|---|---|---|---|---|---|
# | Review my chapter's headline claim with three reviewer roles | your AI (3 roles) | "Review this chapter and flag any problem" (run three times) | All three returned "looks solid, no major problems" | ESCALATED (trigger 3): I treated the agreement as one signal, not three, and re-checked the headline myself | Re-read the claim against my inquiry declaration; found it reached past my sample | The roles shared a base model, so their agreement was correlated by construction | *(your name)* |
# |  |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |  |
#
# ---

# %% [markdown]
# ## 5. Wrap-Up
#
# Across two lectures you learned to run a *team* of AI roles instead of one assistant.
# You decomposed a chapter into scoped tasks, wired them into a worker-critic workflow,
# and read off the code what running critics in parallel buys you against sequencing
# them. Then you met the trap that a room full of agreeing tools sets: your simulation
# showed four correlated reviewers missing a real flaw about seven times as often as
# four independent ones, and adding more correlated roles could not fix it. You learned
# to diagnose why roles differ, to escalate and override at the decisions that are
# yours, to write a stopping rule about your own confidence, and to stage the Evidence
# Defense you now perform.
#
# > **"More roles do not mean more truth. Agreement is worth only the independence
# > behind it, and the decisions that carry your name, the claim boundary, the ethics,
# > the defense, never belong to the tools. You ran the team. You own the chapter."**
#
# That is the course. You began with a curiosity and a set of assumptions about what AI
# could do for your research. You end able to classify a question, match it to a design,
# say what an answer can and cannot establish, and defend every claim from a verified
# ledger. The habit you built, ask then verify then document, outlasts this class and
# every tool in it. Bring your chapter, your ledger, and your AI-management portfolio to
# the defense. Then submit, and stand behind the evidence.
#
# ---

# %% [markdown]
# ## 6. Sources & Provenance
#
# **Provenance of this notebook:**
# - *fresh | the multi-agent method (task decomposition, worker-critic wiring, the correlated-error / false-consensus framing) | newly-constructed-from-source-concept*
# - *ai_resources/multi_agent_worksheet.md | the decompose -> declare-dependencies -> diagnose-conflict -> override -> stopping-rule sequence | adapted into the notebook's flow*
# - *ai_resources/ai_error_taxonomy.md | correlated errors, false consensus, sycophantic agreement, illusion of completeness (the verify checklists) | referenced*
# - *ai_resources/escalation_protocol.md | the five triggers, human override, and the escalation ledger row | referenced*
# - *project/final_dossier/evidence_defense_protocol.md | the ten-minute defense (claims / choices / verification), concede-gracefully, the three forbidden moves | referenced*
# - *GenAI Studio sequential-workflow roles (level-4 planning aid) | the worker-critic role bench run against a chapter draft | referenced*
# - *fresh | the seeded worker-critic workflow graph and the independent-vs-correlated reviewer simulation, a correlated-error demonstration (seed 464) | newly-constructed-from-source-concept*
#
# **Readings:**
# - *(Optional send-off)* Blair, G., Coppock, A., & Humphreys, M. (2023). *Research
#   Design in the Social Sciences*, ch. 24 'Epilogue'. Free online:
#   [book.declaredesign.org](https://book.declaredesign.org/).
# - Course AI resources: the
#   [multi-agent worksheet](https://github.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/ai_resources/multi_agent_worksheet.md),
#   the [escalation protocol](https://github.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/ai_resources/escalation_protocol.md),
#   and the [Evidence Defense protocol](https://github.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/project/final_dossier/evidence_defense_protocol.md).
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>

# %% [markdown]
# ---
#
# ### ⏸ Optional depth from here
#
# **Today's lecture path and the notebook's close are complete.** Everything below this line is optional depth: run it if you want to push the ideas further. Nothing here is required, and any 🏠-marked prompt above is optional too.

# %% [markdown]
# **🏠 Optional depth.** Run this on your own if you want to go deeper.
# **Before you ask:** predict in one sentence what happens to each team's miss rate as
# you add more reviewers. Commit before the tool explains it.
#
# > 💡 **AI Prompt:** "This cell sweeps the number of reviewers from 2 up to 16 for
# > both an independent team and a correlated team that shares a blind spot, and prints
# > each team's miss rate at every team size: [paste the next cell]. Explain why the
# > independent team's miss rate keeps shrinking toward zero while the correlated team's
# > flattens out at a floor. Then tell me what that floor equals and why adding more
# > correlated reviewers cannot push the miss rate below it."
# >
# > **After running, verify (counters *correlated errors across tools or roles*: 'more
# > reviewers' is not the same as 'more independence'):**
# > - [ ] Confirm the floor your AI names matches the correlated rate your cell printed
# >   at the largest team size, not a rounder number it preferred.
# > - [ ] Check that its independent-team numbers match the printed sweep at each team
# >   size, not a smooth curve it imagined.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.

# %%
# Sweep the team size. Fresh seed so the sweep is reproducible on its own (seed 464).
rng_sweep = np.random.default_rng(SEED)

team_sizes = [2, 4, 8, 16]
indep_rates, corr_rates = [], []
for kk in team_sizes:
    caught_i = rng_sweep.random((n_chapters, kk)) < detect
    indep_rates.append((~caught_i.any(axis=1)).mean())
    bl = rng_sweep.random(n_chapters) < rho
    caught_c = (rng_sweep.random((n_chapters, kk)) < detect) & (~bl[:, None])
    corr_rates.append((~caught_c.any(axis=1)).mean())

print("Miss rate as the team grows:")
print(f"  {'reviewers':>10} | {'independent':>12} | {'correlated':>11}")
for kk, ri, rc in zip(team_sizes, indep_rates, corr_rates):
    print(f"  {kk:>10} | {ri:>11.1%} | {rc:>10.1%}")
print(f"\n  The correlated floor sits near the shared-blind-spot rate ({rho:.0%}): "
      f"adding roles cannot push below it.")

fig, ax = plt.subplots()
ax.plot(team_sizes, indep_rates, marker="o", color="#4C72B0", label="independent reviewers")
ax.plot(team_sizes, corr_rates, marker="s", color="#DD8452", label="correlated reviewers")
ax.axhline(rho, color="#8C8C8C", linestyle=":", linewidth=1.3, label=f"shared blind-spot rate ({rho:.0%})")
ax.set_xlabel("Number of reviewers on the team")
ax.set_ylabel("Share of flawed chapters missed")
ax.set_title("More reviewers help only if their errors are independent")
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Self-check: independence buys you everything; correlation floors out near rho.
assert indep_rates[0] > indep_rates[-1], "independent miss rate should fall as the team grows"
assert indep_rates[-1] < 0.01, "16 independent reviewers should almost never all miss"
assert corr_rates[-1] > 0.30, "the correlated team should stay stuck near the shared blind-spot floor"
print(f"✓ Self-check passed: independent misses fall from {indep_rates[0]:.1%} to "
      f"{indep_rates[-1]:.1%} across 2 to 16 reviewers;\n  the correlated team barely "
      f"moves, from {corr_rates[0]:.1%} to {corr_rates[-1]:.1%}. Count is not independence.")

# %% [markdown]
# *The two lines say it plainly: the independent team's misses drop toward zero as it
# grows, while the correlated team flattens against a floor set by its shared blind
# spot. Piling on more correlated reviewers cannot buy what independence buys.*

# %% [markdown]
# ### ⚔️ Competing AI Roles
#
# Now pit two roles against each other on a single sentence you care about, and
# adjudicate as the human. Take one headline sentence from your chapter. Run it past a
# **Research-Note Reviewer** (optimizes for clarity and strength) and a
# **Research-Question Diagnostician** (checks the claim stays inside its compass reach).
# When the reviewer praises the sentence and the diagnostician flags it as overreaching,
# you have a conflict to diagnose and decide.
#
# In the cell below: paste the sentence, summarize what each role said, diagnose the
# conflict (real disagreement, correlated error, or false consensus), and record *your*
# decision with a non-AI verification.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My headline sentence:**
#
# **What the Reviewer said / what the Diagnostician said:**
#
# **My diagnosis (real disagreement / correlated error / false consensus):**
#
# **My decision, and the non-AI check that backs it:**
#
# ---

# %% [markdown]
# ## 7. Escalation, Human Override, and Stopping Rules
#
# **Guiding question:** *at what moment do you stop letting AI drive and take the
# decision back into your own hands, and how do you know when you are done?*
#
# Some decisions are never the tools' to make. The habit that protects them is
# **escalation to human judgment**: the moment an AI output would *settle* rather than
# *inform* a decision that is yours, you stop and decide it yourself. Example: a role
# proposes calling your result "causal." That would settle your claim boundary, so it
# escalates to you. The five triggers that force an escalation are listed in
# [`ai_resources/escalation_protocol.md`](https://github.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/ai_resources/escalation_protocol.md);
# any one is enough.
#
# What you do at an escalation is a **human override**: you take the pen back and make
# the call in your own words, backed by your own verification, even when the roles
# agreed on something else. Example: three roles agree your causal wording is fine, and
# you overrule all three because your design has no identification argument. A
# decision that just counted the roles is not a decision. It is a vote, and votes among
# correlated models are meaningless.
#
# You also need a **stopping rule**: a written statement of what "done" looks like,
# about *your* confidence, not the roles' agreement. Example: "I stop when I can defend
# each surviving claim to a hostile reviewer with a verification I ran myself." A bad
# stopping rule is "when the roles all agree," because that can happen while everyone is
# wrong, as your simulation just showed.
#
# Finally, some calls are **decisions that should never be automated** no matter how
# good the tools get: which research problem to pursue, the claim boundary, an ethical
# judgment, and the public defense. These stay human by design.
#
# > **A question that often comes up here:** *"If I keep overriding the AI, why use it
# > at all?"* Because the tools are excellent at the parts you *can* delegate: drafting,
# > surfacing leads, listing threats, tightening prose. Escalation does not mean
# > distrusting everything. It means keeping a human at the few decisions that carry
# > your name. A semester-long ledger with zero escalations is a warning sign, not a
# > badge. It usually means AI was never used on anything that mattered, or a boundary
# > was crossed without anyone noticing.

# %% [markdown]
# ## 8. Staging the Evidence Defense
#
# **Guiding question:** *how do you stand behind your claims out loud, at their
# boundaries, under questions you cannot rehearse for?*
#
# The course ends where it began, with a claim you would put your name on, now defended
# in public. The **Evidence Defense** is a ten-minute defense followed by a five-minute
# cross-examination, in which you defend not just *what* you claim but *why* your
# compass position, your data, and your checks license it. The full format lives in
# [`project/final_dossier/evidence_defense_protocol.md`](https://github.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/project/final_dossier/evidence_defense_protocol.md).
# Your ten minutes have three movements, in order:
#
# - **Claims (about three minutes)**: your headline claim and the exact edge it stops
#   at. Example: "In my sample I find X; I do not claim it holds for the population."
# - **Choices (about four minutes)**: why this compass position, this data strategy,
#   this operationalization, and the road you did not take.
# - **Verification (about three minutes)**: how you checked, the sensitivity that
#   survived, the sources confirmed real. Verification is the spine of the defense, not
#   an afterthought.
#
# Two more terms decide whether the defense goes well. **Concede gracefully** means
# that where your ledger says a claim reaches too far, you say so precisely and name the
# smaller true claim, instead of digging in. Conceding the right point on time is
# scored as strength, not weakness. And the **forbidden moves** are three ways to lose
# the room: inventing a new claim under pressure to escape a hard question, un-conceding
# a point by insistence rather than evidence, and blaming the AI tool. "The AI gave me
# that" is never a defense. You verified, or you did not.
#
# All of this feeds your **AI-management portfolio**: the record of how you ran your AI
# team this semester, what you automated, where you escalated, and which decisions you
# kept human. It is read partly for whether you recognized those boundaries and took the
# pen back when you should have.
#
# > **A question that often comes up here:** *"What if I get a question I cannot
# > answer?"* Answer from your ledger if the row exists, and if it does not, concede the
# > point and name the smaller claim you *can* defend. That is a far stronger move than
# > inventing an answer, which is a forbidden move precisely because the room can tell.
# > A defense is not a performance of certainty. It is an honest account of what your
# > evidence holds and where it stops.

# %% [markdown]
# ### 📝 Practice: answer like a researcher
#
# Three questions you may hear at a defense. For each, draft a one-line answer
# that names your evidence and its boundary, without apologizing for either.
#
# - **A.** "How do you know your AI didn't write this?"
# - **B.** "Your sample is small. Why should we believe the effect?"
# - **C.** "What would change your conclusion?"
#
# **A:**
#
# **B:**
#
# **C:**

# %% [markdown]
# **🏠 Optional depth.** Run this on your own if you want to go deeper.
# **Before you ask:** write the one hard question you most fear in cross-examination.
# Commit it before the tool guesses at your weak points.
#
# > 💡 **AI Prompt:** "Act as a hostile but fair cross-examiner at a research
# > defense. Here is my headline claim, its stated boundary, and my three weakest ledger
# > rows: [paste them]. Ask me the five hardest questions you can, each grounded in a
# > specific claim or verification, ranked from most to least dangerous. Do not soften
# > them, and do not answer them for me. Then tell me which single question you think I
# > am least prepared for."
# >
# > **After running, verify (counters *sycophantic agreement*: a partner that reassures
# > you has rehearsed your ego, not your defense):**
# > - [ ] If every question is gentle or it calls your claim "well-supported," push back:
# >   "assume I am overclaiming, find the weakest link." Weak questions are a red flag.
# > - [ ] Check its hardest question against the question *you* committed to fearing
# >   above. If yours is scarier and missing from its list, trust your own judgment.
# > - [ ] Rehearse your answer from a real ledger row, not from memory. If no row backs
# >   your answer, that is the row to build before you defend.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision, verification.
